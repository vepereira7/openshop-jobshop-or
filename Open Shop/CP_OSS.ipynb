# %%
# Description: Open Shop Scheduling Problem using Constraint Programming
# import the necessary classes
import pandas as pd
import numpy as np
import time
from ortools.constraint_solver import pywrapcp
from ortools.sat.python import cp_model
from ortools.constraint_solver.pywrapcp import IntervalVar 
from ortools.init import pywrapinit
import collections
import pandas as pd

# %%
def extract_data(filename):
    # Initialize variables to store the data.
    nj = []
    nm = []
    times = []
    machines = []

    task_counter = 0
    task_matrix = []


    # Open the file and read each line.
    with open(filename, 'r') as file:
        contents = file.read()
        lines = contents.splitlines()

        for line in range(len(lines)):
            # Check if the line contains the number of jobs and machines.
            if 'number of jobs' in lines[line]:
                nj.append(lines[line + 1].split()[0])
                nm.append(lines[line + 1].split()[1])
                break
        
        num_jobs = int(nj[0])
        num_machines = int(nm[0])
        for line in range(len(lines)):

            if 'number of jobs' in lines[line]:
                continue

            # elif ' ' in lines[line]:
            #     continue

            elif 'processing times :' in lines[line]:

                task_matrix.append(task_counter)
                task_matrix[task_counter] = []

                job_counter = 0

                pos = 0
                while pos < num_jobs:
                    pos += 1
                    time_var = lines[line + pos].split()
                    machine_var = lines[line + pos + num_jobs + 1].split()

                    task_matrix[task_counter].append([])
                    
                    #print('new times/machines pairs')
                    for aux in range(len(time_var)):
                        #print(f'{time_var[aux]} , {machine_var[aux]}')
                        task_matrix[task_counter][job_counter].append((int(time_var[aux]), int(machine_var[aux])))
                    
                    job_counter += 1

                task_counter +=1

        #print(task_matrix)
    
    for i in range(len(task_matrix)):
        for j in range(len(task_matrix[i])):
            for k in range(len(task_matrix[i][j])):
                task_matrix[i][j][k] = tuple(reversed(task_matrix[i][j][k]))

    return (num_jobs, num_machines, task_matrix)

# %%
num_jobs, num_machines, smaller_lists = extract_data('tai4_4.txt')

# %%
def main(jobs_data):
    """Entry point of the program."""
    machines_count = 1 + max(task[0] for job in jobs_data for task in job)
    all_machines = range(1,machines_count)
    # Computes horizon dynamically as the sum of all durations.
    horizon = sum(task[1] for job in jobs_data for task in job)

    # Create the model.
    model = cp_model.CpModel()

    # Named tuple to store information about created variables.
    task_type = collections.namedtuple('task_type', 'start end interval')
    # Named tuple to manipulate solution information.
    assigned_task_type = collections.namedtuple('assigned_task_type',
                                                'start job index duration')

    # Creates job intervals and add to the corresponding machine lists.
    all_tasks = {}
    machine_to_intervals = collections.defaultdict(list)

    for job_id, job in enumerate(jobs_data):
        for task_id, task in enumerate(job):
            machine = task[0]
            duration = task[1]
            suffix = '_%i_%i' % (job_id, task_id)
            start_var = model.NewIntVar(0, horizon, 'start' + suffix)
            end_var = model.NewIntVar(0, horizon, 'end' + suffix)
            interval_var = model.NewIntervalVar(start_var, duration, end_var,
                                                'interval' + suffix)
            all_tasks[job_id, task_id] = task_type(start=start_var,
                                                   end=end_var,
                                                   interval=interval_var)
            machine_to_intervals[machine].append(interval_var)

    # Create and add disjunctive constraints.
    for machine in all_machines:
        model.AddNoOverlap(machine_to_intervals[machine])

    # # Precedences inside a job.
    # for job_id, job in enumerate(jobs_data):
    #     for task_id in range(len(job) - 1):
    #         model.Add(all_tasks[job_id, task_id +
    #                             1].start >= all_tasks[job_id, task_id].end)

    # Makespan objective.
    obj_var = model.NewIntVar(0, horizon, 'makespan')
    model.AddMaxEquality(obj_var, [
        all_tasks[job_id, len(job) - 1].end
        for job_id, job in enumerate(jobs_data)
    ])
    model.Minimize(obj_var)

    # Creates the solver and solve.
    solver = cp_model.CpSolver()
    solver.parameters.max_time_in_seconds = 60.0 
    solver.parameters.num_search_workers = 8
    solver.parameters.log_search_progress = True
    status = solver.Solve(model)

    if status == cp_model.OPTIMAL or status == cp_model.FEASIBLE:
        print('Solution:')
        # Create one list of assigned tasks per machine.
        assigned_jobs = collections.defaultdict(list)
        for job_id, job in enumerate(jobs_data):
            for task_id, task in enumerate(job):
                machine = task[0]
                assigned_jobs[machine].append(
                    assigned_task_type(start=solver.Value(
                        all_tasks[job_id, task_id].start),
                                       job=job_id,
                                       index=task_id,
                                       duration=task[1]))

        # Create per machine output lines.
        output = ''
        for machine in all_machines:
            # Sort by starting time.
            assigned_jobs[machine].sort()
            sol_line_tasks = 'Machine ' + str(machine) + ': '
            sol_line = '           '

            for assigned_task in assigned_jobs[machine]:
                name = 'job_%i_task_%i' % (assigned_task.job,
                                           assigned_task.index)
                # Add spaces to output to align columns.
                sol_line_tasks += '%-15s' % name

                start = assigned_task.start
                duration = assigned_task.duration
                sol_tmp = '[%i,%i]' % (start, start + duration)
                # Add spaces to output to align columns.
                sol_line += '%-15s' % sol_tmp

            sol_line += '\n'
            sol_line_tasks += '\n'
            output += sol_line_tasks
            output += sol_line

        # Finally print the solution found.
        print(f'Optimal Schedule Length: {solver.ObjectiveValue()}')
        print(output)
    else:
        print('No solution found.')

    # Statistics.
    print('\nStatistics')
    print('  - conflicts: %i' % solver.NumConflicts())
    print('  - branches : %i' % solver.NumBranches())
    print('  - wall time: %f s' % solver.WallTime())
    print('  - status   : %s' % solver.StatusName(status))
    print('  - objective: %i' % solver.ObjectiveValue())
    print('  - User Time  : %i' % solver.UserTime())

# %%
main(smaller_lists[0])
# Out:
# Solution:
# Optimal Schedule Length: 116.0
# Machine 1: job_1_task_1   job_0_task_1   job_2_task_0   job_3_task_0
#            [0,15]         [15,49]        [49,87]        [87,182]
# Machine 2: job_0_task_3   job_3_task_2   job_2_task_1   job_1_task_2
#            [0,2]          [2,9]          [9,28]         [28,117]
# Machine 3: job_2_task_2   job_1_task_3   job_3_task_1   job_0_task_0
#            [0,28]         [28,98]        [98,132]       [132,186]
# Machine 4: job_3_task_3   job_2_task_3   job_1_task_0   job_0_task_2
#            [0,29]         [29,116]       [116,125]      [125,186]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 21
#   - wall time: 0.029321 s
#   - status   : OPTIMAL
#   - objective: 116
#   - User Time  : 0

# %%
list_files = ['tai4_4.txt','tai5_5.txt','tai7_7.txt','tai10_10.txt','tai15_15.txt','tai20_20.txt']
start_cell_time = time.time()
for i in range(len(list_files)):
    start_list_time = time.time()
    print(f'This is the file: {list_files[i]}')
    num_jobs, num_machines, smaller_lists = extract_data(list_files[i])
    for i in range(len(smaller_lists)):
        start_time = time.time()
        print (f'This is the list number: {i}')
        main(smaller_lists[i])
        print("--- %.2f seconds ---" % (time.time() - start_time))
    print("--- %.2f seconds for the file---" % (time.time() - start_list_time))
print("--- %.2f seconds for the cell---" % (time.time() - start_cell_time))
# Out:
# This is the file: tai4_4.txt
# This is the list number: 0
# Solution:
# Optimal Schedule Length: 116.0
# Machine 1: job_1_task_1   job_0_task_1   job_2_task_0   job_3_task_0
#            [0,15]         [15,49]        [49,87]        [87,182]
# Machine 2: job_0_task_3   job_3_task_2   job_2_task_1   job_1_task_2
#            [0,2]          [2,9]          [9,28]         [28,117]
# Machine 3: job_2_task_2   job_1_task_3   job_3_task_1   job_0_task_0
#            [0,28]         [28,98]        [98,132]       [132,186]
# Machine 4: job_3_task_3   job_2_task_3   job_1_task_0   job_0_task_2
#            [0,29]         [29,116]       [116,125]      [125,186]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 74
#   - wall time: 0.022949 s
#   - status   : OPTIMAL
#   - objective: 116
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 1
# Solution:
# Optimal Schedule Length: 128.0
# Machine 1: job_0_task_2   job_3_task_3   job_2_task_0   job_1_task_1
#            [0,45]         [45,119]       [119,148]      [148,228]
# Machine 2: job_1_task_3   job_0_task_3   job_3_task_2   job_2_task_1
#            [0,45]         [45,128]       [128,173]      [173,229]
# Machine 3: job_2_task_2   job_1_task_2   job_3_task_1   job_0_task_1
#            [0,29]         [29,87]        [87,151]       [151,221]
# Machine 4: job_0_task_0   job_3_task_0   job_2_task_3   job_1_task_0
#            [0,5]          [5,48]         [48,109]       [109,133]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 73
#   - wall time: 0.023662 s
#   - status   : OPTIMAL
#   - objective: 128
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 2
# Solution:
# Optimal Schedule Length: 104.0
# Machine 1: job_0_task_0   job_1_task_3   job_2_task_1   job_3_task_0
#            [0,2]          [2,87]         [87,141]       [141,200]
# Machine 2: job_0_task_2   job_3_task_2   job_1_task_0   job_2_task_2
#            [0,5]          [5,68]         [68,136]       [136,213]
# Machine 3: job_1_task_1   job_3_task_3   job_0_task_1   job_2_task_0
#            [0,14]         [14,86]        [86,124]       [124,213]
# Machine 4: job_2_task_3   job_0_task_3   job_3_task_1   job_1_task_2
#            [0,38]         [38,104]       [104,155]      [155,250]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 33
#   - wall time: 0.012519 s
#   - status   : OPTIMAL
#   - objective: 104
#   - User Time  : 0
# --- 0.02 seconds ---
# This is the list number: 3
# Solution:
# Optimal Schedule Length: 103.0
# Machine 1: job_1_task_1   job_3_task_1   job_2_task_2   job_0_task_2
#            [0,25]         [25,68]        [68,126]       [126,186]
# Machine 2: job_0_task_3   job_3_task_3   job_1_task_2   job_2_task_1
#            [0,19]         [19,81]        [81,121]       [121,209]
# Machine 3: job_2_task_3   job_1_task_3   job_0_task_1   job_3_task_2
#            [0,28]         [28,103]       [103,157]      [157,231]
# Machine 4: job_0_task_0   job_2_task_0   job_3_task_0   job_1_task_0
#            [0,35]         [35,87]        [87,147]       [147,245]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 16
#   - wall time: 0.010347 s
#   - status   : OPTIMAL
#   - objective: 103
#   - User Time  : 0
# --- 0.02 seconds ---
# This is the list number: 4
# Solution:
# Optimal Schedule Length: 130.0
# Machine 1: job_2_task_2   job_1_task_2   job_3_task_1   job_0_task_0
#            [0,48]         [48,121]       [121,197]      [197,287]
# Machine 2: job_1_task_3   job_0_task_2   job_3_task_2   job_2_task_1
#            [0,26]         [26,90]        [90,177]       [177,271]
# Machine 3: job_2_task_3   job_3_task_0   job_0_task_1   job_1_task_1
#            [0,93]         [93,136]       [136,186]      [186,278]
# Machine 4: job_0_task_3   job_3_task_3   job_2_task_0   job_1_task_0
#            [0,65]         [65,130]       [130,157]      [157,204]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 112
#   - wall time: 0.012525 s
#   - status   : OPTIMAL
#   - objective: 130
#   - User Time  : 0
# --- 0.01 seconds ---
# This is the list number: 5
# Solution:
# Optimal Schedule Length: 50.0
# Machine 1: job_3_task_3   job_2_task_2   job_0_task_0   job_1_task_0
#            [0,50]         [50,57]        [57,94]        [94,185]
# Machine 2: job_1_task_2   job_0_task_3   job_3_task_0   job_2_task_0
#            [0,1]          [1,47]         [47,83]        [83,174]
# Machine 3: job_2_task_3   job_1_task_3   job_3_task_2   job_0_task_2
#            [0,4]          [4,14]         [14,56]        [56,147]
# Machine 4: job_0_task_1   job_3_task_1   job_2_task_1   job_1_task_1
#            [0,11]         [11,41]        [41,102]       [102,178]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 0
#   - wall time: 0.013486 s
#   - status   : OPTIMAL
#   - objective: 50
#   - User Time  : 0
# --- 0.02 seconds ---
# This is the list number: 6
# Solution:
# Optimal Schedule Length: 81.0
# Machine 1: job_0_task_3   job_2_task_1   job_1_task_1   job_3_task_0
#            [0,57]         [57,65]        [65,95]        [95,161]
# Machine 2: job_0_task_2   job_1_task_2   job_2_task_0   job_3_task_2
#            [0,17]         [17,60]        [60,117]       [117,181]
# Machine 3: job_2_task_3   job_3_task_3   job_0_task_0   job_1_task_0
#            [0,19]         [19,81]        [81,90]        [90,168]
# Machine 4: job_3_task_1   job_1_task_3   job_2_task_2   job_0_task_1
#            [0,5]          [5,45]         [45,101]       [101,184]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 31
#   - wall time: 0.012888 s
#   - status   : OPTIMAL
#   - objective: 81
#   - User Time  : 0
# --- 0.02 seconds ---
# This is the list number: 7
# Solution:
# Optimal Schedule Length: 142.0
# Machine 1: job_2_task_3   job_1_task_3   job_0_task_1   job_3_task_1
#            [0,61]         [61,142]       [142,158]      [158,209]
# Machine 2: job_3_task_0   job_2_task_2   job_0_task_2   job_1_task_0
#            [0,9]          [9,34]         [34,117]       [117,207]
# Machine 3: job_0_task_3   job_1_task_1   job_3_task_2   job_2_task_0
#            [0,14]         [14,33]        [33,80]        [80,176]
# Machine 4: job_2_task_1   job_1_task_2   job_3_task_3   job_0_task_0
#            [0,4]          [4,25]         [25,117]       [117,212]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 30
#   - wall time: 0.011887 s
#   - status   : OPTIMAL
#   - objective: 142
#   - User Time  : 0
# --- 0.02 seconds ---
# This is the list number: 8
# Solution:
# Optimal Schedule Length: 82.0
# Machine 1: job_3_task_0   job_0_task_3   job_2_task_0   job_1_task_0
#            [0,11]         [11,73]        [73,136]       [136,202]
# Machine 2: job_2_task_3   job_1_task_1   job_0_task_2   job_3_task_1
#            [0,32]         [32,95]        [95,166]       [166,238]
# Machine 3: job_3_task_3   job_1_task_2   job_0_task_1   job_2_task_1
#            [0,82]         [82,103]       [103,162]      [162,257]
# Machine 4: job_1_task_3   job_2_task_2   job_0_task_0   job_3_task_2
#            [0,69]         [69,114]       [114,160]      [160,253]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 82
#   - wall time: 0.027045 s
#   - status   : OPTIMAL
#   - objective: 82
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 9
# Solution:
# Optimal Schedule Length: 113.0
# Machine 1: job_3_task_3   job_0_task_3   job_1_task_1   job_2_task_1
#            [0,16]         [16,113]       [113,149]      [149,202]
# Machine 2: job_0_task_0   job_3_task_0   job_2_task_3   job_1_task_0
#            [1,5]          [5,21]         [21,84]        [84,133]
# Machine 3: job_0_task_1   job_1_task_3   job_2_task_2   job_3_task_2
#            [0,40]         [40,92]        [92,119]       [119,211]
# Machine 4: job_0_task_2   job_3_task_1   job_2_task_0   job_1_task_2
#            [0,1]          [1,34]         [34,104]       [104,179]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 43
#   - wall time: 0.012761 s
#   - status   : OPTIMAL
#   - objective: 113
#   - User Time  : 0
# --- 0.02 seconds ---
# --- 0.20 seconds for the file---
# This is the file: tai5_5.txt
# This is the list number: 0
# Solution:
# Optimal Schedule Length: 138.0
# Machine 1: job_1_task_0   job_3_task_4   job_0_task_1   job_2_task_1   job_4_task_0
#            [0,7]          [7,61]         [61,125]       [125,199]      [199,279]
# Machine 2: job_4_task_2   job_0_task_4   job_3_task_0   job_1_task_2   job_2_task_2
#            [0,45]         [45,111]       [111,156]      [156,225]      [225,295]
# Machine 3: job_4_task_4   job_2_task_4   job_1_task_4   job_0_task_2   job_3_task_3
#            [0,10]         [10,70]        [70,138]       [138,169]      [169,267]
# Machine 4: job_2_task_0   job_1_task_1   job_4_task_1   job_3_task_1   job_0_task_0
#            [0,1]          [1,15]         [15,30]        [30,106]       [106,191]
# Machine 5: job_3_task_2   job_1_task_3   job_0_task_3   job_2_task_3   job_4_task_3
#            [0,13]         [13,31]        [31,75]        [75,165]       [165,256]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 25
#   - wall time: 0.026808 s
#   - status   : OPTIMAL
#   - objective: 138
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 1
# Solution:
# Optimal Schedule Length: 91.0
# Machine 1: job_1_task_2   job_2_task_3   job_0_task_4   job_3_task_1   job_4_task_3
#            [0,6]          [6,14]         [14,33]        [33,104]       [104,190]
# Machine 2: job_4_task_4   job_1_task_0   job_0_task_1   job_2_task_0   job_3_task_2
#            [0,15]         [15,37]        [37,75]        [75,158]       [158,245]
# Machine 3: job_2_task_2   job_3_task_4   job_4_task_0   job_1_task_3   job_0_task_3
#            [0,15]         [15,55]        [55,110]       [110,174]      [174,255]
# Machine 4: job_2_task_4   job_1_task_4   job_3_task_3   job_4_task_2   job_0_task_0
#            [0,1]          [1,91]         [91,112]       [112,167]      [167,250]
# Machine 5: job_0_task_2   job_3_task_0   job_2_task_1   job_4_task_1   job_1_task_1
#            [0,32]         [32,65]        [65,100]       [100,142]      [142,194]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 1
#   - wall time: 0.027395 s
#   - status   : OPTIMAL
#   - objective: 91
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 2
# Solution:
# Optimal Schedule Length: 51.0
# Machine 1: job_3_task_4   job_4_task_3   job_2_task_3   job_1_task_3   job_0_task_3
#            [0,39]         [39,93]        [93,158]       [158,237]      [237,317]
# Machine 2: job_0_task_4   job_2_task_4   job_4_task_1   job_1_task_2   job_3_task_0
#            [0,3]          [3,40]         [40,69]        [69,138]       [138,233]
# Machine 3: job_4_task_4   job_1_task_1   job_3_task_1   job_0_task_1   job_2_task_1
#            [0,27]         [27,78]        [78,136]       [136,201]      [201,276]
# Machine 4: job_1_task_4   job_3_task_3   job_2_task_0   job_4_task_0   job_0_task_0
#            [0,51]         [51,100]       [100,153]      [153,221]      [221,319]
# Machine 5: job_0_task_2   job_1_task_0   job_3_task_2   job_2_task_2   job_4_task_2
#            [0,9]          [9,54]         [54,130]       [130,221]      [221,314]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 0
#   - wall time: 0.012561 s
#   - status   : OPTIMAL
#   - objective: 51
#   - User Time  : 0
# --- 0.02 seconds ---
# This is the list number: 3
# Solution:
# Optimal Schedule Length: 153.0
# Machine 1: job_4_task_3   job_3_task_0   job_2_task_4   job_0_task_1   job_1_task_1
#            [0,12]         [12,37]        [37,112]       [112,178]      [178,256]
# Machine 2: job_1_task_4   job_0_task_2   job_2_task_2   job_3_task_1   job_4_task_0
#            [0,44]         [44,89]        [89,142]       [142,219]      [219,302]
# Machine 3: job_1_task_2   job_3_task_3   job_0_task_0   job_2_task_0   job_4_task_1
#            [0,36]         [36,74]        [74,138]       [138,219]      [219,300]
# Machine 4: job_0_task_4   job_4_task_2   job_1_task_0   job_3_task_2   job_2_task_3
#            [0,31]         [31,68]        [68,134]       [134,213]      [213,304]
# Machine 5: job_3_task_4   job_4_task_4   job_2_task_1   job_0_task_3   job_1_task_3
#            [0,60]         [60,153]       [153,158]      [158,193]      [193,264]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 105
#   - wall time: 0.026460 s
#   - status   : OPTIMAL
#   - objective: 153
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 4
# Solution:
# Optimal Schedule Length: 131.0
# Machine 1: job_4_task_4   job_1_task_0   job_0_task_2   job_2_task_2   job_3_task_3
#            [0,28]         [28,61]        [61,119]       [119,205]      [205,297]
# Machine 2: job_1_task_3   job_0_task_4   job_2_task_3   job_4_task_2   job_3_task_0
#            [0,48]         [48,100]       [100,159]      [159,234]      [234,319]
# Machine 3: job_3_task_4   job_1_task_4   job_2_task_4   job_0_task_0   job_4_task_0
#            [0,5]          [5,51]         [51,131]       [131,209]      [209,300]
# Machine 4: job_4_task_1   job_1_task_1   job_3_task_2   job_0_task_3   job_2_task_1
#            [0,49]         [49,101]       [101,157]      [157,217]      [217,280]
# Machine 5: job_3_task_1   job_2_task_0   job_0_task_1   job_4_task_3   job_1_task_2
#            [0,2]          [2,33]         [33,106]       [106,184]      [184,276]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 37
#   - wall time: 0.010256 s
#   - status   : OPTIMAL
#   - objective: 131
#   - User Time  : 0
# --- 0.01 seconds ---
# This is the list number: 5
# Solution:
# Optimal Schedule Length: 167.0
# Machine 1: job_2_task_3   job_4_task_1   job_3_task_2   job_0_task_2   job_1_task_3
#            [0,17]         [17,54]        [54,115]       [115,208]      [208,304]
# Machine 2: job_0_task_1   job_3_task_0   job_4_task_3   job_2_task_1   job_1_task_2
#            [0,41]         [41,96]        [96,152]       [152,214]      [214,277]
# Machine 3: job_3_task_4   job_2_task_2   job_4_task_4   job_0_task_3   job_1_task_0
#            [0,26]         [26,72]        [72,154]       [154,214]      [214,295]
# Machine 4: job_2_task_4   job_0_task_4   job_1_task_1   job_4_task_2   job_3_task_1
#            [0,81]         [81,167]       [167,173]      [173,207]      [207,292]
# Machine 5: job_1_task_4   job_0_task_0   job_2_task_0   job_3_task_3   job_4_task_0
#            [0,4]          [4,9]          [9,59]         [59,137]       [137,235]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 52
#   - wall time: 0.026779 s
#   - status   : OPTIMAL
#   - objective: 167
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 6
# Solution:
# Optimal Schedule Length: 89.0
# Machine 1: job_3_task_3   job_2_task_3   job_0_task_3   job_1_task_3   job_4_task_2
#            [0,14]         [14,61]        [61,126]       [126,197]      [197,286]
# Machine 2: job_4_task_4   job_1_task_4   job_0_task_4   job_2_task_2   job_3_task_0
#            [0,7]          [7,38]         [38,89]        [89,167]       [167,264]
# Machine 3: job_3_task_2   job_1_task_0   job_0_task_2   job_2_task_0   job_4_task_0
#            [0,48]         [48,97]        [97,159]       [159,222]      [222,298]
# Machine 4: job_2_task_4   job_3_task_4   job_0_task_0   job_4_task_1   job_1_task_2
#            [0,2]          [2,44]         [44,109]       [109,189]      [189,274]
# Machine 5: job_4_task_3   job_0_task_1   job_1_task_1   job_2_task_1   job_3_task_1
#            [0,9]          [9,25]         [25,83]        [83,145]       [145,240]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 0
#   - wall time: 0.023928 s
#   - status   : OPTIMAL
#   - objective: 89
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 7
# Solution:
# Optimal Schedule Length: 80.0
# Machine 1: job_2_task_3   job_0_task_2   job_1_task_1   job_3_task_2   job_4_task_0
#            [0,18]         [18,64]        [64,116]       [116,168]      [168,263]
# Machine 2: job_4_task_4   job_1_task_2   job_0_task_3   job_3_task_3   job_2_task_0
#            [0,22]         [22,86]        [86,152]       [152,221]      [221,291]
# Machine 3: job_3_task_4   job_0_task_1   job_1_task_3   job_4_task_1   job_2_task_2
#            [0,80]         [80,110]       [110,148]      [148,202]      [202,281]
# Machine 4: job_4_task_3   job_0_task_4   job_2_task_4   job_3_task_1   job_1_task_0
#            [0,4]          [4,33]         [33,62]        [62,121]       [121,203]
# Machine 5: job_3_task_0   job_1_task_4   job_4_task_2   job_0_task_0   job_2_task_1
#            [0,14]         [14,70]        [70,107]       [107,196]      [196,288]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 66
#   - wall time: 0.024509 s
#   - status   : OPTIMAL
#   - objective: 80
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 8
# Solution:
# Optimal Schedule Length: 128.0
# Machine 1: job_4_task_1   job_0_task_0   job_1_task_4   job_2_task_2   job_3_task_0
#            [0,16]         [16,38]        [38,111]       [111,188]      [188,284]
# Machine 2: job_0_task_4   job_4_task_4   job_2_task_0   job_3_task_2   job_1_task_1
#            [0,35]         [35,128]       [128,166]      [166,238]      [238,331]
# Machine 3: job_2_task_1   job_3_task_1   job_0_task_2   job_1_task_3   job_4_task_3
#            [0,34]         [34,89]        [89,172]       [172,256]      [256,345]
# Machine 4: job_1_task_2   job_0_task_3   job_3_task_4   job_4_task_0   job_2_task_3
#            [0,23]         [23,61]        [61,128]       [128,177]      [177,271]
# Machine 5: job_2_task_4   job_3_task_3   job_1_task_0   job_0_task_1   job_4_task_2
#            [0,41]         [41,100]       [100,168]      [168,258]      [258,348]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 73
#   - wall time: 0.024143 s
#   - status   : OPTIMAL
#   - objective: 128
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 9
# Solution:
# Optimal Schedule Length: 99.0
# Machine 1: job_4_task_4   job_1_task_3   job_2_task_2   job_3_task_3   job_0_task_0
#            [0,91]         [91,105]       [105,164]      [164,231]      [231,321]
# Machine 2: job_1_task_4   job_0_task_3   job_3_task_0   job_4_task_0   job_2_task_0
#            [0,56]         [56,92]        [92,141]       [141,215]      [215,312]
# Machine 3: job_2_task_1   job_3_task_4   job_4_task_2   job_0_task_2   job_1_task_1
#            [0,45]         [45,95]        [95,120]       [120,207]      [207,300]
# Machine 4: job_0_task_1   job_2_task_3   job_4_task_3   job_3_task_1   job_1_task_0
#            [0,17]         [17,61]        [61,137]       [137,218]      [218,317]
# Machine 5: job_2_task_4   job_0_task_4   job_4_task_1   job_3_task_2   job_1_task_2
#            [0,40]         [40,99]        [99,152]       [152,182]      [182,214]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 202
#   - wall time: 0.013142 s
#   - status   : OPTIMAL
#   - objective: 99
#   - User Time  : 0
# --- 0.02 seconds ---
# --- 0.27 seconds for the file---
# This is the file: tai7_7.txt
# This is the list number: 0
# Solution:
# Optimal Schedule Length: 133.0
# Machine 1: job_5_task_3   job_4_task_4   job_6_task_6   job_2_task_0   job_0_task_4   job_3_task_2   job_1_task_4
#            [0,11]         [11,63]        [63,115]       [115,181]      [181,252]      [252,330]      [330,421]
# Machine 2: job_4_task_5   job_1_task_0   job_5_task_2   job_0_task_1   job_3_task_0   job_6_task_0   job_2_task_1
#            [0,9]          [9,28]         [28,65]        [65,104]       [104,152]      [152,235]      [235,330]
# Machine 3: job_1_task_1   job_3_task_4   job_5_task_5   job_6_task_5   job_0_task_0   job_4_task_2   job_2_task_4
#            [0,13]         [13,32]        [32,62]        [62,150]       [150,239]      [239,330]      [330,426]
# Machine 4: job_5_task_4   job_2_task_5   job_4_task_1   job_6_task_1   job_0_task_2   job_3_task_5   job_1_task_5
#            [0,2]          [2,20]         [20,48]        [48,93]        [93,147]       [147,215]      [215,288]
# Machine 5: job_2_task_6   job_0_task_6   job_3_task_6   job_6_task_2   job_1_task_3   job_4_task_3   job_5_task_1
#            [0,14]         [14,70]        [70,133]       [133,170]      [170,216]      [216,291]      [291,389]
# Machine 6: job_5_task_6   job_3_task_1   job_2_task_2   job_6_task_4   job_4_task_0   job_1_task_2   job_0_task_5
#            [0,38]         [38,84]        [84,132]       [132,184]      [184,244]      [244,325]      [325,417]
# Machine 7: job_4_task_6   job_2_task_3   job_1_task_6   job_5_task_0   job_0_task_3   job_6_task_3   job_3_task_3
#            [0,7]          [7,31]         [31,58]        [58,91]        [91,125]       [125,202]      [202,296]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 50
#   - wall time: 0.025910 s
#   - status   : OPTIMAL
#   - objective: 133
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 1
# Solution:
# Optimal Schedule Length: 92.0
# Machine 1: job_2_task_6   job_3_task_3   job_0_task_6   job_6_task_2   job_4_task_4   job_1_task_0   job_5_task_3
#            [0,9]          [9,13]         [13,89]        [89,153]       [153,246]      [246,343]      [343,440]
# Machine 2: job_3_task_1   job_2_task_1   job_0_task_5   job_4_task_6   job_1_task_5   job_6_task_3   job_5_task_4
#            [0,3]          [3,10]         [10,19]        [19,36]        [36,120]       [120,210]      [210,306]
# Machine 3: job_3_task_4   job_5_task_5   job_4_task_3   job_2_task_2   job_0_task_3   job_1_task_4   job_6_task_5
#            [0,15]         [15,48]        [48,83]        [83,160]       [160,242]      [242,339]      [339,436]
# Machine 4: job_1_task_2   job_5_task_6   job_6_task_4   job_2_task_0   job_4_task_5   job_3_task_0   job_0_task_0
#            [0,20]         [20,76]        [76,137]       [137,199]      [199,271]      [271,354]      [354,443]
# Machine 5: job_1_task_6   job_0_task_2   job_3_task_2   job_6_task_0   job_4_task_2   job_5_task_2   job_2_task_5
#            [0,92]         [92,96]        [96,183]       [183,205]      [205,238]      [238,296]      [296,371]
# Machine 6: job_6_task_6   job_1_task_1   job_3_task_5   job_5_task_1   job_4_task_1   job_2_task_4   job_0_task_4
#            [0,9]          [9,19]         [19,30]        [30,70]        [70,126]       [126,204]      [204,290]
# Machine 7: job_3_task_6   job_1_task_3   job_5_task_0   job_2_task_3   job_0_task_1   job_6_task_1   job_4_task_0
#            [0,22]         [22,55]        [55,103]       [103,160]      [160,225]      [225,294]      [294,378]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 244
#   - wall time: 0.021921 s
#   - status   : OPTIMAL
#   - objective: 92
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 2
# Solution:
# Optimal Schedule Length: 195.0
# Machine 1: job_6_task_5   job_4_task_2   job_3_task_4   job_5_task_2   job_2_task_5   job_0_task_4   job_1_task_4
#            [0,19]         [19,59]        [59,105]       [105,151]      [151,222]      [222,298]      [298,382]
# Machine 2: job_4_task_3   job_2_task_6   job_6_task_2   job_0_task_0   job_5_task_5   job_1_task_2   job_3_task_3
#            [0,94]         [94,191]       [191,216]      [216,311]      [311,356]      [356,406]      [406,468]
# Machine 3: job_5_task_6   job_6_task_6   job_4_task_6   job_2_task_4   job_3_task_5   job_1_task_3   job_0_task_5
#            [0,47]         [47,116]       [116,195]      [195,212]      [212,284]      [284,364]      [364,457]
# Machine 4: job_3_task_6   job_5_task_3   job_0_task_6   job_6_task_3   job_1_task_1   job_4_task_0   job_2_task_0
#            [0,22]         [22,48]        [48,77]        [77,126]       [126,194]      [194,274]      [274,360]
# Machine 5: job_4_task_4   job_1_task_5   job_5_task_0   job_2_task_2   job_0_task_3   job_6_task_4   job_3_task_2
#            [0,15]         [15,59]        [59,103]       [103,153]      [153,235]      [235,318]      [318,412]
# Machine 6: job_4_task_1   job_1_task_0   job_6_task_1   job_2_task_1   job_5_task_4   job_0_task_1   job_3_task_0
#            [0,27]         [27,79]        [79,132]       [132,190]      [190,259]      [259,337]      [337,435]
# Machine 7: job_0_task_2   job_3_task_1   job_1_task_6   job_2_task_3   job_5_task_1   job_4_task_5   job_6_task_0
#            [0,5]          [5,62]         [62,124]       [124,191]      [191,265]      [265,352]      [352,444]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 342
#   - wall time: 0.025450 s
#   - status   : OPTIMAL
#   - objective: 195
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 3
# Solution:
# Optimal Schedule Length: 120.0
# Machine 1: job_5_task_0   job_3_task_0   job_1_task_5   job_0_task_4   job_2_task_1   job_6_task_0   job_4_task_5
#            [0,4]          [4,40]         [40,83]        [83,133]       [133,210]      [210,287]      [287,385]
# Machine 2: job_5_task_6   job_3_task_6   job_2_task_3   job_6_task_4   job_0_task_2   job_1_task_3   job_4_task_3
#            [0,32]         [32,114]       [114,170]      [170,200]      [200,241]      [241,289]      [289,367]
# Machine 3: job_1_task_2   job_6_task_2   job_2_task_6   job_5_task_2   job_3_task_3   job_0_task_1   job_4_task_1
#            [0,21]         [21,58]        [58,120]       [120,126]      [126,191]      [191,260]      [260,337]
# Machine 4: job_4_task_6   job_6_task_3   job_5_task_3   job_3_task_4   job_0_task_5   job_2_task_4   job_1_task_4
#            [0,27]         [27,81]        [81,137]       [137,205]      [205,279]      [279,357]      [357,454]
# Machine 5: job_1_task_6   job_6_task_6   job_3_task_5   job_2_task_5   job_5_task_4   job_4_task_2   job_0_task_0
#            [0,47]         [47,120]       [120,129]      [129,179]      [179,216]      [216,264]      [264,350]
# Machine 6: job_0_task_6   job_3_task_2   job_5_task_5   job_1_task_0   job_4_task_4   job_2_task_0   job_6_task_5
#            [0,48]         [48,98]        [98,148]       [148,209]      [209,279]      [279,361]      [361,443]
# Machine 7: job_2_task_2   job_4_task_0   job_1_task_1   job_6_task_1   job_5_task_1   job_3_task_1   job_0_task_3
#            [0,18]         [18,64]        [64,114]       [114,189]      [189,275]      [275,362]      [362,457]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 417
#   - wall time: 0.026214 s
#   - status   : OPTIMAL
#   - objective: 120
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 4
# Solution:
# Optimal Schedule Length: 137.0
# Machine 1: job_1_task_5   job_4_task_1   job_3_task_0   job_2_task_1   job_5_task_0   job_6_task_5   job_0_task_1
#            [0,20]         [20,47]        [47,96]        [96,149]       [149,215]      [215,288]      [288,378]
# Machine 2: job_1_task_2   job_6_task_2   job_4_task_3   job_3_task_5   job_0_task_3   job_5_task_4   job_2_task_5
#            [0,7]          [7,15]         [15,48]        [48,96]        [96,158]       [158,228]      [228,327]
# Machine 3: job_0_task_2   job_4_task_0   job_3_task_1   job_5_task_3   job_1_task_0   job_6_task_1   job_2_task_4
#            [0,19]         [19,61]        [61,123]       [123,185]      [185,250]      [250,321]      [321,416]
# Machine 4: job_0_task_4   job_3_task_6   job_6_task_4   job_2_task_2   job_5_task_1   job_1_task_1   job_4_task_2
#            [0,26]         [26,103]       [103,154]      [154,210]      [210,266]      [266,325]      [325,398]
# Machine 5: job_3_task_2   job_2_task_6   job_0_task_6   job_4_task_5   job_6_task_0   job_1_task_4   job_5_task_2
#            [0,12]         [12,57]        [57,137]       [137,175]      [175,230]      [230,304]      [304,380]
# Machine 6: job_2_task_3   job_0_task_5   job_4_task_6   job_3_task_3   job_5_task_5   job_6_task_3   job_1_task_3
#            [0,7]          [7,30]         [30,125]       [125,154]      [154,190]      [190,229]      [229,320]
# Machine 7: job_6_task_6   job_5_task_6   job_1_task_6   job_2_task_0   job_3_task_4   job_4_task_4   job_0_task_0
#            [0,36]         [36,75]        [75,137]       [137,141]      [141,147]      [147,228]      [228,314]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 569
#   - wall time: 0.039366 s
#   - status   : OPTIMAL
#   - objective: 137
#   - User Time  : 0
# --- 0.05 seconds ---
# This is the list number: 5
# Solution:
# Optimal Schedule Length: 97.0
# Machine 1: job_3_task_6   job_4_task_0   job_1_task_5   job_5_task_5   job_2_task_1   job_6_task_5   job_0_task_1
#            [0,94]         [94,100]       [100,132]      [132,178]      [178,253]      [253,328]      [328,415]
# Machine 2: job_2_task_6   job_3_task_1   job_4_task_5   job_1_task_2   job_5_task_4   job_0_task_0   job_6_task_4
#            [0,61]         [61,100]       [100,146]      [146,205]      [205,269]      [269,345]      [345,438]
# Machine 3: job_2_task_3   job_4_task_4   job_6_task_3   job_3_task_5   job_1_task_0   job_5_task_1   job_0_task_2
#            [0,1]          [1,9]          [9,45]         [45,106]       [106,184]      [184,264]      [264,359]
# Machine 4: job_0_task_6   job_6_task_6   job_3_task_4   job_5_task_3   job_2_task_0   job_4_task_2   job_1_task_4
#            [0,2]          [2,97]         [97,122]       [122,182]      [182,245]      [245,322]      [322,417]
# Machine 5: job_4_task_6   job_0_task_4   job_1_task_1   job_5_task_0   job_6_task_0   job_2_task_2   job_3_task_2
#            [0,24]         [24,79]        [79,136]       [136,196]      [196,272]      [272,359]      [359,448]
# Machine 6: job_5_task_6   job_0_task_3   job_1_task_6   job_6_task_2   job_3_task_3   job_2_task_5   job_4_task_3
#            [0,5]          [5,25]         [25,94]        [94,121]       [121,162]      [162,238]      [238,329]
# Machine 7: job_2_task_4   job_1_task_3   job_6_task_1   job_4_task_1   job_3_task_0   job_0_task_5   job_5_task_2
#            [0,25]         [25,65]        [65,114]       [114,173]      [173,239]      [239,327]      [327,424]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 659
#   - wall time: 0.038988 s
#   - status   : OPTIMAL
#   - objective: 97
#   - User Time  : 0
# --- 0.04 seconds ---
# This is the list number: 6
# Solution:
# Optimal Schedule Length: 192.0
# Machine 1: job_0_task_2   job_2_task_6   job_4_task_3   job_1_task_4   job_5_task_2   job_6_task_0   job_3_task_4
#            [0,5]          [5,11]         [11,21]        [21,67]        [67,136]       [136,231]      [231,328]
# Machine 2: job_3_task_6   job_4_task_6   job_0_task_1   job_1_task_5   job_6_task_5   job_5_task_3   job_2_task_2
#            [0,93]         [93,192]       [192,201]      [201,231]      [231,265]      [265,328]      [328,409]
# Machine 3: job_5_task_5   job_6_task_3   job_4_task_1   job_3_task_3   job_1_task_1   job_2_task_5   job_0_task_5
#            [0,10]         [10,57]        [57,116]       [116,177]      [177,246]      [246,328]      [328,422]
# Machine 4: job_5_task_1   job_6_task_2   job_1_task_6   job_4_task_0   job_2_task_3   job_3_task_5   job_0_task_3
#            [0,32]         [32,80]        [80,138]       [138,194]      [194,254]      [254,320]      [320,418]
# Machine 5: job_3_task_2   job_4_task_2   job_1_task_0   job_2_task_1   job_5_task_4   job_0_task_4   job_6_task_1
#            [0,10]         [10,29]        [29,88]        [88,152]       [152,223]      [223,299]      [299,386]
# Machine 6: job_1_task_2   job_3_task_1   job_6_task_4   job_5_task_6   job_0_task_0   job_4_task_4   job_2_task_4
#            [0,25]         [25,53]        [53,99]        [99,179]       [179,245]      [245,317]      [317,401]
# Machine 7: job_2_task_0   job_0_task_6   job_3_task_0   job_6_task_6   job_1_task_3   job_5_task_0   job_4_task_5
#            [0,15]         [15,40]        [40,68]        [68,99]        [99,155]       [155,231]      [231,309]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 402
#   - wall time: 0.027206 s
#   - status   : OPTIMAL
#   - objective: 192
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 7
# Solution:
# Optimal Schedule Length: 141.0
# Machine 1: job_2_task_3   job_6_task_5   job_3_task_1   job_4_task_3   job_1_task_4   job_0_task_5   job_5_task_5
#            [0,5]          [5,28]         [28,66]        [66,118]       [118,172]      [172,269]      [269,367]
# Machine 2: job_5_task_2   job_0_task_1   job_1_task_3   job_2_task_2   job_6_task_0   job_4_task_1   job_3_task_3
#            [0,17]         [17,37]        [37,79]        [79,129]       [129,187]      [187,248]      [248,344]
# Machine 3: job_2_task_6   job_5_task_4   job_0_task_0   job_6_task_6   job_1_task_0   job_3_task_2   job_4_task_2
#            [0,11]         [11,29]        [29,48]        [48,110]       [110,147]      [147,215]      [215,287]
# Machine 4: job_5_task_6   job_4_task_4   job_3_task_0   job_1_task_6   job_0_task_3   job_2_task_0   job_6_task_1
#            [0,6]          [6,23]         [23,56]        [56,117]       [117,153]      [153,205]      [205,289]
# Machine 5: job_4_task_6   job_0_task_6   job_5_task_0   job_1_task_2   job_2_task_4   job_3_task_4   job_6_task_4
#            [0,58]         [58,141]       [141,143]      [143,191]      [191,248]      [248,327]      [327,408]
# Machine 6: job_2_task_1   job_5_task_1   job_6_task_3   job_1_task_5   job_4_task_5   job_3_task_5   job_0_task_4
#            [0,1]          [1,22]         [22,48]        [48,128]       [128,209]      [209,292]      [292,384]
# Machine 7: job_0_task_2   job_3_task_6   job_4_task_0   job_1_task_1   job_6_task_2   job_5_task_3   job_2_task_5
#            [0,14]         [14,41]        [41,95]        [95,150]       [150,230]      [230,323]      [323,420]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 413
#   - wall time: 0.023293 s
#   - status   : OPTIMAL
#   - objective: 141
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 8
# Solution:
# Optimal Schedule Length: 92.0
# Machine 1: job_1_task_2   job_0_task_6   job_2_task_0   job_4_task_1   job_5_task_5   job_3_task_3   job_6_task_5
#            [0,13]         [13,45]        [45,91]        [91,142]       [142,231]      [231,321]      [321,414]
# Machine 2: job_4_task_0   job_5_task_6   job_6_task_4   job_3_task_4   job_0_task_3   job_1_task_0   job_2_task_2
#            [0,37]         [37,84]        [84,115]       [115,165]      [165,232]      [232,304]      [304,398]
# Machine 3: job_3_task_6   job_0_task_4   job_2_task_1   job_6_task_3   job_1_task_4   job_5_task_0   job_4_task_5
#            [0,92]         [92,124]       [124,147]      [147,233]      [233,268]      [268,333]      [333,419]
# Machine 4: job_0_task_2   job_2_task_5   job_5_task_4   job_6_task_2   job_1_task_5   job_4_task_2   job_3_task_0
#            [0,43]         [43,87]        [87,149]       [149,213]      [213,279]      [279,354]      [354,449]
# Machine 5: job_4_task_6   job_2_task_6   job_1_task_3   job_6_task_1   job_5_task_2   job_3_task_2   job_0_task_1
#            [0,13]         [13,28]        [28,69]        [69,131]       [131,194]      [194,263]      [263,334]
# Machine 6: job_3_task_5   job_1_task_6   job_6_task_0   job_0_task_5   job_2_task_4   job_5_task_3   job_4_task_4
#            [0,42]         [42,89]        [89,106]       [106,178]      [178,251]      [251,333]      [333,426]
# Machine 7: job_6_task_6   job_2_task_3   job_0_task_0   job_3_task_1   job_5_task_1   job_4_task_3   job_1_task_1
#            [0,92]         [92,98]        [98,129]       [129,149]      [149,176]      [176,244]      [244,304]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 630
#   - wall time: 0.025067 s
#   - status   : OPTIMAL
#   - objective: 92
#   - User Time  : 0
# --- 0.03 seconds ---
# This is the list number: 9
# Solution:
# Optimal Schedule Length: 148.0
# Machine 1: job_2_task_0   job_6_task_5   job_0_task_6   job_1_task_4   job_5_task_1   job_4_task_3   job_3_task_4
#            [1,19]         [19,76]        [76,138]       [138,159]      [159,189]      [189,281]      [281,329]
# Machine 2: job_3_task_5   job_6_task_1   job_1_task_6   job_0_task_5   job_4_task_4   job_5_task_2   job_2_task_5
#            [0,1]          [1,22]         [22,112]       [112,154]      [154,215]      [215,285]      [285,360]
# Machine 3: job_4_task_0   job_1_task_0   job_2_task_6   job_0_task_0   job_6_task_4   job_3_task_3   job_5_task_3
#            [1,47]         [47,51]        [51,137]       [137,156]      [156,221]      [221,316]      [316,399]
# Machine 4: job_4_task_6   job_6_task_6   job_2_task_4   job_3_task_2   job_0_task_2   job_1_task_3   job_5_task_4
#            [0,64]         [64,148]       [148,152]      [152,190]      [190,241]      [241,302]      [302,363]
# Machine 5: job_4_task_1   job_6_task_0   job_5_task_0   job_3_task_1   job_2_task_3   job_1_task_5   job_0_task_1
#            [0,6]          [6,27]         [27,67]        [67,124]       [124,202]      [202,294]      [294,388]
# Machine 6: job_5_task_5   job_3_task_6   job_2_task_2   job_4_task_5   job_1_task_1   job_0_task_3   job_6_task_2
#            [0,5]          [5,32]         [32,67]        [67,121]       [121,182]      [182,268]      [268,357]
# Machine 7: job_4_task_2   job_0_task_4   job_1_task_2   job_3_task_0   job_5_task_6   job_6_task_3   job_2_task_1
#            [0,50]         [50,53]        [53,66]        [66,84]        [84,137]       [137,186]      [186,250]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 916
#   - wall time: 0.039278 s
#   - status   : OPTIMAL
#   - objective: 148
#   - User Time  : 0
# --- 0.05 seconds ---
# --- 0.36 seconds for the file---
# This is the file: tai10_10.txt
# This is the list number: 0
# Solution:
# Optimal Schedule Length: 155.0
# Machine 1: job_5_task_3   job_2_task_3   job_3_task_2   job_1_task_9   job_9_task_7   job_8_task_4   job_0_task_0   job_7_task_7   job_6_task_2   job_4_task_0
#            [0,11]         [11,35]        [35,66]        [66,152]       [152,183]      [183,221]      [221,269]      [269,318]      [318,371]      [371,427]
# Machine 2: job_0_task_3   job_8_task_7   job_1_task_6   job_4_task_5   job_6_task_8   job_9_task_1   job_7_task_6   job_2_task_2   job_3_task_1   job_5_task_5
#            [0,2]          [2,30]         [30,59]        [59,88]        [88,132]       [132,182]      [182,268]      [268,355]      [355,444]      [444,541]
# Machine 3: job_8_task_8   job_9_task_3   job_6_task_5   job_7_task_4   job_3_task_8   job_5_task_1   job_2_task_4   job_4_task_2   job_0_task_1   job_1_task_3
#            [0,39]         [39,80]        [80,124]       [124,179]      [179,241]      [241,303]      [303,373]      [373,445]      [445,541]      [541,637]
# Machine 4: job_2_task_5   job_1_task_8   job_4_task_6   job_5_task_9   job_0_task_5   job_3_task_6   job_9_task_8   job_6_task_0   job_7_task_2   job_8_task_6
#            [0,6]          [6,22]         [22,42]        [42,88]        [88,155]       [155,222]      [222,306]      [306,399]      [399,492]      [492,589]
# Machine 5: job_3_task_4   job_6_task_9   job_0_task_9   job_4_task_1   job_8_task_2   job_1_task_1   job_2_task_7   job_7_task_8   job_9_task_5   job_5_task_6
#            [0,37]         [37,77]        [77,145]       [145,191]      [191,244]      [244,304]      [304,369]      [369,449]      [449,531]      [531,614]
# Machine 6: job_3_task_9   job_2_task_9   job_4_task_8   job_7_task_5   job_6_task_6   job_0_task_4   job_5_task_0   job_1_task_7   job_9_task_6   job_8_task_0
#            [0,69]         [69,155]       [155,167]      [167,196]      [196,229]      [229,276]      [276,331]      [331,388]      [388,471]      [471,565]
# Machine 7: job_1_task_5   job_8_task_1   job_6_task_7   job_4_task_9   job_0_task_6   job_3_task_3   job_5_task_7   job_9_task_2   job_2_task_0   job_7_task_3
#            [0,22]         [22,60]        [60,102]       [102,154]      [154,206]      [206,272]      [272,339]      [339,412]      [412,508]      [508,605]
# Machine 8: job_1_task_4   job_8_task_9   job_9_task_0   job_7_task_9   job_5_task_2   job_4_task_7   job_2_task_6   job_0_task_8   job_6_task_3   job_3_task_5
#            [0,12]         [12,30]        [30,64]        [64,131]       [131,168]      [168,214]      [214,278]      [278,361]      [361,446]      [446,537]
# Machine 9: job_7_task_0   job_8_task_5   job_4_task_4   job_2_task_1   job_9_task_9   job_0_task_7   job_3_task_7   job_5_task_4   job_1_task_0   job_6_task_4
#            [0,3]          [3,9]          [9,17]         [17,55]        [55,150]       [150,219]      [219,290]      [290,376]      [376,468]      [468,563]
# Machine 10: job_4_task_3   job_3_task_0   job_7_task_1   job_6_task_1   job_1_task_2   job_9_task_4   job_0_task_2   job_5_task_8   job_8_task_3   job_2_task_8
#            [0,12]         [12,29]        [29,47]        [47,72]        [72,98]        [98,132]       [132,183]      [183,243]      [243,315]      [315,405]
#
#
# Statistics
#   - conflicts: 3
#   - branches : 2646
#   - wall time: 0.080889 s
#   - status   : OPTIMAL
#   - objective: 155
#   - User Time  : 0
# --- 0.09 seconds ---
# This is the list number: 1
# Solution:
# Optimal Schedule Length: 117.0
# Machine 1: job_8_task_9   job_2_task_5   job_5_task_1   job_9_task_8   job_6_task_7   job_4_task_6   job_3_task_4   job_0_task_5   job_1_task_4   job_7_task_7
#            [0,16]         [16,59]        [59,104]       [104,150]      [150,201]      [201,268]      [268,343]      [343,420]      [420,501]      [501,588]
# Machine 2: job_3_task_9   job_2_task_9   job_1_task_9   job_4_task_3   job_0_task_7   job_7_task_1   job_9_task_7   job_5_task_4   job_6_task_0   job_8_task_1
#            [0,2]          [2,53]         [53,117]       [117,131]      [131,161]      [161,229]      [229,302]      [302,378]      [378,462]      [462,512]
# Machine 3: job_8_task_3   job_0_task_9   job_1_task_6   job_3_task_3   job_5_task_8   job_9_task_4   job_6_task_4   job_7_task_2   job_2_task_6   job_4_task_5
#            [0,2]          [2,99]         [99,111]       [111,177]      [177,236]      [236,254]      [254,287]      [287,320]      [320,373]      [373,431]
# Machine 4: job_9_task_9   job_3_task_7   job_7_task_9   job_6_task_2   job_8_task_5   job_0_task_2   job_2_task_4   job_4_task_8   job_1_task_3   job_5_task_6
#            [0,61]         [61,74]        [74,84]        [84,112]       [112,166]      [166,202]      [202,248]      [248,313]      [313,401]      [401,452]
# Machine 5: job_5_task_9   job_8_task_4   job_4_task_9   job_2_task_7   job_9_task_1   job_1_task_2   job_7_task_3   job_6_task_3   job_3_task_2   job_0_task_1
#            [0,32]         [32,36]        [36,91]        [91,140]       [140,159]      [159,204]      [204,286]      [286,375]      [375,468]      [468,565]
# Machine 6: job_5_task_7   job_6_task_6   job_8_task_0   job_1_task_1   job_2_task_3   job_0_task_4   job_9_task_5   job_3_task_6   job_7_task_0   job_4_task_2
#            [0,4]          [4,10]         [10,27]        [27,53]        [53,84]        [84,120]       [120,175]      [175,246]      [246,332]      [332,420]
# Machine 7: job_6_task_5   job_8_task_7   job_3_task_8   job_9_task_0   job_5_task_2   job_0_task_8   job_2_task_0   job_4_task_0   job_7_task_4   job_1_task_0
#            [0,10]         [10,28]        [28,49]        [49,78]        [78,114]       [114,165]      [165,238]      [238,329]      [329,420]      [420,518]
# Machine 8: job_1_task_5   job_3_task_0   job_4_task_1   job_8_task_2   job_5_task_0   job_2_task_8   job_6_task_1   job_7_task_5   job_9_task_3   job_0_task_0
#            [0,3]          [3,7]          [7,22]         [22,45]        [45,83]        [83,122]       [122,198]      [198,285]      [285,373]      [373,468]
# Machine 9: job_2_task_2   job_6_task_9   job_1_task_7   job_0_task_3   job_7_task_6   job_8_task_8   job_4_task_7   job_5_task_5   job_9_task_6   job_3_task_1
#            [0,9]          [9,102]        [102,192]      [192,210]      [210,233]      [233,316]      [316,345]      [345,391]      [391,444]      [444,501]
# Machine 10: job_6_task_8   job_1_task_8   job_7_task_8   job_9_task_2   job_4_task_4   job_0_task_6   job_8_task_6   job_2_task_1   job_3_task_5   job_5_task_3
#            [0,3]          [3,9]          [9,23]         [23,37]        [37,59]        [59,109]       [109,168]      [168,255]      [255,350]      [350,446]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 2183
#   - wall time: 0.054486 s
#   - status   : OPTIMAL
#   - objective: 117
#   - User Time  : 0
# --- 0.06 seconds ---
# This is the list number: 2
# Solution:
# Optimal Schedule Length: 110.0
# Machine 1: job_0_task_9   job_8_task_9   job_9_task_9   job_4_task_6   job_6_task_6   job_7_task_6   job_2_task_5   job_1_task_3   job_3_task_3   job_5_task_3
#            [0,9]          [9,33]         [33,110]       [110,118]      [118,139]      [139,177]      [177,222]      [222,304]      [304,390]      [390,487]
# Machine 2: job_9_task_7   job_7_task_1   job_3_task_9   job_8_task_0   job_4_task_3   job_6_task_7   job_2_task_8   job_0_task_4   job_5_task_0   job_1_task_5
#            [0,4]          [4,29]         [29,88]        [88,120]       [120,155]      [155,191]      [191,235]      [235,293]      [293,356]      [356,428]
# Machine 3: job_3_task_8   job_1_task_4   job_5_task_9   job_4_task_1   job_6_task_8   job_2_task_0   job_8_task_3   job_7_task_7   job_0_task_5   job_9_task_1
#            [0,1]          [1,5]          [5,21]         [21,62]        [62,108]       [108,156]      [156,222]      [222,290]      [290,365]      [365,458]
# Machine 4: job_9_task_2   job_2_task_2   job_4_task_9   job_0_task_1   job_8_task_4   job_6_task_2   job_1_task_2   job_3_task_4   job_5_task_1   job_7_task_8
#            [0,2]          [2,6]          [6,22]         [22,45]        [45,114]       [114,184]      [184,265]      [265,348]      [348,439]      [439,531]
# Machine 5: job_4_task_5   job_1_task_9   job_7_task_4   job_5_task_6   job_6_task_5   job_2_task_1   job_8_task_1   job_3_task_5   job_9_task_8   job_0_task_2
#            [0,18]         [18,94]        [94,119]       [119,164]      [164,211]      [211,263]      [263,315]      [315,387]      [387,472]      [472,563]
# Machine 6: job_7_task_9   job_6_task_0   job_5_task_5   job_9_task_0   job_8_task_5   job_3_task_6   job_0_task_3   job_1_task_0   job_4_task_8   job_2_task_3
#            [0,10]         [10,23]        [23,48]        [48,93]        [93,139]       [139,188]      [188,251]      [251,324]      [324,414]      [414,513]
# Machine 7: job_6_task_1   job_4_task_7   job_2_task_9   job_1_task_8   job_3_task_0   job_9_task_6   job_8_task_7   job_7_task_2   job_5_task_4   job_0_task_6
#            [0,15]         [15,31]        [31,54]        [54,93]        [93,155]       [155,220]      [220,294]      [294,374]      [374,461]      [461,560]
# Machine 8: job_1_task_6   job_6_task_9   job_0_task_0   job_9_task_3   job_2_task_6   job_7_task_5   job_8_task_6   job_5_task_2   job_4_task_2   job_3_task_1
#            [0,20]         [20,53]        [53,90]        [90,129]       [129,178]      [178,234]      [234,296]      [296,375]      [375,461]      [461,552]
# Machine 9: job_6_task_4   job_3_task_2   job_0_task_8   job_7_task_0   job_2_task_7   job_9_task_4   job_4_task_0   job_8_task_8   job_5_task_8   job_1_task_7
#            [0,6]          [6,21]         [21,49]        [49,81]        [81,117]       [117,160]      [160,206]      [206,256]      [256,327]      [327,400]
# Machine 10: job_5_task_7   job_8_task_2   job_6_task_3   job_1_task_1   job_2_task_4   job_4_task_4   job_9_task_5   job_0_task_7   job_7_task_3   job_3_task_7
# ...
#            [0,2]          [2,8]          [8,18]         [18,32]        [32,57]        [57,85]        [85,114]       [114,145]      [145,183]      [183,235]      [235,289]      [289,348]      [348,413]      [413,484]      [484,557]      [557,635]      [635,714]      [714,803]      [803,900]      [900,999]
# Machine 17: job_13_task_8  job_6_task_4   job_7_task_16  job_15_task_4  job_11_task_15 job_2_task_9   job_8_task_11  job_1_task_14  job_10_task_9  job_0_task_12  job_4_task_0   job_3_task_17  job_5_task_14  job_16_task_1  job_14_task_12 job_19_task_17 job_12_task_17 job_18_task_17 job_17_task_16 job_9_task_13
#            [0,7]          [7,22]         [22,40]        [40,58]        [58,81]        [81,107]       [107,133]      [133,168]      [168,210]      [210,253]      [253,296]      [296,344]      [344,402]      [402,469]      [469,540]      [540,613]      [613,693]      [693,782]      [782,873]      [873,969]
# Machine 18: job_8_task_8   job_1_task_8   job_18_task_14 job_16_task_6  job_11_task_19 job_5_task_13  job_12_task_15 job_3_task_19  job_7_task_17  job_4_task_2   job_0_task_1   job_15_task_16 job_13_task_12 job_14_task_0  job_2_task_15  job_9_task_7   job_19_task_2  job_6_task_14  job_17_task_0  job_10_task_17
#            [0,1]          [1,8]          [8,16]         [16,34]        [34,53]        [53,73]        [73,100]       [100,131]      [131,164]      [164,213]      [213,269]      [269,332]      [332,398]      [398,467]      [467,543]      [543,620]      [620,699]      [699,781]      [781,863]      [863,958]
# Machine 19: job_2_task_1   job_4_task_1   job_11_task_7  job_8_task_18  job_6_task_1   job_15_task_1  job_7_task_12  job_16_task_18 job_14_task_1  job_3_task_6   job_0_task_8   job_17_task_2  job_5_task_18  job_12_task_14 job_1_task_0   job_19_task_16 job_10_task_0  job_18_task_13 job_13_task_2  job_9_task_3
#            [0,1]          [1,3]          [3,7]          [7,13]         [13,22]        [22,33]        [33,47]        [47,65]        [65,84]        [84,111]       [111,155]      [155,201]      [201,250]      [250,320]      [320,397]      [397,474]      [474,559]      [559,652]      [652,747]      [747,843]
# Machine 20: job_6_task_19  job_18_task_19 job_9_task_19  job_0_task_3   job_3_task_5   job_16_task_13 job_11_task_6  job_17_task_9  job_13_task_9  job_12_task_18 job_5_task_10  job_4_task_18  job_15_task_11 job_2_task_12  job_10_task_16 job_19_task_7  job_1_task_16  job_7_task_10  job_8_task_5   job_14_task_7
#            [0,46]         [46,105]       [105,170]      [170,177]      [177,185]      [185,202]      [202,221]      [221,247]      [247,275]      [275,308]      [308,345]      [345,394]      [394,448]      [448,503]      [503,567]      [567,640]      [640,724]      [724,814]      [814,904]      [904,1002]
#
#
# Statistics
#   - conflicts: 0
#   - branches : 9884
#   - wall time: 0.471775 s
#   - status   : OPTIMAL
#   - objective: 170
#   - User Time  : 0
# --- 0.52 seconds ---
# This is the list number: 9
# Solution:
# Optimal Schedule Length: 132.0
# Machine 1: job_6_task_19  job_14_task_19 job_12_task_0  job_2_task_3   job_15_task_8  job_13_task_18 job_0_task_17  job_5_task_11  job_3_task_3   job_9_task_9   job_4_task_12  job_11_task_17 job_8_task_13  job_18_task_5  job_1_task_17  job_17_task_16 job_16_task_14 job_7_task_8   job_19_task_14 job_10_task_1
#            [0,60]         [60,132]       [132,134]      [134,140]      [140,147]      [147,157]      [157,172]      [172,191]      [191,224]      [224,260]      [260,307]      [307,356]      [356,411]      [411,472]      [472,542]      [542,614]      [614,697]      [697,784]      [784,872]      [872,969]
# Machine 2: job_16_task_7  job_2_task_9   job_5_task_4   job_15_task_13 job_10_task_19 job_19_task_4  job_1_task_9   job_7_task_14  job_6_task_13  job_12_task_7  job_0_task_13  job_11_task_0  job_3_task_2   job_8_task_6   job_14_task_17 job_4_task_11  job_13_task_1  job_18_task_6  job_9_task_16  job_17_task_6
#            [0,7]          [7,20]         [20,37]        [37,54]        [54,119]       [119,140]      [140,167]      [167,194]      [194,226]      [226,262]      [262,311]      [311,375]      [375,442]      [442,520]      [520,602]      [602,685]      [685,769]      [769,858]      [858,954]      [954,1050]
# Machine 3: job_0_task_11  job_6_task_8   job_17_task_17 job_15_task_19 job_12_task_12 job_8_task_4   job_3_task_1   job_11_task_16 job_5_task_17  job_18_task_2  job_2_task_12  job_9_task_4   job_10_task_18 job_16_task_3  job_13_task_15 job_1_task_11  job_4_task_14  job_14_task_6  job_19_task_11 job_7_task_10
#            [0,12]         [12,26]        [26,43]        [43,128]       [128,149]      [149,175]      [175,203]      [203,231]      [231,270]      [270,314]      [314,361]      [361,413]      [413,470]      [470,533]      [533,605]      [605,682]      [682,759]      [759,839]      [839,925]      [925,1018]
# Machine 4: job_9_task_8   job_13_task_5  job_10_task_4  job_2_task_19  job_19_task_7  job_5_task_19  job_17_task_18 job_11_task_4  job_16_task_8  job_12_task_3  job_7_task_15  job_15_task_2  job_6_task_0   job_4_task_7   job_3_task_13  job_14_task_4  job_8_task_5   job_18_task_7  job_1_task_7   job_0_task_14
#            [0,2]          [2,8]          [8,19]         [19,40]        [40,65]        [65,91]        [91,117]       [117,152]      [152,190]      [190,230]      [230,277]      [277,325]      [325,382]      [382,455]      [455,542]      [542,631]      [631,722]      [722,815]      [815,909]      [909,1007]
# Machine 5: job_15_task_14 job_4_task_19  job_16_task_15 job_0_task_2   job_1_task_19  job_19_task_6  job_12_task_15 job_17_task_9  job_9_task_3   job_2_task_13  job_18_task_10 job_5_task_5   job_13_task_12 job_14_task_7  job_8_task_11  job_10_task_14 job_6_task_5   job_3_task_12  job_7_task_12  job_11_task_11
#            [0,5]          [5,13]         [13,21]        [21,36]        [41,132]       [132,151]      [151,171]      [171,200]      [200,242]      [242,301]      [301,361]      [361,425]      [425,490]      [490,555]      [555,628]      [628,708]      [708,791]      [791,879]      [879,970]      [970,1062]
# Machine 6: job_0_task_19  job_11_task_8  job_6_task_4   job_7_task_19  job_8_task_8   job_10_task_6  job_2_task_14  job_16_task_16 job_18_task_3  job_4_task_9   job_17_task_0  job_3_task_4   job_9_task_2   job_19_task_16 job_15_task_16 job_5_task_13  job_13_task_11 job_12_task_8  job_14_task_2  job_1_task_4
#            [0,10]         [10,22]        [22,43]        [43,127]       [127,153]      [153,182]      [182,212]      [212,245]      [245,279]      [279,320]      [320,369]      [369,423]      [423,477]      [477,542]      [542,614]      [614,691]      [691,772]      [772,854]      [854,938]      [938,1030]
# Machine 7: job_13_task_16 job_4_task_16  job_19_task_2  job_5_task_8   job_11_task_7  job_1_task_14  job_6_task_2   job_14_task_8  job_10_task_8  job_15_task_10 job_18_task_13 job_17_task_5  job_8_task_9   job_12_task_2  job_9_task_14  job_3_task_18  job_7_task_13  job_16_task_11 job_2_task_8   job_0_task_0
#            [0,7]          [7,16]         [16,28]        [28,45]        [45,64]        [64,92]        [92,129]       [129,169]      [169,210]      [210,255]      [255,301]      [301,354]      [354,409]      [409,465]      [465,534]      [534,614]      [614,704]      [704,794]      [794,886]      [886,984]
# Machine 8: job_7_task_3   job_14_task_16 job_11_task_12 job_18_task_19 job_17_task_11 job_19_task_15 job_15_task_9  job_3_task_0   job_12_task_1  job_16_task_2  job_8_task_1   job_9_task_5   job_6_task_3   job_5_task_18  job_2_task_6   job_1_task_2   job_13_task_4  job_0_task_8   job_10_task_5  job_4_task_8
#            [0,10]         [10,21]        [21,34]        [34,131]       [131,149]      [149,169]      [169,195]      [195,231]      [231,278]      [278,328]      [328,382]      [382,441]      [441,510]      [510,584]      [584,659]      [659,735]      [735,812]      [812,897]      [897,986]      [986,1083]
# Machine 9: job_7_task_4   job_12_task_17 job_17_task_15 job_3_task_19  job_5_task_14  job_8_task_12  job_9_task_15  job_0_task_6   job_1_task_0   job_10_task_10 job_14_task_18 job_11_task_9  job_19_task_5  job_15_task_1  job_18_task_1  job_2_task_11  job_13_task_7  job_16_task_5  job_6_task_7   job_4_task_13
#            [0,2]          [2,4]          [4,6]          [6,15]         [15,31]        [31,60]        [60,93]        [93,140]       [140,190]      [190,243]      [243,303]      [303,364]      [364,425]      [425,490]      [490,557]      [557,626]      [626,698]      [698,771]      [771,856]      [856,948]
# Machine 10: job_0_task_16  job_16_task_10 job_4_task_3   job_14_task_12 job_3_task_9   job_8_task_14  job_9_task_13  job_2_task_2   job_13_task_10 job_6_task_16  job_15_task_0  job_10_task_16 job_7_task_2   job_1_task_18  job_17_task_8  job_11_task_10 job_5_task_10  job_12_task_14 job_18_task_11 job_19_task_9
#            [0,5]          [5,10]         [10,18]        [18,28]        [28,52]        [52,76]        [76,101]       [101,128]      [128,155]      [155,185]      [185,215]      [215,248]      [248,295]      [295,354]      [354,423]      [423,495]      [495,572]      [572,655]      [655,741]      [741,833]
# Machine 11: job_11_task_13 job_14_task_11 job_18_task_0  job_12_task_4  job_16_task_12 job_9_task_1   job_19_task_10 job_5_task_12  job_10_task_7  job_2_task_10  job_15_task_7  job_1_task_15  job_3_task_10  job_7_task_5   job_17_task_14 job_13_task_9  job_4_task_6   job_6_task_6   job_8_task_15  job_0_task_5
#            [0,12]         [12,24]        [24,37]        [37,62]        [62,91]        [91,123]       [123,176]      [176,232]      [232,289]      [289,350]      [350,413]      [413,482]      [482,558]      [558,635]      [635,715]      [715,797]      [797,883]      [883,972]      [972,1066]     [1066,1164]
# Machine 12: job_14_task_9  job_13_task_19 job_12_task_19 job_1_task_3   job_6_task_11  job_9_task_18  job_3_task_6   job_0_task_7   job_8_task_17  job_10_task_9  job_18_task_8  job_16_task_6  job_4_task_5   job_17_task_7  job_2_task_0   job_7_task_18  job_11_task_14 job_15_task_3  job_19_task_3  job_5_task_3
#            [0,8]          [8,29]         [29,128]       [128,143]      [143,172]      [172,208]      [208,255]      [255,304]      [304,355]      [355,407]      [407,466]      [466,529]      [529,593]      [593,662]      [662,735]      [735,810]      [810,887]      [887,968]      [968,1055]     [1055,1144]
# Machine 13: job_8_task_19  job_12_task_9  job_4_task_0   job_19_task_13 job_5_task_15  job_11_task_5  job_17_task_4  job_9_task_10  job_2_task_18  job_15_task_15 job_7_task_0   job_18_task_16 job_0_task_4   job_16_task_9  job_14_task_13 job_3_task_16  job_6_task_12  job_1_task_1   job_10_task_17 job_13_task_0
#            [0,1]          [1,8]          [8,17]         [17,30]        [30,44]        [44,67]        [67,109]       [109,152]      [152,198]      [198,249]      [249,315]      [315,392]      [392,470]      [470,551]      [551,636]      [636,726]      [726,816]      [816,908]      [908,1000]     [1000,1092]
# Machine 14: job_11_task_6  job_7_task_1   job_14_task_5  job_15_task_5  job_0_task_12  job_2_task_7   job_10_task_15 job_18_task_12 job_19_task_0  job_6_task_10  job_12_task_5  job_4_task_15  job_8_task_3   job_17_task_10 job_3_task_8   job_13_task_13 job_9_task_7   job_5_task_6   job_1_task_10  job_16_task_17
#            [0,8]          [8,21]         [21,40]        [40,66]        [66,94]        [94,124]       [124,163]      [163,203]      [203,243]      [243,285]      [285,331]      [331,380]      [380,438]      [438,505]      [505,577]      [577,651]      [651,734]      [734,821]      [821,915]      [915,1010]
# Machine 15: job_14_task_3  job_12_task_16 job_0_task_9   job_3_task_7   job_2_task_5   job_19_task_19 job_10_task_13 job_17_task_2  job_8_task_7   job_1_task_8   job_16_task_0  job_6_task_17  job_11_task_15 job_15_task_4  job_9_task_11  job_7_task_7   job_18_task_15 job_5_task_0   job_13_task_6  job_4_task_4
#            [0,2]          [2,7]          [7,16]         [16,26]        [26,37]        [37,108]       [108,136]      [136,167]      [167,203]      [203,244]      [244,297]      [297,359]      [359,423]      [423,495]      [495,569]      [569,652]      [652,740]      [740,836]      [836,932]      [932,1030]
# Machine 16: job_11_task_1  job_18_task_4  job_15_task_6  job_13_task_8  job_4_task_17  job_7_task_6   job_16_task_4  job_19_task_18 job_1_task_5   job_0_task_1   job_12_task_11 job_2_task_1   job_14_task_14 job_9_task_17  job_10_task_0  job_8_task_16  job_5_task_9   job_6_task_18  job_3_task_11  job_17_task_3
#            [0,13]         [13,30]        [30,48]        [48,67]        [67,89]        [89,116]       [116,155]      [155,198]      [198,243]      [243,292]      [292,351]      [351,415]      [415,483]      [483,559]      [559,637]      [637,716]      [716,798]      [798,885]      [885,982]      [982,1081]
# Machine 17: job_2_task_17  job_6_task_14  job_14_task_0  job_18_task_9  job_9_task_19  job_7_task_9   job_16_task_13 job_11_task_18 job_5_task_2   job_15_task_11 job_19_task_17 job_4_task_18  job_13_task_17 job_17_task_12 job_0_task_15  job_1_task_13  job_10_task_12 job_3_task_17  job_12_task_13 job_8_task_10
#            [0,1]          [1,2]          [2,9]          [9,26]         [26,113]       [113,134]      [134,157]      [157,181]      [181,208]      [208,236]      [236,279]      [279,337]      [337,398]      [398,460]      [460,523]      [523,590]      [590,670]      [670,753]      [753,849]      [849,947]
# Machine 18: job_0_task_18  job_7_task_16  job_2_task_4   job_8_task_2   job_11_task_19 job_13_task_2  job_15_task_18 job_5_task_1   job_17_task_1  job_19_task_1  job_4_task_10  job_1_task_16  job_9_task_0   job_12_task_6  job_3_task_5   job_6_task_1   job_18_task_14 job_16_task_1  job_10_task_3  job_14_task_15
#            [0,4]          [4,8]          [8,15]         [15,23]        [23,38]        [38,54]        [54,85]        [85,119]       [119,157]      [157,201]      [201,247]      [247,300]      [300,354]      [354,409]      [409,481]      [481,553]      [553,631]      [631,716]      [716,803]      [803,890]
# Machine 19: job_4_task_1   job_2_task_15  job_18_task_17 job_1_task_6   job_11_task_3  job_9_task_12  job_0_task_10  job_14_task_10 job_17_task_13 job_19_task_8  job_13_task_14 job_7_task_17  job_10_task_2  job_8_task_18  job_15_task_17 job_6_task_15  job_16_task_18 job_5_task_7   job_12_task_10 job_3_task_15
#            [0,2]          [2,15]         [15,33]        [33,52]        [52,71]        [71,92]        [92,114]       [114,136]      [136,161]      [161,187]      [187,220]      [220,262]      [262,310]      [310,366]      [366,427]      [427,500]      [500,579]      [579,670]      [670,761]      [761,857]
# Machine 20: job_1_task_12  job_16_task_19 job_17_task_19 job_14_task_1  job_7_task_11  job_10_task_11 job_8_task_0   job_6_task_9   job_2_task_16  job_12_task_18 job_11_task_2  job_19_task_12 job_5_task_16  job_4_task_2   job_13_task_3  job_9_task_6   job_0_task_3   job_3_task_14  job_15_task_12 job_18_task_18
#            [0,4]          [4,55]         [55,130]       [130,140]      [140,158]      [158,182]      [182,208]      [208,240]      [240,277]      [277,318]      [318,367]      [367,424]      [424,485]      [485,549]      [549,620]      [620,708]      [708,800]      [800,892]      [892,986]      [986,1082]
#
#
# Statistics
#   - conflicts: 4
#   - branches : 9684
#   - wall time: 0.435198 s
#   - status   : OPTIMAL
#   - objective: 132
#   - User Time  : 0
# --- 0.48 seconds ---
# --- 4.63 seconds for the file---
# --- 8.76 seconds for the cell---
