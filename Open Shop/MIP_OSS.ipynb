# %% [markdown]
# # OPEN SHOP SCHEDULING

# %% [markdown]
# ## Data

# %%
import pandas as pd
import numpy as np
from ortools.linear_solver import pywraplp
from ortools.init import pywrapinit
import pandas as pd 
import time
import collections
from ortools.linear_solver import pywraplp
import time

# %%
def extract_data(filename):
    # Initialize variables to store the data.
    nj = []
    nm = []
    times = []
    machines = []

    task_counter = 0
    task_matrix = []


    # Open the file and read each line.
    with open(filename, 'r') as file:
        contents = file.read()
        lines = contents.splitlines()

        for line in range(len(lines)):
            # Check if the line contains the number of jobs and machines.
            if 'number of jobs' in lines[line]:
                nj.append(lines[line + 1].split()[0])
                nm.append(lines[line + 1].split()[1])
                break
        
        num_jobs = int(nj[0])
        num_machines = int(nm[0])
        for line in range(len(lines)):

            if 'number of jobs' in lines[line]:
                continue

            # elif ' ' in lines[line]:
            #     continue

            elif 'processing times :' in lines[line]:

                task_matrix.append(task_counter)
                task_matrix[task_counter] = []

                job_counter = 0

                pos = 0
                while pos < num_jobs:
                    pos += 1
                    time_var = lines[line + pos].split()
                    machine_var = lines[line + pos + num_jobs + 1].split()

                    task_matrix[task_counter].append([])
                    
                    #print('new times/machines pairs')
                    for aux in range(len(time_var)):
                        #print(f'{time_var[aux]} , {machine_var[aux]}')
                        task_matrix[task_counter][job_counter].append((int(time_var[aux]), int(machine_var[aux])))
                    
                    job_counter += 1

                task_counter +=1

        #print(task_matrix)

    return (num_jobs, num_machines, task_matrix)

# %%
def main(jobs_data):
    machines_count = num_machines
    all_machines = range(1,machines_count+1,1)
    # Computes horizon dynamically as the sum of all durations.
    horizon = sum(task[0] for job in jobs_data for task in job)

    # Named tuple to store information about created variables.
    task_type = collections.namedtuple('task_type', 'start end interval')
    # Named tuple to manipulate solution information.
    assigned_task_type = collections.namedtuple('assigned_task_type',
                                                'start job index duration')

    # Create the MIP solver with the CBC backend.
    solver = pywraplp.Solver('schedule_jobs_mip',
                            pywraplp.Solver.SCIP_MIXED_INTEGER_PROGRAMMING)

    # Creates job intervals and add to the corresponding machine lists.
    all_tasks = {}
    machine_to_intervals = collections.defaultdict(list)

    # Create binary variables for task overlap.
    x = {}
    M = 1000000  # Large constant for precedence constraints.
    for job_id, job in enumerate(jobs_data):
        for task_id, task in enumerate(job):
            for other_task_id, other_task in enumerate(job):
                if task_id != other_task_id:
                    x[job_id, task_id, other_task_id] = solver.BoolVar(
                        'x_%i_%i_%i' % (job_id, task_id, other_task_id))

    for job_id, job in enumerate(jobs_data):
        #print(job_id,job)
        for task_id, task in enumerate(job):
            #print(task_id+1, task)
            duration = task[0]
            machine = task[1]
            suffix = '_%i_%i' % (job_id, task_id)

            start_var = solver.IntVar(0, horizon, 'start' + suffix)
            #end_var = solver.IntVar(0, horizon, 'end' + suffix)
            end_var = start_var + duration
            #interval_var = solver.ComputeExactConditionNumber(0,horizon, name = 'interval' + suffix)
            all_tasks[job_id, task_id] = task_type(start=start_var,
                                                end = end_var,
                                                interval = None)
            machine_to_intervals[machine].append(start_var)
            #correto
    # # Create precedence constraints for tasks on the same machine.
    # for job_id, job in enumerate(jobs_data):
    #     for task_id, task in enumerate(job):
    #         for other_task_id, other_task in enumerate(job):
    #             if task_id != other_task_id:
    #                 x[job_id, task_id, other_task_id] = solver.BoolVar(
    #                     'x_%i_%i_%i' % (job_id, task_id, other_task_id))
    # Add constraints to ensure that the start time, duration, and end time variables
    # represent a valid time interval.
    #solver.Add(end_var == start_var + interval_var)


    # Makespan objective.
    obj_var = solver.IntVar(0, horizon, 'makespan')
    for job_id, job in enumerate(jobs_data):
        solver.Add(obj_var >= all_tasks[job_id, len(job) - 1].end)
    solver.Minimize(obj_var)

    if solver.Solve() == pywraplp.Solver.OPTIMAL or solver.Solve() == pywraplp.Solver.FEASIBLE:
        print('Solution:')
        # Create one list of assigned tasks per machine.
        assigned_jobs = collections.defaultdict(list)
        for job_id, job in enumerate(jobs_data):
            for task_id, task in enumerate(job):
                machine = task[1]
                assigned_jobs[machine].append(
                    assigned_task_type(solver.Objective().Value(
                        ),
                                        job=job_id,
                                        index=task_id,
                                        duration=task[0]))
            # Create per machine output lines.
        output = ''
        for machine in all_machines:
            # Sort by starting time.
            assigned_jobs[machine].sort()
            sol_line_tasks = 'Machine ' + str(machine) + ': '
            sol_line = '           '

            for assigned_task in assigned_jobs[machine]:
                name = 'job_%i_task_%i' % (assigned_task.job,
                                            assigned_task.index)
                # Add spaces to output to align columns.
                sol_line_tasks += '%-15s' % name

                start = assigned_task.start
                duration = assigned_task.duration

                sol_tmp = '[%i,%i]' % (start,duration)
                # Add spaces to output to align columns.
                sol_line += '%-15s' % sol_tmp

            sol_line += '\n'
            sol_line_tasks += '\n'
            output += sol_line_tasks
            output += sol_line

        # Finally print the solution found.
        print(f'Optimal Schedule Length: {solver.Objective().Value()}')
        print(output)
    else:
        print('No solution found.')

# %%
list_files = ['tai4_4.txt','tai5_5.txt','tai7_7.txt','tai10_10.txt','tai15_15.txt','tai20_20.txt']
start_cell_time = time.time()
for i in range(len(list_files)):
    start_list_time = time.time()
    print(f'This is the file: {list_files[i]}')
    num_jobs, num_machines, task_matrix = extract_data(list_files[i])
    for i in range(len(task_matrix)):
        start_time = time.time()
        print (f'This is the list number: {i}')
        main(task_matrix[i])
        print("--- %.2f seconds ---" % (time.time() - start_time))
    print("--- %.2f seconds for the file---" % (time.time() - start_list_time))
print("--- %.2f seconds for the cell---" % (time.time() - start_cell_time))
# Out:
# This is the file: tai4_4.txt
# This is the list number: 0
# Solution:
# Optimal Schedule Length: 87.0
# Machine 1: job_0_task_1   job_1_task_1   job_2_task_0   job_3_task_0
#            [87,34]        [87,15]        [87,38]        [87,95]
# Machine 2: job_0_task_3   job_1_task_2   job_2_task_1   job_3_task_2
#            [87,2]         [87,89]        [87,19]        [87,7]
# Machine 3: job_0_task_0   job_1_task_3   job_2_task_2   job_3_task_1
#            [87,54]        [87,70]        [87,28]        [87,34]
# Machine 4: job_0_task_2   job_1_task_0   job_2_task_3   job_3_task_3
#            [87,61]        [87,9]         [87,87]        [87,29]
#
# --- 0.01 seconds ---
# This is the list number: 1
# Solution:
# Optimal Schedule Length: 83.0
# Machine 1: job_0_task_2   job_1_task_1   job_2_task_0   job_3_task_3
#            [83,45]        [83,80]        [83,29]        [83,74]
# Machine 2: job_0_task_3   job_1_task_3   job_2_task_1   job_3_task_2
#            [83,83]        [83,45]        [83,56]        [83,45]
# Machine 3: job_0_task_1   job_1_task_2   job_2_task_2   job_3_task_1
#            [83,70]        [83,58]        [83,29]        [83,64]
# Machine 4: job_0_task_0   job_1_task_0   job_2_task_3   job_3_task_0
#            [83,5]         [83,24]        [83,61]        [83,43]
#
# --- 0.01 seconds ---
# This is the list number: 2
# Solution:
# Optimal Schedule Length: 85.0
# Machine 1: job_0_task_0   job_1_task_3   job_2_task_1   job_3_task_0
#            [85,2]         [85,85]        [85,54]        [85,59]
# Machine 2: job_0_task_2   job_1_task_0   job_2_task_2   job_3_task_2
#            [85,5]         [85,68]        [85,77]        [85,63]
# Machine 3: job_0_task_1   job_1_task_1   job_2_task_0   job_3_task_3
#            [85,38]        [85,14]        [85,89]        [85,72]
# Machine 4: job_0_task_3   job_1_task_2   job_2_task_3   job_3_task_1
#            [85,66]        [85,95]        [85,38]        [85,51]
#
# --- 0.01 seconds ---
# This is the list number: 3
# Solution:
# Optimal Schedule Length: 75.0
# Machine 1: job_0_task_2   job_1_task_1   job_2_task_2   job_3_task_1
#            [75,60]        [75,25]        [75,58]        [75,43]
# Machine 2: job_0_task_3   job_1_task_2   job_2_task_1   job_3_task_3
#            [75,19]        [75,40]        [75,88]        [75,62]
# Machine 3: job_0_task_1   job_1_task_3   job_2_task_3   job_3_task_2
#            [75,54]        [75,75]        [75,28]        [75,74]
# Machine 4: job_0_task_0   job_1_task_0   job_2_task_0   job_3_task_0
#            [75,35]        [75,98]        [75,52]        [75,60]
#
# --- 0.01 seconds ---
# This is the list number: 4
# Solution:
# Optimal Schedule Length: 93.0
# Machine 1: job_0_task_0   job_1_task_2   job_2_task_2   job_3_task_1
#            [93,90]        [93,73]        [93,48]        [93,76]
# Machine 2: job_0_task_2   job_1_task_3   job_2_task_1   job_3_task_2
#            [93,64]        [93,26]        [93,94]        [93,87]
# Machine 3: job_0_task_1   job_1_task_1   job_2_task_3   job_3_task_0
#            [93,50]        [93,92]        [93,93]        [93,43]
# Machine 4: job_0_task_3   job_1_task_0   job_2_task_0   job_3_task_3
#            [93,65]        [93,47]        [93,27]        [93,65]
#
# --- 0.01 seconds ---
# This is the list number: 5
# Solution:
# Optimal Schedule Length: 50.0
# Machine 1: job_0_task_0   job_1_task_0   job_2_task_2   job_3_task_3
#            [50,37]        [50,91]        [50,7]         [50,50]
# Machine 2: job_0_task_3   job_1_task_2   job_2_task_0   job_3_task_0
#            [50,46]        [50,1]         [50,91]        [50,36]
# Machine 3: job_0_task_2   job_1_task_3   job_2_task_3   job_3_task_2
#            [50,91]        [50,10]        [50,4]         [50,42]
# Machine 4: job_0_task_1   job_1_task_1   job_2_task_1   job_3_task_1
#            [50,11]        [50,76]        [50,61]        [50,30]
#
# --- 0.01 seconds ---
# This is the list number: 6
# Solution:
# Optimal Schedule Length: 62.0
# Machine 1: job_0_task_3   job_1_task_1   job_2_task_1   job_3_task_0
#            [62,57]        [62,30]        [62,8]         [62,66]
# Machine 2: job_0_task_2   job_1_task_2   job_2_task_0   job_3_task_2
#            [62,17]        [62,43]        [62,57]        [62,64]
# Machine 3: job_0_task_0   job_1_task_0   job_2_task_3   job_3_task_3
#            [62,9]         [62,78]        [62,19]        [62,62]
# Machine 4: job_0_task_1   job_1_task_3   job_2_task_2   job_3_task_1
#            [62,83]        [62,40]        [62,56]        [62,5]
#
# --- 0.01 seconds ---
# This is the list number: 7
# Solution:
# Optimal Schedule Length: 92.0
# Machine 1: job_0_task_1   job_1_task_3   job_2_task_3   job_3_task_1
#            [92,16]        [92,81]        [92,61]        [92,51]
# Machine 2: job_0_task_2   job_1_task_0   job_2_task_2   job_3_task_0
#            [92,83]        [92,90]        [92,25]        [92,9]
# Machine 3: job_0_task_3   job_1_task_1   job_2_task_0   job_3_task_2
#            [92,14]        [92,19]        [92,96]        [92,47]
# Machine 4: job_0_task_0   job_1_task_2   job_2_task_1   job_3_task_3
#            [92,95]        [92,21]        [92,4]         [92,92]
#
# --- 0.05 seconds ---
# This is the list number: 8
# Solution:
# Optimal Schedule Length: 82.0
# Machine 1: job_0_task_3   job_1_task_0   job_2_task_0   job_3_task_0
#            [82,62]        [82,66]        [82,63]        [82,11]
# Machine 2: job_0_task_2   job_1_task_1   job_2_task_3   job_3_task_1
#            [82,71]        [82,63]        [82,32]        [82,72]
# Machine 3: job_0_task_1   job_1_task_2   job_2_task_1   job_3_task_3
#            [82,59]        [82,21]        [82,95]        [82,82]
# Machine 4: job_0_task_0   job_1_task_3   job_2_task_2   job_3_task_2
#            [82,46]        [82,69]        [82,45]        [82,93]
#
# --- 0.01 seconds ---
# This is the list number: 9
# Solution:
# Optimal Schedule Length: 97.0
# Machine 1: job_0_task_3   job_1_task_1   job_2_task_1   job_3_task_3
#            [97,97]        [97,36]        [97,53]        [97,16]
# Machine 2: job_0_task_0   job_1_task_0   job_2_task_3   job_3_task_0
#            [97,4]         [97,49]        [97,63]        [97,16]
# Machine 3: job_0_task_1   job_1_task_3   job_2_task_2   job_3_task_2
#            [97,40]        [97,52]        [97,27]        [97,92]
# Machine 4: job_0_task_2   job_1_task_2   job_2_task_0   job_3_task_1
#            [97,1]         [97,75]        [97,70]        [97,33]
#
# --- 0.01 seconds ---
# --- 0.18 seconds for the file---
# This is the file: tai5_5.txt
# This is the list number: 0
# Solution:
# Optimal Schedule Length: 68.0
# Machine 1: job_0_task_1   job_1_task_0   job_2_task_1   job_3_task_4   job_4_task_0
#            [68,64]        [68,7]         [68,74]        [68,54]        [68,80]
# Machine 2: job_0_task_4   job_1_task_2   job_2_task_2   job_3_task_0   job_4_task_2
#            [68,66]        [68,69]        [68,70]        [68,45]        [68,45]
# Machine 3: job_0_task_2   job_1_task_4   job_2_task_4   job_3_task_3   job_4_task_4
#            [68,31]        [68,68]        [68,60]        [68,98]        [68,10]
# Machine 4: job_0_task_0   job_1_task_1   job_2_task_0   job_3_task_1   job_4_task_1
#            [68,85]        [68,14]        [68,1]         [68,76]        [68,15]
# Machine 5: job_0_task_3   job_1_task_3   job_2_task_3   job_3_task_2   job_4_task_3
#            [68,44]        [68,18]        [68,90]        [68,13]        [68,91]
#
# --- 0.03 seconds ---
# This is the list number: 1
# Solution:
# Optimal Schedule Length: 90.0
# Machine 1: job_0_task_4   job_1_task_2   job_2_task_3   job_3_task_1   job_4_task_3
#            [90,19]        [90,6]         [90,8]         [90,71]        [90,86]
# Machine 2: job_0_task_1   job_1_task_0   job_2_task_0   job_3_task_2   job_4_task_4
#            [90,38]        [90,22]        [90,83]        [90,87]        [90,15]
# Machine 3: job_0_task_3   job_1_task_3   job_2_task_2   job_3_task_4   job_4_task_0
#            [90,81]        [90,64]        [90,15]        [90,40]        [90,55]
# Machine 4: job_0_task_0   job_1_task_4   job_2_task_4   job_3_task_3   job_4_task_2
#            [90,83]        [90,90]        [90,1]         [90,21]        [90,55]
# Machine 5: job_0_task_2   job_1_task_1   job_2_task_1   job_3_task_0   job_4_task_1
#            [90,32]        [90,52]        [90,35]        [90,33]        [90,42]
#
# --- 0.01 seconds ---
# This is the list number: 2
# Solution:
# Optimal Schedule Length: 51.0
# Machine 1: job_0_task_3   job_1_task_3   job_2_task_3   job_3_task_4   job_4_task_3
#            [51,80]        [51,79]        [51,65]        [51,39]        [51,54]
# Machine 2: job_0_task_4   job_1_task_2   job_2_task_4   job_3_task_0   job_4_task_1
#            [51,3]         [51,69]        [51,37]        [51,95]        [51,29]
# Machine 3: job_0_task_1   job_1_task_1   job_2_task_1   job_3_task_1   job_4_task_4
#            [51,65]        [51,51]        [51,75]        [51,58]        [51,27]
# Machine 4: job_0_task_0   job_1_task_4   job_2_task_0   job_3_task_3   job_4_task_0
#            [51,98]        [51,51]        [51,53]        [51,49]        [51,68]
# Machine 5: job_0_task_2   job_1_task_0   job_2_task_2   job_3_task_2   job_4_task_2
#            [51,9]         [51,45]        [51,91]        [51,76]        [51,93]
#
# --- 0.01 seconds ---
# This is the list number: 3
# Solution:
# Optimal Schedule Length: 93.0
# Machine 1: job_0_task_1   job_1_task_1   job_2_task_4   job_3_task_0   job_4_task_3
#            [93,66]        [93,78]        [93,75]        [93,25]        [93,12]
# Machine 2: job_0_task_2   job_1_task_4   job_2_task_2   job_3_task_1   job_4_task_0
#            [93,45]        [93,44]        [93,53]        [93,77]        [93,83]
# Machine 3: job_0_task_0   job_1_task_2   job_2_task_0   job_3_task_3   job_4_task_1
#            [93,64]        [93,36]        [93,81]        [93,38]        [93,81]
# Machine 4: job_0_task_4   job_1_task_0   job_2_task_3   job_3_task_2   job_4_task_2
#            [93,31]        [93,66]        [93,91]        [93,79]        [93,37]
# Machine 5: job_0_task_3   job_1_task_3   job_2_task_1   job_3_task_4   job_4_task_4
#            [93,35]        [93,71]        [93,5]         [93,60]        [93,93]
#
# --- 0.01 seconds ---
# This is the list number: 4
# Solution:
# Optimal Schedule Length: 80.0
# Machine 1: job_0_task_2   job_1_task_0   job_2_task_2   job_3_task_3   job_4_task_4
#            [80,58]        [80,33]        [80,86]        [80,92]        [80,28]
# Machine 2: job_0_task_4   job_1_task_3   job_2_task_3   job_3_task_0   job_4_task_2
#            [80,52]        [80,48]        [80,59]        [80,85]        [80,75]
# Machine 3: job_0_task_0   job_1_task_4   job_2_task_4   job_3_task_4   job_4_task_0
#            [80,78]        [80,46]        [80,80]        [80,5]         [80,91]
# Machine 4: job_0_task_3   job_1_task_1   job_2_task_1   job_3_task_2   job_4_task_1
#            [80,60]        [80,52]        [80,63]        [80,56]        [80,49]
# Machine 5: job_0_task_1   job_1_task_2   job_2_task_0   job_3_task_1   job_4_task_3
#            [80,73]        [80,92]        [80,31]        [80,2]         [80,78]
#
# --- 0.01 seconds ---
# This is the list number: 5
# Solution:
# Optimal Schedule Length: 86.0
# Machine 1: job_0_task_2   job_1_task_3   job_2_task_3   job_3_task_2   job_4_task_1
#            [86,93]        [86,96]        [86,17]        [86,61]        [86,37]
# Machine 2: job_0_task_1   job_1_task_2   job_2_task_1   job_3_task_0   job_4_task_3
#            [86,41]        [86,63]        [86,62]        [86,55]        [86,56]
# Machine 3: job_0_task_3   job_1_task_0   job_2_task_2   job_3_task_4   job_4_task_4
#            [86,60]        [86,81]        [86,46]        [86,26]        [86,82]
# Machine 4: job_0_task_4   job_1_task_1   job_2_task_4   job_3_task_1   job_4_task_2
#            [86,86]        [86,6]         [86,81]        [86,85]        [86,34]
# Machine 5: job_0_task_0   job_1_task_4   job_2_task_0   job_3_task_3   job_4_task_0
#            [86,5]         [86,4]         [86,50]        [86,78]        [86,98]
#
# --- 0.05 seconds ---
# This is the list number: 6
# Solution:
# Optimal Schedule Length: 51.0
# Machine 1: job_0_task_3   job_1_task_3   job_2_task_3   job_3_task_3   job_4_task_2
#            [51,65]        [51,71]        [51,47]        [51,14]        [51,89]
# Machine 2: job_0_task_4   job_1_task_4   job_2_task_2   job_3_task_0   job_4_task_4
#            [51,51]        [51,31]        [51,78]        [51,97]        [51,7]
# Machine 3: job_0_task_2   job_1_task_0   job_2_task_0   job_3_task_2   job_4_task_0
#            [51,62]        [51,49]        [51,63]        [51,48]        [51,76]
# Machine 4: job_0_task_0   job_1_task_2   job_2_task_4   job_3_task_4   job_4_task_1
#            [51,65]        [51,85]        [51,2]         [51,42]        [51,80]
# Machine 5: job_0_task_1   job_1_task_1   job_2_task_1   job_3_task_1   job_4_task_3
#            [51,16]        [51,58]        [51,62]        [51,95]        [51,9]
#
# --- 0.01 seconds ---
# This is the list number: 7
# Solution:
# Optimal Schedule Length: 80.0
# Machine 1: job_0_task_2   job_1_task_1   job_2_task_3   job_3_task_2   job_4_task_0
#            [80,46]        [80,52]        [80,18]        [80,52]        [80,95]
# Machine 2: job_0_task_3   job_1_task_2   job_2_task_0   job_3_task_3   job_4_task_4
#            [80,66]        [80,64]        [80,70]        [80,69]        [80,22]
# Machine 3: job_0_task_1   job_1_task_3   job_2_task_2   job_3_task_4   job_4_task_1
#            [80,30]        [80,38]        [80,79]        [80,80]        [80,54]
# Machine 4: job_0_task_4   job_1_task_0   job_2_task_4   job_3_task_1   job_4_task_3
#            [80,29]        [80,82]        [80,29]        [80,59]        [80,4]
# Machine 5: job_0_task_0   job_1_task_4   job_2_task_1   job_3_task_0   job_4_task_2
#            [80,89]        [80,56]        [80,92]        [80,14]        [80,37]
#
# --- 0.01 seconds ---
# This is the list number: 8
# Solution:
# Optimal Schedule Length: 93.0
# Machine 1: job_0_task_0   job_1_task_4   job_2_task_2   job_3_task_0   job_4_task_1
#            [93,22]        [93,73]        [93,77]        [93,96]        [93,16]
# Machine 2: job_0_task_4   job_1_task_1   job_2_task_0   job_3_task_2   job_4_task_4
#            [93,35]        [93,93]        [93,38]        [93,72]        [93,93]
# Machine 3: job_0_task_2   job_1_task_3   job_2_task_1   job_3_task_1   job_4_task_3
#            [93,83]        [93,84]        [93,34]        [93,55]        [93,89]
# Machine 4: job_0_task_3   job_1_task_2   job_2_task_3   job_3_task_4   job_4_task_0
#            [93,38]        [93,23]        [93,94]        [93,67]        [93,49]
# Machine 5: job_0_task_1   job_1_task_0   job_2_task_4   job_3_task_3   job_4_task_2
#            [93,90]        [93,68]        [93,41]        [93,59]        [93,90]
#
# --- 0.02 seconds ---
# This is the list number: 9
# Solution:
# Optimal Schedule Length: 91.0
# Machine 1: job_0_task_0   job_1_task_3   job_2_task_2   job_3_task_3   job_4_task_4
#            [91,90]        [91,14]        [91,59]        [91,67]        [91,91]
# Machine 2: job_0_task_3   job_1_task_4   job_2_task_0   job_3_task_0   job_4_task_0
#            [91,36]        [91,56]        [91,97]        [91,49]        [91,74]
# Machine 3: job_0_task_2   job_1_task_1   job_2_task_1   job_3_task_4   job_4_task_2
#            [91,87]        [91,93]        [91,45]        [91,50]        [91,25]
# Machine 4: job_0_task_1   job_1_task_0   job_2_task_3   job_3_task_1   job_4_task_3
#            [91,17]        [91,99]        [91,44]        [91,81]        [91,76]
# Machine 5: job_0_task_4   job_1_task_2   job_2_task_4   job_3_task_2   job_4_task_1
#            [91,59]        [91,32]        [91,40]        [91,30]        [91,53]
#
# --- 0.01 seconds ---
# --- 0.23 seconds for the file---
# This is the file: tai7_7.txt
# This is the list number: 0
# Solution:
# Optimal Schedule Length: 63.0
# Machine 1: job_0_task_4   job_1_task_4   job_2_task_0   job_3_task_2   job_4_task_4   job_5_task_3   job_6_task_6
#            [63,71]        [63,91]        [63,66]        [63,78]        [63,52]        [63,11]        [63,52]
# Machine 2: job_0_task_1   job_1_task_0   job_2_task_1   job_3_task_0   job_4_task_5   job_5_task_2   job_6_task_0
#            [63,39]        [63,19]        [63,95]        [63,48]        [63,9]         [63,37]        [63,83]
# Machine 3: job_0_task_0   job_1_task_1   job_2_task_4   job_3_task_4   job_4_task_2   job_5_task_5   job_6_task_5
#            [63,89]        [63,13]        [63,96]        [63,19]        [63,91]        [63,30]        [63,88]
# Machine 4: job_0_task_2   job_1_task_5   job_2_task_5   job_3_task_5   job_4_task_1   job_5_task_4   job_6_task_1
#            [63,54]        [63,73]        [63,18]        [63,68]        [63,28]        [63,2]         [63,45]
# Machine 5: job_0_task_6   job_1_task_3   job_2_task_6   job_3_task_6   job_4_task_3   job_5_task_1   job_6_task_2
#            [63,56]        [63,46]        [63,14]        [63,63]        [63,75]        [63,98]        [63,37]
# Machine 6: job_0_task_5   job_1_task_2   job_2_task_2   job_3_task_1   job_4_task_0   job_5_task_6   job_6_task_4
#            [63,92]        [63,81]        [63,48]        [63,46]        [63,60]        [63,38]        [63,52]
# Machine 7: job_0_task_3   job_1_task_6   job_2_task_3   job_3_task_3   job_4_task_6   job_5_task_0   job_6_task_3
#            [63,34]        [63,27]        [63,24]        [63,94]        [63,7]         [63,33]        [63,77]
#
# --- 0.02 seconds ---
# This is the list number: 1
# Solution:
# Optimal Schedule Length: 92.0
# Machine 1: job_0_task_6   job_1_task_0   job_2_task_6   job_3_task_3   job_4_task_4   job_5_task_3   job_6_task_2
#            [92,76]        [92,97]        [92,9]         [92,4]         [92,93]        [92,97]        [92,64]
# Machine 2: job_0_task_5   job_1_task_5   job_2_task_1   job_3_task_1   job_4_task_6   job_5_task_4   job_6_task_3
#            [92,9]         [92,84]        [92,7]         [92,3]         [92,17]        [92,96]        [92,90]
# Machine 3: job_0_task_3   job_1_task_4   job_2_task_2   job_3_task_4   job_4_task_3   job_5_task_5   job_6_task_5
#            [92,82]        [92,97]        [92,77]        [92,15]        [92,35]        [92,33]        [92,97]
# Machine 4: job_0_task_0   job_1_task_2   job_2_task_0   job_3_task_0   job_4_task_5   job_5_task_6   job_6_task_4
#            [92,89]        [92,20]        [92,62]        [92,83]        [92,72]        [92,56]        [92,61]
# Machine 5: job_0_task_2   job_1_task_6   job_2_task_5   job_3_task_2   job_4_task_2   job_5_task_2   job_6_task_0
#            [92,4]         [92,92]        [92,75]        [92,87]        [92,33]        [92,58]        [92,22]
# Machine 6: job_0_task_4   job_1_task_1   job_2_task_4   job_3_task_5   job_4_task_1   job_5_task_1   job_6_task_6
#            [92,86]        [92,10]        [92,78]        [92,11]        [92,56]        [92,40]        [92,9]
# Machine 7: job_0_task_1   job_1_task_3   job_2_task_3   job_3_task_6   job_4_task_0   job_5_task_0   job_6_task_1
#            [92,65]        [92,33]        [92,57]        [92,22]        [92,84]        [92,48]        [92,69]
#
# --- 0.02 seconds ---
# This is the list number: 2
# Solution:
# Optimal Schedule Length: 97.0
# Machine 1: job_0_task_4   job_1_task_4   job_2_task_5   job_3_task_4   job_4_task_2   job_5_task_2   job_6_task_5
#            [97,76]        [97,84]        [97,71]        [97,46]        [97,40]        [97,46]        [97,19]
# Machine 2: job_0_task_0   job_1_task_2   job_2_task_6   job_3_task_3   job_4_task_3   job_5_task_5   job_6_task_2
#            [97,95]        [97,50]        [97,97]        [97,62]        [97,94]        [97,45]        [97,25]
# Machine 3: job_0_task_5   job_1_task_3   job_2_task_4   job_3_task_5   job_4_task_6   job_5_task_6   job_6_task_6
#            [97,93]        [97,80]        [97,17]        [97,72]        [97,79]        [97,47]        [97,69]
# Machine 4: job_0_task_6   job_1_task_1   job_2_task_0   job_3_task_6   job_4_task_0   job_5_task_3   job_6_task_3
#            [97,29]        [97,68]        [97,86]        [97,22]        [97,80]        [97,26]        [97,49]
# Machine 5: job_0_task_3   job_1_task_5   job_2_task_2   job_3_task_2   job_4_task_4   job_5_task_0   job_6_task_4
#            [97,82]        [97,44]        [97,50]        [97,94]        [97,15]        [97,44]        [97,83]
# Machine 6: job_0_task_1   job_1_task_0   job_2_task_1   job_3_task_0   job_4_task_1   job_5_task_4   job_6_task_1
#            [97,78]        [97,52]        [97,58]        [97,98]        [97,27]        [97,69]        [97,53]
# Machine 7: job_0_task_2   job_1_task_6   job_2_task_3   job_3_task_1   job_4_task_5   job_5_task_1   job_6_task_0
#            [97,5]         [97,62]        [97,67]        [97,57]        [97,87]        [97,74]        [97,92]
#
# --- 0.02 seconds ---
# This is the list number: 3
# Solution:
# Optimal Schedule Length: 82.0
# Machine 1: job_0_task_4   job_1_task_5   job_2_task_1   job_3_task_0   job_4_task_5   job_5_task_0   job_6_task_0
#            [82,50]        [82,43]        [82,77]        [82,36]        [82,98]        [82,4]         [82,77]
# Machine 2: job_0_task_2   job_1_task_3   job_2_task_3   job_3_task_6   job_4_task_3   job_5_task_6   job_6_task_4
#            [82,41]        [82,48]        [82,56]        [82,82]        [82,78]        [82,32]        [82,30]
# Machine 3: job_0_task_1   job_1_task_2   job_2_task_6   job_3_task_3   job_4_task_1   job_5_task_2   job_6_task_2
#            [82,69]        [82,21]        [82,62]        [82,65]        [82,77]        [82,6]         [82,37]
# Machine 4: job_0_task_5   job_1_task_4   job_2_task_4   job_3_task_4   job_4_task_6   job_5_task_3   job_6_task_3
#            [82,74]        [82,97]        [82,78]        [82,68]        [82,27]        [82,56]        [82,54]
# Machine 5: job_0_task_0   job_1_task_6   job_2_task_5   job_3_task_5   job_4_task_2   job_5_task_4   job_6_task_6
#            [82,86]        [82,47]        [82,50]        [82,9]         [82,48]        [82,37]        [82,73]
# Machine 6: job_0_task_6   job_1_task_0   job_2_task_0   job_3_task_2   job_4_task_4   job_5_task_5   job_6_task_5
#            [82,48]        [82,61]        [82,82]        [82,50]        [82,70]        [82,50]        [82,82]
# Machine 7: job_0_task_3   job_1_task_1   job_2_task_2   job_3_task_1   job_4_task_0   job_5_task_1   job_6_task_1
#            [82,95]        [82,50]        [82,18]        [82,87]        [82,46]        [82,86]        [82,75]
#
# --- 0.03 seconds ---
# This is the list number: 4
# Solution:
# Optimal Schedule Length: 95.0
# Machine 1: job_0_task_1   job_1_task_5   job_2_task_1   job_3_task_0   job_4_task_1   job_5_task_0   job_6_task_5
#            [95,90]        [95,20]        [95,53]        [95,49]        [95,27]        [95,66]        [95,73]
# Machine 2: job_0_task_3   job_1_task_2   job_2_task_5   job_3_task_5   job_4_task_3   job_5_task_4   job_6_task_2
#            [95,62]        [95,7]         [95,99]        [95,48]        [95,33]        [95,70]        [95,8]
# Machine 3: job_0_task_2   job_1_task_0   job_2_task_4   job_3_task_1   job_4_task_0   job_5_task_3   job_6_task_1
#            [95,19]        [95,65]        [95,95]        [95,62]        [95,42]        [95,62]        [95,71]
# Machine 4: job_0_task_4   job_1_task_1   job_2_task_2   job_3_task_6   job_4_task_2   job_5_task_1   job_6_task_4
#            [95,26]        [95,59]        [95,56]        [95,77]        [95,73]        [95,56]        [95,51]
# Machine 5: job_0_task_6   job_1_task_4   job_2_task_6   job_3_task_2   job_4_task_5   job_5_task_2   job_6_task_0
#            [95,80]        [95,74]        [95,45]        [95,12]        [95,38]        [95,76]        [95,55]
# Machine 6: job_0_task_5   job_1_task_3   job_2_task_3   job_3_task_3   job_4_task_6   job_5_task_5   job_6_task_3
#            [95,23]        [95,91]        [95,7]         [95,29]        [95,95]        [95,36]        [95,39]
# Machine 7: job_0_task_0   job_1_task_6   job_2_task_0   job_3_task_4   job_4_task_4   job_5_task_6   job_6_task_6
#            [95,86]        [95,62]        [95,4]         [95,6]         [95,81]        [95,39]        [95,36]
#
# --- 0.01 seconds ---
# This is the list number: 5
# Solution:
# Optimal Schedule Length: 95.0
# Machine 1: job_0_task_1   job_1_task_5   job_2_task_1   job_3_task_6   job_4_task_0   job_5_task_5   job_6_task_5
#            [95,87]        [95,32]        [95,75]        [95,94]        [95,6]         [95,46]        [95,75]
# Machine 2: job_0_task_0   job_1_task_2   job_2_task_6   job_3_task_1   job_4_task_5   job_5_task_4   job_6_task_4
#            [95,76]        [95,59]        [95,61]        [95,39]        [95,46]        [95,64]        [95,93]
# Machine 3: job_0_task_2   job_1_task_0   job_2_task_3   job_3_task_5   job_4_task_4   job_5_task_1   job_6_task_3
#            [95,95]        [95,78]        [95,1]         [95,61]        [95,8]         [95,80]        [95,36]
# Machine 4: job_0_task_6   job_1_task_4   job_2_task_0   job_3_task_4   job_4_task_2   job_5_task_3   job_6_task_6
#            [95,2]         [95,95]        [95,63]        [95,25]        [95,77]        [95,60]        [95,95]
# Machine 5: job_0_task_4   job_1_task_1   job_2_task_2   job_3_task_2   job_4_task_6   job_5_task_0   job_6_task_0
#            [95,55]        [95,57]        [95,87]        [95,89]        [95,24]        [95,60]        [95,76]
# Machine 6: job_0_task_3   job_1_task_6   job_2_task_5   job_3_task_3   job_4_task_3   job_5_task_6   job_6_task_2
#            [95,20]        [95,69]        [95,76]        [95,41]        [95,91]        [95,5]         [95,27]
# Machine 7: job_0_task_5   job_1_task_3   job_2_task_4   job_3_task_0   job_4_task_1   job_5_task_2   job_6_task_1
#            [95,88]        [95,40]        [95,25]        [95,66]        [95,59]        [95,97]        [95,49]
#
# --- 0.04 seconds ---
# This is the list number: 6
# Solution:
# Optimal Schedule Length: 99.0
# Machine 1: job_0_task_2   job_1_task_4   job_2_task_6   job_3_task_4   job_4_task_3   job_5_task_2   job_6_task_0
#            [99,5]         [99,46]        [99,6]         [99,97]        [99,10]        [99,69]        [99,95]
# Machine 2: job_0_task_1   job_1_task_5   job_2_task_2   job_3_task_6   job_4_task_6   job_5_task_3   job_6_task_5
#            [99,9]         [99,30]        [99,81]        [99,93]        [99,99]        [99,63]        [99,34]
# Machine 3: job_0_task_5   job_1_task_1   job_2_task_5   job_3_task_3   job_4_task_1   job_5_task_5   job_6_task_3
#            [99,94]        [99,69]        [99,82]        [99,61]        [99,59]        [99,10]        [99,47]
# Machine 4: job_0_task_3   job_1_task_6   job_2_task_3   job_3_task_5   job_4_task_0   job_5_task_1   job_6_task_2
#            [99,98]        [99,58]        [99,60]        [99,66]        [99,56]        [99,32]        [99,48]
# Machine 5: job_0_task_4   job_1_task_0   job_2_task_1   job_3_task_2   job_4_task_2   job_5_task_4   job_6_task_1
#            [99,76]        [99,59]        [99,64]        [99,10]        [99,19]        [99,71]        [99,87]
# Machine 6: job_0_task_0   job_1_task_2   job_2_task_4   job_3_task_1   job_4_task_4   job_5_task_6   job_6_task_4
#            [99,66]        [99,25]        [99,84]        [99,28]        [99,72]        [99,80]        [99,46]
# Machine 7: job_0_task_6   job_1_task_3   job_2_task_0   job_3_task_0   job_4_task_5   job_5_task_0   job_6_task_6
#            [99,25]        [99,56]        [99,15]        [99,28]        [99,78]        [99,76]        [99,31]
#
# --- 0.01 seconds ---
# This is the list number: 7
# Solution:
# Optimal Schedule Length: 83.0
# Machine 1: job_0_task_5   job_1_task_4   job_2_task_3   job_3_task_1   job_4_task_3   job_5_task_5   job_6_task_5
#            [83,97]        [83,54]        [83,5]         [83,38]        [83,52]        [83,98]        [83,23]
# Machine 2: job_0_task_1   job_1_task_3   job_2_task_2   job_3_task_3   job_4_task_1   job_5_task_2   job_6_task_0
#            [83,20]        [83,42]        [83,50]        [83,96]        [83,61]        [83,17]        [83,58]
# Machine 3: job_0_task_0   job_1_task_0   job_2_task_6   job_3_task_2   job_4_task_2   job_5_task_4   job_6_task_6
#            [83,19]        [83,37]        [83,11]        [83,68]        [83,72]        [83,18]        [83,62]
# Machine 4: job_0_task_3   job_1_task_6   job_2_task_0   job_3_task_0   job_4_task_4   job_5_task_6   job_6_task_1
#            [83,36]        [83,61]        [83,52]        [83,33]        [83,17]        [83,6]         [83,84]
# Machine 5: job_0_task_6   job_1_task_2   job_2_task_4   job_3_task_4   job_4_task_6   job_5_task_0   job_6_task_4
#            [83,83]        [83,48]        [83,57]        [83,79]        [83,58]        [83,2]         [83,81]
# Machine 6: job_0_task_4   job_1_task_5   job_2_task_1   job_3_task_5   job_4_task_5   job_5_task_1   job_6_task_3
#            [83,92]        [83,80]        [83,1]         [83,83]        [83,81]        [83,21]        [83,26]
# Machine 7: job_0_task_2   job_1_task_1   job_2_task_5   job_3_task_6   job_4_task_0   job_5_task_3   job_6_task_2
#            [83,14]        [83,55]        [83,97]        [83,27]        [83,54]        [83,93]        [83,80]
#
# --- 0.05 seconds ---
# This is the list number: 8
# Solution:
# Optimal Schedule Length: 92.0
# Machine 1: job_0_task_6   job_1_task_2   job_2_task_0   job_3_task_3   job_4_task_1   job_5_task_5   job_6_task_5
#            [92,32]        [92,13]        [92,46]        [92,90]        [92,51]        [92,89]        [92,93]
# Machine 2: job_0_task_3   job_1_task_0   job_2_task_2   job_3_task_4   job_4_task_0   job_5_task_6   job_6_task_4
#            [92,67]        [92,72]        [92,94]        [92,50]        [92,37]        [92,47]        [92,31]
# Machine 3: job_0_task_4   job_1_task_4   job_2_task_1   job_3_task_6   job_4_task_5   job_5_task_0   job_6_task_3
#            [92,32]        [92,35]        [92,23]        [92,92]        [92,86]        [92,65]        [92,86]
# Machine 4: job_0_task_2   job_1_task_5   job_2_task_5   job_3_task_0   job_4_task_2   job_5_task_4   job_6_task_2
#            [92,43]        [92,66]        [92,44]        [92,95]        [92,75]        [92,62]        [92,64]
# Machine 5: job_0_task_1   job_1_task_3   job_2_task_6   job_3_task_2   job_4_task_6   job_5_task_2   job_6_task_1
#            [92,71]        [92,41]        [92,15]        [92,69]        [92,13]        [92,63]        [92,62]
# Machine 6: job_0_task_5   job_1_task_6   job_2_task_4   job_3_task_5   job_4_task_4   job_5_task_3   job_6_task_0
#            [92,72]        [92,47]        [92,73]        [92,42]        [92,93]        [92,82]        [92,17]
# Machine 7: job_0_task_0   job_1_task_1   job_2_task_3   job_3_task_1   job_4_task_3   job_5_task_1   job_6_task_6
#            [92,31]        [92,60]        [92,6]         [92,20]        [92,68]        [92,27]        [92,92]
#
# --- 0.01 seconds ---
# This is the list number: 9
# Solution:
# Optimal Schedule Length: 90.0
# Machine 1: job_0_task_6   job_1_task_4   job_2_task_0   job_3_task_4   job_4_task_3   job_5_task_1   job_6_task_5
#            [90,62]        [90,21]        [90,18]        [90,48]        [90,92]        [90,30]        [90,57]
# Machine 2: job_0_task_5   job_1_task_6   job_2_task_5   job_3_task_5   job_4_task_4   job_5_task_2   job_6_task_1
#            [90,42]        [90,90]        [90,75]        [90,1]         [90,61]        [90,70]        [90,21]
# Machine 3: job_0_task_0   job_1_task_0   job_2_task_6   job_3_task_3   job_4_task_0   job_5_task_3   job_6_task_4
#            [90,19]        [90,4]         [90,86]        [90,95]        [90,46]        [90,83]        [90,65]
# Machine 4: job_0_task_2   job_1_task_3   job_2_task_4   job_3_task_2   job_4_task_6   job_5_task_4   job_6_task_6
#            [90,51]        [90,61]        [90,4]         [90,38]        [90,64]        [90,61]        [90,84]
# Machine 5: job_0_task_1   job_1_task_5   job_2_task_3   job_3_task_1   job_4_task_1   job_5_task_0   job_6_task_0
#            [90,94]        [90,92]        [90,78]        [90,57]        [90,6]         [90,40]        [90,21]
# Machine 6: job_0_task_3   job_1_task_1   job_2_task_2   job_3_task_6   job_4_task_5   job_5_task_5   job_6_task_2
#            [90,86]        [90,61]        [90,35]        [90,27]        [90,54]        [90,5]         [90,89]
# Machine 7: job_0_task_4   job_1_task_2   job_2_task_1   job_3_task_0   job_4_task_2   job_5_task_6   job_6_task_3
#            [90,3]         [90,13]        [90,64]        [90,18]        [90,50]        [90,53]        [90,49]
#
# --- 0.04 seconds ---
# --- 0.29 seconds for the file---
# This is the file: tai10_10.txt
# This is the list number: 0
# Solution:
# Optimal Schedule Length: 95.0
# Machine 1: job_0_task_0   job_1_task_9   job_2_task_3   job_3_task_2   job_4_task_0   job_5_task_3   job_6_task_2   job_7_task_7   job_8_task_4   job_9_task_7
#            [95,48]        [95,86]        [95,24]        [95,31]        [95,56]        [95,11]        [95,53]        [95,49]        [95,38]        [95,31]
# Machine 2: job_0_task_3   job_1_task_6   job_2_task_2   job_3_task_1   job_4_task_5   job_5_task_5   job_6_task_8   job_7_task_6   job_8_task_7   job_9_task_1
#            [95,2]         [95,29]        [95,87]        [95,89]        [95,29]        [95,97]        [95,44]        [95,86]        [95,28]        [95,50]
# Machine 3: job_0_task_1   job_1_task_3   job_2_task_4   job_3_task_8   job_4_task_2   job_5_task_1   job_6_task_5   job_7_task_4   job_8_task_8   job_9_task_3
#            [95,96]        [95,96]        [95,70]        [95,62]        [95,72]        [95,62]        [95,44]        [95,55]        [95,39]        [95,41]
# Machine 4: job_0_task_5   job_1_task_8   job_2_task_5   job_3_task_6   job_4_task_6   job_5_task_9   job_6_task_0   job_7_task_2   job_8_task_6   job_9_task_8
#            [95,67]        [95,16]        [95,6]         [95,67]        [95,20]        [95,46]        [95,93]        [95,93]        [95,97]        [95,84]
# Machine 5: job_0_task_9   job_1_task_1   job_2_task_7   job_3_task_4   job_4_task_1   job_5_task_6   job_6_task_9   job_7_task_8   job_8_task_2   job_9_task_5
#            [95,68]        [95,60]        [95,65]        [95,37]        [95,46]        [95,83]        [95,40]        [95,80]        [95,53]        [95,82]
# Machine 6: job_0_task_4   job_1_task_7   job_2_task_9   job_3_task_9   job_4_task_8   job_5_task_0   job_6_task_6   job_7_task_5   job_8_task_0   job_9_task_6
#            [95,47]        [95,57]        [95,86]        [95,69]        [95,12]        [95,55]        [95,33]        [95,29]        [95,94]        [95,83]
# Machine 7: job_0_task_6   job_1_task_5   job_2_task_0   job_3_task_3   job_4_task_9   job_5_task_7   job_6_task_7   job_7_task_3   job_8_task_1   job_9_task_2
#            [95,52]        [95,22]        [95,96]        [95,66]        [95,52]        [95,67]        [95,42]        [95,97]        [95,38]        [95,73]
# Machine 8: job_0_task_8   job_1_task_4   job_2_task_6   job_3_task_5   job_4_task_7   job_5_task_2   job_6_task_3   job_7_task_9   job_8_task_9   job_9_task_0
#            [95,83]        [95,12]        [95,64]        [95,91]        [95,46]        [95,37]        [95,85]        [95,67]        [95,18]        [95,34]
# Machine 9: job_0_task_7   job_1_task_0   job_2_task_1   job_3_task_7   job_4_task_4   job_5_task_4   job_6_task_4   job_7_task_0   job_8_task_5   job_9_task_9
#            [95,69]        [95,92]        [95,38]        [95,71]        [95,8]         [95,86]        [95,95]        [95,3]         [95,6]         [95,95]
# Machine 10: job_0_task_2   job_1_task_2   job_2_task_8   job_3_task_0   job_4_task_3   job_5_task_8   job_6_task_1   job_7_task_1   job_8_task_3   job_9_task_4
#            [95,51]        [95,26]        [95,90]        [95,17]        [95,12]        [95,60]        [95,25]        [95,18]        [95,72]        [95,34]
#
# --- 0.03 seconds ---
# This is the list number: 1
# Solution:
# Optimal Schedule Length: 97.0
# Machine 1: job_0_task_5   job_1_task_4   job_2_task_5   job_3_task_4   job_4_task_6   job_5_task_1   job_6_task_7   job_7_task_7   job_8_task_9   job_9_task_8
#            [97,77]        [97,81]        [97,43]        [97,75]        [97,67]        [97,45]        [97,51]        [97,87]        [97,16]        [97,46]
# Machine 2: job_0_task_7   job_1_task_9   job_2_task_9   job_3_task_9   job_4_task_3   job_5_task_4   job_6_task_0   job_7_task_1   job_8_task_1   job_9_task_7
#            [97,30]        [97,64]        [97,51]        [97,2]         [97,14]        [97,76]        [97,84]        [97,68]        [97,50]        [97,73]
# Machine 3: job_0_task_9   job_1_task_6   job_2_task_6   job_3_task_3   job_4_task_5   job_5_task_8   job_6_task_4   job_7_task_2   job_8_task_3   job_9_task_4
#            [97,97]        [97,12]        [97,53]        [97,66]        [97,58]        [97,59]        [97,33]        [97,33]        [97,2]         [97,18]
# Machine 4: job_0_task_2   job_1_task_3   job_2_task_4   job_3_task_7   job_4_task_8   job_5_task_6   job_6_task_2   job_7_task_9   job_8_task_5   job_9_task_9
#            [97,36]        [97,88]        [97,46]        [97,13]        [97,65]        [97,51]        [97,28]        [97,10]        [97,54]        [97,61]
# Machine 5: job_0_task_1   job_1_task_2   job_2_task_7   job_3_task_2   job_4_task_9   job_5_task_9   job_6_task_3   job_7_task_3   job_8_task_4   job_9_task_1
#            [97,97]        [97,45]        [97,49]        [97,93]        [97,55]        [97,32]        [97,89]        [97,82]        [97,4]         [97,19]
# Machine 6: job_0_task_4   job_1_task_1   job_2_task_3   job_3_task_6   job_4_task_2   job_5_task_7   job_6_task_6   job_7_task_0   job_8_task_0   job_9_task_5
#            [97,36]        [97,26]        [97,31]        [97,71]        [97,88]        [97,4]         [97,6]         [97,86]        [97,17]        [97,55]
# Machine 7: job_0_task_8   job_1_task_0   job_2_task_0   job_3_task_8   job_4_task_0   job_5_task_2   job_6_task_5   job_7_task_4   job_8_task_7   job_9_task_0
#            [97,51]        [97,98]        [97,73]        [97,21]        [97,91]        [97,36]        [97,10]        [97,91]        [97,18]        [97,29]
# Machine 8: job_0_task_0   job_1_task_5   job_2_task_8   job_3_task_0   job_4_task_1   job_5_task_0   job_6_task_1   job_7_task_5   job_8_task_2   job_9_task_3
#            [97,95]        [97,3]         [97,39]        [97,4]         [97,15]        [97,38]        [97,76]        [97,87]        [97,23]        [97,88]
# Machine 9: job_0_task_3   job_1_task_7   job_2_task_2   job_3_task_1   job_4_task_7   job_5_task_5   job_6_task_9   job_7_task_6   job_8_task_8   job_9_task_6
#            [97,18]        [97,90]        [97,9]         [97,57]        [97,29]        [97,46]        [97,93]        [97,23]        [97,83]        [97,53]
# Machine 10: job_0_task_6   job_1_task_8   job_2_task_1   job_3_task_5   job_4_task_4   job_5_task_3   job_6_task_8   job_7_task_8   job_8_task_6   job_9_task_2
#            [97,50]        [97,6]         [97,87]        [97,95]        [97,22]        [97,96]        [97,3]         [97,14]        [97,59]        [97,14]
#
# --- 0.02 seconds ---
# This is the list number: 2
# Solution:
# Optimal Schedule Length: 77.0
# Machine 1: job_0_task_9   job_1_task_3   job_2_task_5   job_3_task_3   job_4_task_6   job_5_task_3   job_6_task_6   job_7_task_6   job_8_task_9   job_9_task_9
#            [77,9]         [77,82]        [77,45]        [77,86]        [77,8]         [77,97]        [77,21]        [77,38]        [77,24]        [77,77]
# Machine 2: job_0_task_4   job_1_task_5   job_2_task_8   job_3_task_9   job_4_task_3   job_5_task_0   job_6_task_7   job_7_task_1   job_8_task_0   job_9_task_7
#            [77,58]        [77,72]        [77,44]        [77,59]        [77,35]        [77,63]        [77,36]        [77,25]        [77,32]        [77,4]
# Machine 3: job_0_task_5   job_1_task_4   job_2_task_0   job_3_task_8   job_4_task_1   job_5_task_9   job_6_task_8   job_7_task_7   job_8_task_3   job_9_task_1
#            [77,75]        [77,4]         [77,48]        [77,1]         [77,41]        [77,16]        [77,46]        [77,68]        [77,66]        [77,93]
# Machine 4: job_0_task_1   job_1_task_2   job_2_task_2   job_3_task_4   job_4_task_9   job_5_task_1   job_6_task_2   job_7_task_8   job_8_task_4   job_9_task_2
#            [77,23]        [77,81]        [77,4]         [77,83]        [77,16]        [77,91]        [77,70]        [77,92]        [77,69]        [77,2]
# Machine 5: job_0_task_2   job_1_task_9   job_2_task_1   job_3_task_5   job_4_task_5   job_5_task_6   job_6_task_5   job_7_task_4   job_8_task_1   job_9_task_8
#            [77,91]        [77,76]        [77,52]        [77,72]        [77,18]        [77,45]        [77,47]        [77,25]        [77,52]        [77,85]
# Machine 6: job_0_task_3   job_1_task_0   job_2_task_3   job_3_task_6   job_4_task_8   job_5_task_5   job_6_task_0   job_7_task_9   job_8_task_5   job_9_task_0
#            [77,63]        [77,73]        [77,99]        [77,49]        [77,90]        [77,25]        [77,13]        [77,10]        [77,46]        [77,45]
# Machine 7: job_0_task_6   job_1_task_8   job_2_task_9   job_3_task_0   job_4_task_7   job_5_task_4   job_6_task_1   job_7_task_2   job_8_task_7   job_9_task_6
#            [77,99]        [77,39]        [77,23]        [77,62]        [77,16]        [77,87]        [77,15]        [77,80]        [77,74]        [77,65]
# Machine 8: job_0_task_0   job_1_task_6   job_2_task_6   job_3_task_1   job_4_task_2   job_5_task_2   job_6_task_9   job_7_task_5   job_8_task_6   job_9_task_3
#            [77,37]        [77,20]        [77,49]        [77,91]        [77,86]        [77,79]        [77,33]        [77,56]        [77,62]        [77,39]
# Machine 9: job_0_task_8   job_1_task_7   job_2_task_7   job_3_task_2   job_4_task_0   job_5_task_8   job_6_task_4   job_7_task_0   job_8_task_8   job_9_task_4
#            [77,28]        [77,73]        [77,36]        [77,15]        [77,46]        [77,71]        [77,6]         [77,32]        [77,50]        [77,43]
# Machine 10: job_0_task_7   job_1_task_1   job_2_task_4   job_3_task_7   job_4_task_4   job_5_task_7   job_6_task_3   job_7_task_3   job_8_task_2   job_9_task_5
#            [77,75]        [77,61]        [77,68]        [77,80]        [77,71]        [77,22]        [77,39]        [77,77]        [77,25]        [77,74]
#
# --- 0.06 seconds ---
# This is the list number: 3
# Solution:
# Optimal Schedule Length: 91.0
# Machine 1: job_0_task_6   job_1_task_5   job_2_task_3   job_3_task_9   job_4_task_3   job_5_task_7   job_6_task_5   job_7_task_0   job_8_task_0   job_9_task_9
#            [91,8]         [91,24]        [91,53]        [91,91]        [91,86]        [91,48]        [91,16]        [91,45]        [91,11]        [91,81]
# Machine 2: job_0_task_2   job_1_task_2   job_2_task_2   job_3_task_8   job_4_task_1   job_5_task_6   job_6_task_6   job_7_task_8   job_8_task_4   job_9_task_1
#            [91,61]        [91,84]        [91,83]        [91,35]        [91,41]        [91,21]        [91,4]         [91,94]        [91,83]        [91,71]
# Machine 3: job_0_task_9   job_1_task_8   job_2_task_6   job_3_task_0   job_4_task_8   job_5_task_3   job_6_task_3   job_7_task_2   job_8_task_7   job_9_task_7
#            [91,19]        [91,98]        [91,27]        [91,15]        [91,97]        [91,42]        [91,29]        [91,22]        [91,97]        [91,56]
# Machine 4: job_0_task_3   job_1_task_4   job_2_task_7   job_3_task_6   job_4_task_4   job_5_task_8   job_6_task_1   job_7_task_7   job_8_task_6   job_9_task_6
#            [91,50]        [91,83]        [91,93]        [91,18]        [91,7]         [91,98]        [91,59]        [91,36]        [91,37]        [91,89]
# Machine 5: job_0_task_1   job_1_task_7   job_2_task_1   job_3_task_3   job_4_task_5   job_5_task_5   job_6_task_0   job_7_task_5   job_8_task_9   job_9_task_3
#            [91,16]        [91,60]        [91,70]        [91,55]        [91,30]        [91,22]        [91,52]        [91,74]        [91,34]        [91,33]
# Machine 6: job_0_task_5   job_1_task_0   job_2_task_8   job_3_task_7   job_4_task_9   job_5_task_0   job_6_task_9   job_7_task_1   job_8_task_5   job_9_task_5
#            [91,69]        [91,13]        [91,95]        [91,50]        [91,75]        [91,7]         [91,46]        [91,37]        [91,67]        [91,1]
# Machine 7: job_0_task_0   job_1_task_1   job_2_task_4   job_3_task_1   job_4_task_2   job_5_task_2   job_6_task_8   job_7_task_9   job_8_task_2   job_9_task_4
#            [91,91]        [91,35]        [91,12]        [91,29]        [91,15]        [91,3]         [91,22]        [91,76]        [91,55]        [91,15]
# Machine 8: job_0_task_8   job_1_task_9   job_2_task_9   job_3_task_5   job_4_task_0   job_5_task_1   job_6_task_4   job_7_task_6   job_8_task_3   job_9_task_8
#            [91,44]        [91,40]        [91,29]        [91,97]        [91,20]        [91,5]         [91,67]        [91,19]        [91,25]        [91,53]
# Machine 9: job_0_task_7   job_1_task_6   job_2_task_0   job_3_task_2   job_4_task_6   job_5_task_4   job_6_task_7   job_7_task_4   job_8_task_8   job_9_task_2
#            [91,61]        [91,81]        [91,44]        [91,39]        [91,33]        [91,26]        [91,79]        [91,94]        [91,32]        [91,72]
# Machine 10: job_0_task_4   job_1_task_3   job_2_task_5   job_3_task_4   job_4_task_7   job_5_task_9   job_6_task_2   job_7_task_3   job_8_task_1   job_9_task_0
#            [91,59]        [91,26]        [91,48]        [91,84]        [91,51]        [91,40]        [91,45]        [91,7]         [91,35]        [91,50]
#
# --- 0.03 seconds ---
# This is the list number: 4
# Solution:
# Optimal Schedule Length: 98.0
# Machine 1: job_0_task_3   job_1_task_2   job_2_task_7   job_3_task_1   job_4_task_8   job_5_task_4   job_6_task_0   job_7_task_5   job_8_task_2   job_9_task_0
#            [98,23]        [98,69]        [98,66]        [98,87]        [98,57]        [98,33]        [98,91]        [98,34]        [98,54]        [98,32]
# Machine 2: job_0_task_9   job_1_task_0   job_2_task_6   job_3_task_2   job_4_task_0   job_5_task_2   job_6_task_3   job_7_task_8   job_8_task_3   job_9_task_7
#            [98,52]        [98,1]         [98,40]        [98,48]        [98,17]        [98,44]        [98,96]        [98,64]        [98,33]        [98,72]
# Machine 3: job_0_task_0   job_1_task_8   job_2_task_2   job_3_task_7   job_4_task_6   job_5_task_8   job_6_task_8   job_7_task_0   job_8_task_6   job_9_task_8
# ...
# Machine 16: job_0_task_0   job_1_task_1   job_2_task_7   job_3_task_3   job_4_task_5   job_5_task_1   job_6_task_17  job_7_task_15  job_8_task_7   job_9_task_11  job_10_task_15 job_11_task_16 job_12_task_11 job_13_task_15 job_14_task_14 job_15_task_14 job_16_task_8  job_17_task_7  job_18_task_6  job_19_task_12
#            [91,73]        [91,79]        [91,2]         [91,59]        [91,71]        [91,52]        [91,38]        [91,28]        [91,97]        [91,29]        [91,31]        [91,14]        [91,78]        [91,89]        [91,10]        [91,25]        [91,6]         [91,65]        [91,54]        [91,99]
# Machine 17: job_0_task_12  job_1_task_14  job_2_task_9   job_3_task_17  job_4_task_0   job_5_task_14  job_6_task_4   job_7_task_16  job_8_task_11  job_9_task_13  job_10_task_9  job_11_task_15 job_12_task_17 job_13_task_8  job_14_task_12 job_15_task_4  job_16_task_1  job_17_task_16 job_18_task_17 job_19_task_17
#            [91,43]        [91,35]        [91,26]        [91,48]        [91,43]        [91,58]        [91,15]        [91,18]        [91,26]        [91,96]        [91,42]        [91,23]        [91,80]        [91,7]         [91,71]        [91,18]        [91,67]        [91,91]        [91,89]        [91,73]
# Machine 18: job_0_task_1   job_1_task_8   job_2_task_15  job_3_task_19  job_4_task_2   job_5_task_13  job_6_task_14  job_7_task_17  job_8_task_8   job_9_task_7   job_10_task_17 job_11_task_19 job_12_task_15 job_13_task_12 job_14_task_0  job_15_task_16 job_16_task_6  job_17_task_0  job_18_task_14 job_19_task_2
#            [91,56]        [91,7]         [91,76]        [91,31]        [91,49]        [91,20]        [91,82]        [91,33]        [91,1]         [91,77]        [91,95]        [91,19]        [91,27]        [91,66]        [91,69]        [91,63]        [91,18]        [91,82]        [91,8]         [91,79]
# Machine 19: job_0_task_8   job_1_task_0   job_2_task_1   job_3_task_6   job_4_task_1   job_5_task_18  job_6_task_1   job_7_task_12  job_8_task_18  job_9_task_3   job_10_task_0  job_11_task_7  job_12_task_14 job_13_task_2  job_14_task_1  job_15_task_1  job_16_task_18 job_17_task_2  job_18_task_13 job_19_task_16
#            [91,44]        [91,77]        [91,1]         [91,27]        [91,2]         [91,49]        [91,9]         [91,14]        [91,6]         [91,96]        [91,85]        [91,4]         [91,70]        [91,95]        [91,19]        [91,11]        [91,18]        [91,46]        [91,93]        [91,77]
# Machine 20: job_0_task_3   job_1_task_16  job_2_task_12  job_3_task_5   job_4_task_18  job_5_task_10  job_6_task_19  job_7_task_10  job_8_task_5   job_9_task_19  job_10_task_16 job_11_task_6  job_12_task_18 job_13_task_9  job_14_task_7  job_15_task_11 job_16_task_13 job_17_task_9  job_18_task_19 job_19_task_7
#            [91,7]         [91,84]        [91,55]        [91,8]         [91,49]        [91,37]        [91,46]        [91,90]        [91,90]        [91,65]        [91,64]        [91,19]        [91,33]        [91,28]        [91,98]        [91,54]        [91,17]        [91,26]        [91,59]        [91,73]
#
# --- 0.20 seconds ---
# This is the list number: 9
# Solution:
# Optimal Schedule Length: 99.0
# Machine 1: job_0_task_17  job_1_task_17  job_2_task_3   job_3_task_3   job_4_task_12  job_5_task_11  job_6_task_19  job_7_task_8   job_8_task_13  job_9_task_9   job_10_task_1  job_11_task_17 job_12_task_0  job_13_task_18 job_14_task_19 job_15_task_8  job_16_task_14 job_17_task_16 job_18_task_5  job_19_task_14
#            [99,15]        [99,70]        [99,6]         [99,33]        [99,47]        [99,19]        [99,60]        [99,87]        [99,55]        [99,36]        [99,97]        [99,49]        [99,2]         [99,10]        [99,72]        [99,7]         [99,83]        [99,72]        [99,61]        [99,88]
# Machine 2: job_0_task_13  job_1_task_9   job_2_task_9   job_3_task_2   job_4_task_11  job_5_task_4   job_6_task_13  job_7_task_14  job_8_task_6   job_9_task_16  job_10_task_19 job_11_task_0  job_12_task_7  job_13_task_1  job_14_task_17 job_15_task_13 job_16_task_7  job_17_task_6  job_18_task_6  job_19_task_4
#            [99,49]        [99,27]        [99,13]        [99,67]        [99,83]        [99,17]        [99,32]        [99,27]        [99,78]        [99,96]        [99,65]        [99,64]        [99,36]        [99,84]        [99,82]        [99,17]        [99,7]         [99,96]        [99,89]        [99,21]
# Machine 3: job_0_task_11  job_1_task_11  job_2_task_12  job_3_task_1   job_4_task_14  job_5_task_17  job_6_task_8   job_7_task_10  job_8_task_4   job_9_task_4   job_10_task_18 job_11_task_16 job_12_task_12 job_13_task_15 job_14_task_6  job_15_task_19 job_16_task_3  job_17_task_17 job_18_task_2  job_19_task_11
#            [99,12]        [99,77]        [99,47]        [99,28]        [99,77]        [99,39]        [99,14]        [99,93]        [99,26]        [99,52]        [99,57]        [99,28]        [99,21]        [99,72]        [99,80]        [99,85]        [99,63]        [99,17]        [99,44]        [99,86]
# Machine 4: job_0_task_14  job_1_task_7   job_2_task_19  job_3_task_13  job_4_task_7   job_5_task_19  job_6_task_0   job_7_task_15  job_8_task_5   job_9_task_8   job_10_task_4  job_11_task_4  job_12_task_3  job_13_task_5  job_14_task_4  job_15_task_2  job_16_task_8  job_17_task_18 job_18_task_7  job_19_task_7
#            [99,98]        [99,94]        [99,21]        [99,87]        [99,73]        [99,26]        [99,57]        [99,47]        [99,91]        [99,2]         [99,11]        [99,35]        [99,40]        [99,6]         [99,89]        [99,48]        [99,38]        [99,26]        [99,93]        [99,25]
# Machine 5: job_0_task_2   job_1_task_19  job_2_task_13  job_3_task_12  job_4_task_19  job_5_task_5   job_6_task_5   job_7_task_12  job_8_task_11  job_9_task_3   job_10_task_14 job_11_task_11 job_12_task_15 job_13_task_12 job_14_task_7  job_15_task_14 job_16_task_15 job_17_task_9  job_18_task_10 job_19_task_6
#            [99,15]        [99,91]        [99,59]        [99,88]        [99,8]         [99,64]        [99,83]        [99,91]        [99,73]        [99,42]        [99,80]        [99,92]        [99,20]        [99,65]        [99,65]        [99,5]         [99,8]         [99,29]        [99,60]        [99,19]
# Machine 6: job_0_task_19  job_1_task_4   job_2_task_14  job_3_task_4   job_4_task_9   job_5_task_13  job_6_task_4   job_7_task_19  job_8_task_8   job_9_task_2   job_10_task_6  job_11_task_8  job_12_task_8  job_13_task_11 job_14_task_2  job_15_task_16 job_16_task_16 job_17_task_0  job_18_task_3  job_19_task_16
#            [99,10]        [99,92]        [99,30]        [99,54]        [99,41]        [99,77]        [99,21]        [99,84]        [99,26]        [99,54]        [99,29]        [99,12]        [99,82]        [99,81]        [99,84]        [99,72]        [99,33]        [99,49]        [99,34]        [99,65]
# Machine 7: job_0_task_0   job_1_task_14  job_2_task_8   job_3_task_18  job_4_task_16  job_5_task_8   job_6_task_2   job_7_task_13  job_8_task_9   job_9_task_14  job_10_task_8  job_11_task_7  job_12_task_2  job_13_task_16 job_14_task_8  job_15_task_10 job_16_task_11 job_17_task_5  job_18_task_13 job_19_task_2
#            [99,98]        [99,28]        [99,92]        [99,80]        [99,9]         [99,17]        [99,37]        [99,90]        [99,55]        [99,69]        [99,41]        [99,19]        [99,56]        [99,7]         [99,40]        [99,45]        [99,90]        [99,53]        [99,46]        [99,12]
# Machine 8: job_0_task_8   job_1_task_2   job_2_task_6   job_3_task_0   job_4_task_8   job_5_task_18  job_6_task_3   job_7_task_3   job_8_task_1   job_9_task_5   job_10_task_5  job_11_task_12 job_12_task_1  job_13_task_4  job_14_task_16 job_15_task_9  job_16_task_2  job_17_task_11 job_18_task_19 job_19_task_15
#            [99,85]        [99,76]        [99,75]        [99,36]        [99,97]        [99,74]        [99,69]        [99,10]        [99,54]        [99,59]        [99,89]        [99,13]        [99,47]        [99,77]        [99,11]        [99,26]        [99,50]        [99,18]        [99,97]        [99,20]
# Machine 9: job_0_task_6   job_1_task_0   job_2_task_11  job_3_task_19  job_4_task_13  job_5_task_14  job_6_task_7   job_7_task_4   job_8_task_12  job_9_task_15  job_10_task_10 job_11_task_9  job_12_task_17 job_13_task_7  job_14_task_18 job_15_task_1  job_16_task_5  job_17_task_15 job_18_task_1  job_19_task_5
#            [99,47]        [99,50]        [99,69]        [99,9]         [99,92]        [99,16]        [99,85]        [99,2]         [99,29]        [99,33]        [99,53]        [99,61]        [99,2]         [99,72]        [99,60]        [99,65]        [99,73]        [99,2]         [99,67]        [99,61]
# Machine 10: job_0_task_16  job_1_task_18  job_2_task_2   job_3_task_9   job_4_task_3   job_5_task_10  job_6_task_16  job_7_task_2   job_8_task_14  job_9_task_13  job_10_task_16 job_11_task_10 job_12_task_14 job_13_task_10 job_14_task_12 job_15_task_0  job_16_task_10 job_17_task_8  job_18_task_11 job_19_task_9
#            [99,5]         [99,59]        [99,27]        [99,24]        [99,8]         [99,77]        [99,30]        [99,47]        [99,24]        [99,25]        [99,33]        [99,72]        [99,83]        [99,27]        [99,10]        [99,30]        [99,5]         [99,69]        [99,86]        [99,92]
# Machine 11: job_0_task_5   job_1_task_15  job_2_task_10  job_3_task_10  job_4_task_6   job_5_task_12  job_6_task_6   job_7_task_5   job_8_task_15  job_9_task_1   job_10_task_7  job_11_task_13 job_12_task_4  job_13_task_9  job_14_task_11 job_15_task_7  job_16_task_12 job_17_task_14 job_18_task_0  job_19_task_10
#            [99,98]        [99,69]        [99,61]        [99,76]        [99,86]        [99,56]        [99,89]        [99,77]        [99,94]        [99,32]        [99,57]        [99,12]        [99,25]        [99,82]        [99,12]        [99,63]        [99,29]        [99,80]        [99,13]        [99,53]
# Machine 12: job_0_task_7   job_1_task_3   job_2_task_0   job_3_task_6   job_4_task_5   job_5_task_3   job_6_task_11  job_7_task_18  job_8_task_17  job_9_task_18  job_10_task_9  job_11_task_14 job_12_task_19 job_13_task_19 job_14_task_9  job_15_task_3  job_16_task_6  job_17_task_7  job_18_task_8  job_19_task_3
#            [99,49]        [99,15]        [99,73]        [99,47]        [99,64]        [99,89]        [99,29]        [99,75]        [99,51]        [99,36]        [99,52]        [99,77]        [99,99]        [99,21]        [99,8]         [99,81]        [99,63]        [99,69]        [99,59]        [99,87]
# Machine 13: job_0_task_4   job_1_task_1   job_2_task_18  job_3_task_16  job_4_task_0   job_5_task_15  job_6_task_12  job_7_task_0   job_8_task_19  job_9_task_10  job_10_task_17 job_11_task_5  job_12_task_9  job_13_task_0  job_14_task_13 job_15_task_15 job_16_task_9  job_17_task_4  job_18_task_16 job_19_task_13
#            [99,78]        [99,92]        [99,46]        [99,90]        [99,9]         [99,14]        [99,90]        [99,66]        [99,1]         [99,43]        [99,92]        [99,23]        [99,7]         [99,92]        [99,85]        [99,51]        [99,81]        [99,42]        [99,77]        [99,13]
# Machine 14: job_0_task_12  job_1_task_10  job_2_task_7   job_3_task_8   job_4_task_15  job_5_task_6   job_6_task_10  job_7_task_1   job_8_task_3   job_9_task_7   job_10_task_15 job_11_task_6  job_12_task_5  job_13_task_13 job_14_task_5  job_15_task_5  job_16_task_17 job_17_task_10 job_18_task_12 job_19_task_0
#            [99,28]        [99,94]        [99,30]        [99,72]        [99,49]        [99,87]        [99,42]        [99,13]        [99,58]        [99,83]        [99,39]        [99,8]         [99,46]        [99,74]        [99,19]        [99,26]        [99,95]        [99,67]        [99,40]        [99,40]
# Machine 15: job_0_task_9   job_1_task_8   job_2_task_5   job_3_task_7   job_4_task_4   job_5_task_0   job_6_task_17  job_7_task_7   job_8_task_7   job_9_task_11  job_10_task_13 job_11_task_15 job_12_task_16 job_13_task_6  job_14_task_3  job_15_task_4  job_16_task_0  job_17_task_2  job_18_task_15 job_19_task_19
#            [99,9]         [99,41]        [99,11]        [99,10]        [99,98]        [99,96]        [99,62]        [99,83]        [99,36]        [99,74]        [99,28]        [99,64]        [99,5]         [99,96]        [99,2]         [99,72]        [99,53]        [99,31]        [99,88]        [99,71]
# Machine 16: job_0_task_1   job_1_task_5   job_2_task_1   job_3_task_11  job_4_task_17  job_5_task_9   job_6_task_18  job_7_task_6   job_8_task_16  job_9_task_17  job_10_task_0  job_11_task_1  job_12_task_11 job_13_task_8  job_14_task_14 job_15_task_6  job_16_task_4  job_17_task_3  job_18_task_4  job_19_task_18
#            [99,49]        [99,45]        [99,64]        [99,97]        [99,22]        [99,82]        [99,87]        [99,27]        [99,79]        [99,76]        [99,78]        [99,13]        [99,59]        [99,19]        [99,68]        [99,18]        [99,39]        [99,99]        [99,17]        [99,43]
# Machine 17: job_0_task_15  job_1_task_13  job_2_task_17  job_3_task_17  job_4_task_18  job_5_task_2   job_6_task_14  job_7_task_9   job_8_task_10  job_9_task_19  job_10_task_12 job_11_task_18 job_12_task_13 job_13_task_17 job_14_task_0  job_15_task_11 job_16_task_13 job_17_task_12 job_18_task_9  job_19_task_17
#            [99,63]        [99,67]        [99,1]         [99,83]        [99,58]        [99,27]        [99,1]         [99,21]        [99,98]        [99,87]        [99,80]        [99,24]        [99,96]        [99,61]        [99,7]         [99,28]        [99,23]        [99,62]        [99,17]        [99,43]
# Machine 18: job_0_task_18  job_1_task_16  job_2_task_4   job_3_task_5   job_4_task_10  job_5_task_1   job_6_task_1   job_7_task_16  job_8_task_2   job_9_task_0   job_10_task_3  job_11_task_19 job_12_task_6  job_13_task_2  job_14_task_15 job_15_task_18 job_16_task_1  job_17_task_1  job_18_task_14 job_19_task_1
#            [99,4]         [99,53]        [99,7]         [99,72]        [99,46]        [99,34]        [99,72]        [99,4]         [99,8]         [99,54]        [99,87]        [99,15]        [99,55]        [99,16]        [99,87]        [99,31]        [99,85]        [99,38]        [99,78]        [99,44]
# Machine 19: job_0_task_10  job_1_task_6   job_2_task_15  job_3_task_15  job_4_task_1   job_5_task_7   job_6_task_15  job_7_task_17  job_8_task_18  job_9_task_12  job_10_task_2  job_11_task_3  job_12_task_10 job_13_task_14 job_14_task_10 job_15_task_17 job_16_task_18 job_17_task_13 job_18_task_17 job_19_task_8
#            [99,22]        [99,19]        [99,13]        [99,96]        [99,2]         [99,91]        [99,73]        [99,42]        [99,56]        [99,21]        [99,48]        [99,19]        [99,91]        [99,33]        [99,22]        [99,61]        [99,79]        [99,25]        [99,18]        [99,26]
# Machine 20: job_0_task_3   job_1_task_12  job_2_task_16  job_3_task_14  job_4_task_2   job_5_task_16  job_6_task_9   job_7_task_11  job_8_task_0   job_9_task_6   job_10_task_11 job_11_task_2  job_12_task_18 job_13_task_3  job_14_task_1  job_15_task_12 job_16_task_19 job_17_task_19 job_18_task_18 job_19_task_12
#            [99,92]        [99,4]         [99,37]        [99,92]        [99,64]        [99,61]        [99,32]        [99,18]        [99,26]        [99,88]        [99,24]        [99,49]        [99,41]        [99,71]        [99,10]        [99,94]        [99,51]        [99,75]        [99,96]        [99,57]
#
# --- 0.22 seconds ---
# --- 1.93 seconds for the file---
# --- 4.00 seconds for the cell---
