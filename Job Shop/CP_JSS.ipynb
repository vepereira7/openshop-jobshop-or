# %%
# Description: Job Shop Scheduling Problem using Constraint Programming
# import the necessary classes
import pandas as pd
import numpy as np
import time
from ortools.constraint_solver import pywrapcp
import collections
from ortools.sat.python import cp_model
from ortools.constraint_solver.pywrapcp import IntervalVar 
from ortools.init import pywrapinit
import pandas as pd

# %%
def extract_data(filename):
    # Initialize variables to store the data.
    nj = []
    nm = []
    times = []
    machines = []


    # Open the file and read each line.
    with open(filename, 'r') as file:
        contents = file.read()
        lines = contents.splitlines()
        # Iterate through each line to find the number of jobs and machines.
        for line in range(len(lines)):
            # Check if the line contains the number of jobs and machines.
            if 'Nb of jobs' in lines[line]:
                nj.append(lines[line + 1].split()[0])
                nm.append(lines[line + 1].split()[1])
            break
        num_jobs = int(nj[0])
        num_machines = int(nm[0])
        for line in range(len(lines)):
            # Check if the line contains the number of jobs and machines.
            if 'Nb of jobs' in lines[line]:
                continue
            if ' ' in lines[line]:
                continue
            elif 'Times' in lines[line]:
                pos = int(0)
                while pos < num_jobs:
                    pos += 1
                    times.append(lines[line + pos].split())
        for line in range(len(lines)):
            if 'Nb of jobs' in lines[line]:
                continue
            if ' ' in lines[line]:
                continue
            if 'Times' in lines[line]:
                continue
            elif 'Machines' in lines[line]:
                pos = int(0)
                while pos < num_jobs:
                    pos +=1
                    machines.append(lines[line + pos].split())
        # Having extracted the data, we now need to convert the data into a format that can be used by the solver.
        # We will convert the data into a list of lists.
        # The first list will contain the number of jobs and the number of machines.
        # The second list will contain the processing times.
        # The third is a list of the combination of jobs and machines.
        # The final input will be a list of lists in the respective order required by the solver.
            # Desired output
                ### List - 1º Level  - Size 10
                ### List - 2º Level  - Size 50
                ### List - 3º Level  - Size 15
                ### List - 4º Level  - Size 2

        list1 = times
        list2 = machines
        list = [(int(x), int(y)) for sublist1, sublist2 in zip(list2, list1) for x, y in zip(sublist2, sublist1)]
        new_list = [i for i in range(1, len(list)+1)]
    
        for i, (x, y) in enumerate(list):
            new_list[i] = [(x, y)]
        num_elements = num_jobs*num_machines
        small_lists = [new_list[i:i + num_elements] for i in range(0, len(new_list), num_elements)]
        smaller_lists = [i for i in range(len(small_lists))]
        for i in range(len(small_lists)):
            smaller_lists[i] = [small_lists[i][j:j + num_machines] for j in range(0, len(small_lists[i]), num_machines)]
        for i in range(len(smaller_lists)):
            for j in range(len(smaller_lists[i])):
                for k in range(len(smaller_lists[i][j])):
                    for l in range(len(smaller_lists[i][j][k])):
                        smaller_lists[i][j][k] = smaller_lists[i][j][k][l]
                        smaller_lists[i][j][k] = tuple(reversed(smaller_lists[i][j][k]))
        return ( num_jobs, num_machines,smaller_lists)

# %%
num_jobs, num_machines, smaller_lists = extract_data('tai15_15.txt')

# %%
# Check the size of the list if it is the correct size as expected for the file selected.
print(len(smaller_lists))
print(len(smaller_lists[0]))
print(len(smaller_lists[0][0]))
print(len(smaller_lists[0][0][0]))
# Out:
# 10
# 15
# 15
# 2

# %%
def main(jobs_data):
    """Entry point of the program."""
    machines_count = 1 + max(task[0] for job in jobs_data for task in job)
    all_machines = range(1,machines_count)
    # Computes horizon dynamically as the sum of all durations.
    horizon = sum(task[1] for job in jobs_data for task in job)

    # Create the model.
    model = cp_model.CpModel()

    # Named tuple to store information about created variables.
    task_type = collections.namedtuple('task_type', 'start end interval')
    # Named tuple to manipulate solution information.
    assigned_task_type = collections.namedtuple('assigned_task_type',
                                                'start job index duration')

    # Creates job intervals and add to the corresponding machine lists.
    all_tasks = {}
    machine_to_intervals = collections.defaultdict(list)

    for job_id, job in enumerate(jobs_data):
        for task_id, task in enumerate(job):
            machine = task[0]
            duration = task[1]
            suffix = '_%i_%i' % (job_id, task_id)
            start_var = model.NewIntVar(0, horizon, 'start' + suffix)
            end_var = model.NewIntVar(0, horizon, 'end' + suffix)
            interval_var = model.NewIntervalVar(start_var, duration, end_var,
                                                'interval' + suffix)
            all_tasks[job_id, task_id] = task_type(start=start_var,
                                                   end=end_var,
                                                   interval=interval_var)
            machine_to_intervals[machine].append(interval_var)

    # Create and add disjunctive constraints.
    for machine in all_machines:
        model.AddNoOverlap(machine_to_intervals[machine])

    # Precedences inside a job.
    for job_id, job in enumerate(jobs_data):
        for task_id in range(len(job) - 1):
            model.Add(all_tasks[job_id, task_id +
                                1].start >= all_tasks[job_id, task_id].end)

    # Makespan objective.
    obj_var = model.NewIntVar(0, horizon, 'makespan')
    model.AddMaxEquality(obj_var, [
        all_tasks[job_id, len(job) - 1].end
        for job_id, job in enumerate(jobs_data)
    ])
    model.Minimize(obj_var)

    # Creates the solver and solve.
    solver = cp_model.CpSolver()
    solver.parameters.max_time_in_seconds = 60.0 
    solver.parameters.num_search_workers = 8
    solver.parameters.log_search_progress = True
    status = solver.Solve(model)

    if status == cp_model.OPTIMAL or status == cp_model.FEASIBLE:
        print('Solution:')
        # Create one list of assigned tasks per machine.
        assigned_jobs = collections.defaultdict(list)
        for job_id, job in enumerate(jobs_data):
            for task_id, task in enumerate(job):
                machine = task[0]
                assigned_jobs[machine].append(
                    assigned_task_type(start=solver.Value(
                        all_tasks[job_id, task_id].start),
                                       job=job_id,
                                       index=task_id,
                                       duration=task[1]))

        # Create per machine output lines.
        output = ''
        for machine in all_machines:
            # Sort by starting time.
            assigned_jobs[machine].sort()
            sol_line_tasks = 'Machine ' + str(machine) + ': '
            sol_line = '           '

            for assigned_task in assigned_jobs[machine]:
                name = 'job_%i_task_%i' % (assigned_task.job,
                                           assigned_task.index)
                # Add spaces to output to align columns.
                sol_line_tasks += '%-15s' % name

                start = assigned_task.start
                duration = assigned_task.duration
                sol_tmp = '[%i,%i]' % (start, start + duration)
                # Add spaces to output to align columns.
                sol_line += '%-15s' % sol_tmp

            sol_line += '\n'
            sol_line_tasks += '\n'
            output += sol_line_tasks
            output += sol_line

        # Finally print the solution found.
        print(f'Optimal Schedule Length: {solver.ObjectiveValue()}')
        print(output)
    else:
        print('No solution found.')

    # Statistics.
    print('\nStatistics')
    print('  - conflicts: %i' % solver.NumConflicts())
    print('  - branches : %i' % solver.NumBranches())
    print('  - wall time: %f s' % solver.WallTime())
    print('  - status   : %s' % solver.StatusName(status))
    print('  - objective: %i' % solver.ObjectiveValue())
    print('  - User Time  : %i' % solver.UserTime())

# %%
list_files = ['tai15_15.txt','tai20_15.txt','tai20_20.txt','tai30_15.txt','tai30_20.txt','tai50_15.txt','tai50_20.txt','tai100_20.txt']
start_cell_time = time.time()
for i in range(len(list_files)):
    start_list_time = time.time()
    print(f'This is the file: {list_files[i]}')
    num_jobs, num_machines, smaller_lists = extract_data(list_files[i])
    for i in range(len(smaller_lists)):
        start_time = time.time()
        print (f'This is the list number: {i}')
        
        main(smaller_lists[i])
        print("--- %.2f seconds ---" % (time.time() - start_time))
    print("--- %.2f seconds for the file---" % (time.time() - start_list_time))
print("--- %.2f seconds for the cell---" % (time.time() - start_cell_time))
# Out:
# This is the file: tai15_15.txt
# This is the list number: 0
# Solution:
# Optimal Schedule Length: 1231.0
# Machine 1: job_7_task_2   job_11_task_2  job_9_task_5   job_10_task_3  job_8_task_4   job_3_task_5   job_12_task_7  job_2_task_8   job_14_task_9  job_5_task_11  job_1_task_10  job_6_task_12  job_4_task_13  job_0_task_13  job_13_task_14
#            [84,93]        [93,168]       [222,239]      [262,270]      [309,322]      [336,430]      [593,670]      [786,840]      [851,859]      [866,953]      [962,980]      [993,1030]     [1031,1073]    [1073,1143]    [1187,1222]
# Machine 2: job_2_task_0   job_8_task_5   job_14_task_5  job_7_task_7   job_6_task_6   job_13_task_7  job_9_task_10  job_11_task_11 job_4_task_10  job_5_task_9   job_12_task_10 job_10_task_11 job_3_task_13  job_1_task_13  job_0_task_14
#            [0,4]          [322,409]      [415,441]      [441,503]      [506,525]      [525,581]      [583,652]      [652,697]      [697,790]      [790,816]      [816,864]      [864,957]      [957,1049]     [1049,1148]    [1148,1231]
# Machine 3: job_11_task_0  job_9_task_3   job_3_task_1   job_4_task_6   job_12_task_3  job_8_task_6   job_0_task_5   job_7_task_8   job_5_task_8   job_2_task_9   job_6_task_10  job_14_task_12 job_10_task_14 job_13_task_13 job_1_task_14
#            [0,47]         [121,181]      [181,204]      [303,398]      [420,440]      [440,522]      [522,537]      [547,553]      [706,784]      [858,926]      [926,969]      [988,1071]     [1071,1144]    [1178,1185]    [1185,1218]
# Machine 4: job_6_task_1   job_5_task_1   job_9_task_7   job_12_task_4  job_0_task_4   job_7_task_11  job_11_task_12 job_10_task_10 job_13_task_12 job_14_task_11 job_1_task_11  job_3_task_14  job_2_task_13  job_4_task_14  job_8_task_14
#            [18,93]        [202,263]      [328,417]      [440,471]      [483,509]      [622,702]      [702,769]      [774,864]      [864,880]      [893,980]      [980,1031]     [1057,1066]    [1072,1107]    [1115,1211]    [1211,1226]
# Machine 5: job_1_task_0   job_13_task_2  job_10_task_0  job_0_task_2   job_4_task_4   job_14_task_4  job_5_task_5   job_3_task_7   job_7_task_10  job_6_task_8   job_12_task_9  job_8_task_9   job_2_task_12  job_9_task_13  job_11_task_14
#            [0,74]         [74,125]       [125,215]      [215,225]      [235,271]      [378,415]      [450,481]      [498,591]      [615,622]      [642,727]      [736,816]      [836,892]      [1033,1072]    [1072,1078]    [1087,1174]
# Machine 6: job_5_task_0   job_7_task_1   job_3_task_0   job_1_task_1   job_12_task_0  job_13_task_4  job_10_task_4  job_11_task_7  job_8_task_7   job_4_task_9   job_2_task_7   job_6_task_9   job_0_task_12  job_9_task_14  job_14_task_14
#            [3,32]         [32,84]        [84,157]       [157,188]      [188,253]      [253,270]      [277,368]      [430,464]      [536,619]      [621,697]      [778,784]      [784,857]      [977,1073]     [1091,1104]    [1120,1217]
# Machine 7: job_9_task_0   job_0_task_0   job_4_task_2   job_8_task_2   job_3_task_3   job_11_task_4  job_14_task_3  job_13_task_5  job_6_task_5   job_12_task_5  job_10_task_6  job_2_task_4   job_1_task_8   job_7_task_13  job_5_task_13
#            [0,5]          [5,99]         [101,122]      [122,218]      [234,264]      [264,315]      [315,349]      [349,438]      [438,506]      [511,544]      [551,640]      [640,690]      [792,883]      [888,945]      [1165,1179]
# Machine 8: job_4_task_0   job_6_task_2   job_7_task_3   job_10_task_1  job_1_task_2   job_11_task_6  job_0_task_3   job_9_task_9   job_3_task_8   job_5_task_7   job_13_task_9  job_14_task_10 job_2_task_10  job_8_task_11  job_12_task_13
#            [0,78]         [93,113]       [113,162]      [217,244]      [244,332]      [346,430]      [430,483]      [495,583]      [591,623]      [623,706]      [706,724]      [881,893]      [927,1009]     [1009,1017]    [1039,1135]
# Machine 9: job_13_task_0  job_4_task_1   job_6_task_3   job_14_task_1  job_9_task_4   job_12_task_1  job_2_task_1   job_11_task_8  job_7_task_9   job_10_task_7  job_0_task_8   job_1_task_5   job_3_task_11  job_8_task_10  job_5_task_14
#            [0,28]         [78,101]       [113,117]      [144,160]      [181,222]      [253,315]      [315,397]      [464,492]      [553,615]      [640,689]      [689,699]      [699,777]      [830,886]      [922,1007]     [1179,1209]
# Machine 10: job_9_task_2   job_3_task_2   job_4_task_5   job_2_task_2   job_13_task_6  job_11_task_9  job_12_task_6  job_1_task_7   job_0_task_10  job_7_task_12  job_10_task_13 job_8_task_12  job_14_task_13 job_5_task_12  job_6_task_14
#            [91,121]       [204,234]      [271,300]      [397,437]      [441,500]      [500,560]      [560,593]      [785,792]      [792,885]      [885,888]      [963,998]      [1017,1083]    [1083,1103]    [1103,1165]    [1165,1231]
# Machine 11: job_8_task_0   job_14_task_0  job_4_task_3   job_3_task_4   job_11_task_5  job_12_task_2  job_9_task_8   job_0_task_6   job_10_task_9  job_13_task_11 job_5_task_10  job_1_task_9   job_6_task_11  job_2_task_11  job_7_task_14
#            [0,85]         [85,142]       [142,202]      [264,317]      [317,320]      [320,417]      [417,495]      [537,602]      [746,774]      [774,804]      [816,866]      [883,962]      [969,993]      [1013,1033]    [1195,1202]
# Machine 12: job_7_task_0   job_9_task_1   job_8_task_1   job_5_task_4   job_6_task_7   job_0_task_7   job_2_task_5   job_13_task_10 job_1_task_6   job_3_task_10  job_14_task_8  job_12_task_11 job_10_task_12 job_4_task_12  job_11_task_13
#            [0,32]         [32,91]        [92,122]       [434,450]      [533,587]      [602,684]      [690,744]      [749,766]      [777,785]      [799,829]      [846,851]      [865,955]      [957,963]      [977,1029]     [1029,1087]
# Machine 13: job_6_task_0   job_0_task_1   job_7_task_4   job_11_task_3  job_14_task_2  job_5_task_2   job_10_task_5  job_2_task_3   job_4_task_8   job_13_task_8  job_8_task_8   job_9_task_11  job_3_task_12  job_12_task_12 job_1_task_12
#            [0,18]         [99,165]       [165,226]      [226,234]      [234,276]      [276,364]      [368,448]      [448,534]      [535,614]      [614,677]      [687,765]      [883,928]      [928,955]      [956,1031]     [1031,1049]
# Machine 14: job_13_task_3  job_7_task_5   job_10_task_2  job_9_task_6   job_5_task_3   job_3_task_6   job_14_task_6  job_11_task_10 job_1_task_4   job_12_task_8  job_2_task_6   job_4_task_11  job_0_task_11  job_6_task_13  job_8_task_13
#            [125,200]      [226,261]      [261,262]      [262,328]      [364,434]      [434,492]      [492,560]      [560,629]      [629,686]      [686,736]      [744,765]      [839,881]      [885,977]      [1030,1117]    [1122,1210]
# Machine 15: job_13_task_1  job_11_task_1  job_6_task_4   job_8_task_3   job_7_task_6   job_4_task_7   job_5_task_6   job_1_task_3   job_3_task_9   job_10_task_8  job_0_task_9   job_14_task_7  job_9_task_12  job_2_task_14  job_12_task_14
#            [28,49]        [49,92]        [117,208]      [218,309]      [309,408]      [408,507]      [507,572]      [572,623]      [623,714]      [714,746]      [746,773]      [773,846]      [947,1029]     [1107,1175]    [1175,1219]
#
#
# Statistics
#   - conflicts: 9274
#   - branches : 11866
#   - wall time: 8.462381 s
#   - status   : OPTIMAL
#   - objective: 1231
#   - User Time  : 8
# --- 8.51 seconds ---
# This is the list number: 1
# Solution:
# Optimal Schedule Length: 1244.0
# Machine 1: job_2_task_1   job_7_task_1   job_12_task_3  job_14_task_4  job_6_task_3   job_5_task_4   job_3_task_3   job_9_task_6   job_0_task_8   job_10_task_9  job_1_task_14  job_11_task_11 job_8_task_10  job_13_task_12 job_4_task_12
#            [33,100]       [100,164]      [164,192]      [242,326]      [333,367]      [367,377]      [377,465]      [504,510]      [698,796]      [810,835]      [861,884]      [885,917]      [943,959]      [1002,1038]    [1038,1111]
# Machine 2: job_14_task_0  job_5_task_2   job_4_task_5   job_10_task_6  job_9_task_5   job_6_task_6   job_3_task_4   job_13_task_5  job_8_task_4   job_12_task_8  job_1_task_11  job_11_task_9  job_0_task_10  job_2_task_10  job_7_task_13
#            [0,36]         [172,265]      [275,316]      [344,396]      [409,412]      [416,424]      [465,489]      [514,537]      [544,635]      [646,727]      [737,748]      [771,833]      [845,888]      [912,934]      [961,972]
# Machine 3: job_9_task_0   job_13_task_0  job_5_task_1   job_14_task_3  job_4_task_8   job_1_task_9   job_2_task_6   job_7_task_8   job_12_task_11 job_11_task_10 job_10_task_10 job_0_task_11  job_6_task_11  job_8_task_11  job_3_task_14
#            [0,5]          [5,16]         [112,172]      [218,242]      [516,535]      [538,624]      [624,684]      [686,782]      [782,824]      [833,872]      [872,881]      [888,896]      [896,988]      [988,1071]     [1238,1242]
# Machine 4: job_11_task_1  job_9_task_2   job_4_task_3   job_1_task_4   job_7_task_3   job_13_task_3  job_0_task_5   job_5_task_9   job_8_task_8   job_14_task_12 job_12_task_14 job_10_task_13 job_2_task_12  job_3_task_11  job_6_task_14
#            [83,115]       [115,136]      [243,256]      [256,349]      [349,393]      [393,452]      [508,602]      [769,810]      [846,914]      [914,934]      [934,987]      [1004,1045]    [1045,1083]    [1083,1173]    [1173,1243]
# Machine 5: job_4_task_1   job_14_task_2  job_0_task_2   job_10_task_4  job_13_task_2  job_11_task_4  job_12_task_6  job_5_task_5   job_1_task_8   job_2_task_8   job_9_task_9   job_3_task_9   job_7_task_14  job_6_task_13  job_8_task_14
#            [128,180]      [180,218]      [218,228]      [228,301]      [301,328]      [329,358]      [358,382]      [385,457]      [476,538]      [804,824]      [835,899]      [899,967]      [972,1066]     [1078,1163]    [1196,1219]
# Machine 6: job_6_task_0   job_5_task_0   job_12_task_2  job_10_task_3  job_13_task_1  job_2_task_3   job_8_task_2   job_3_task_6   job_7_task_6   job_14_task_10 job_1_task_12  job_0_task_9   job_9_task_10  job_11_task_12 job_4_task_14
#            [0,50]         [50,112]       [113,116]      [140,208]      [208,301]      [301,392]      [433,484]      [561,639]      [639,660]      [680,748]      [748,768]      [796,845]      [899,975]      [975,983]      [1211,1230]
# Machine 7: job_2_task_2   job_9_task_4   job_14_task_6  job_10_task_7  job_7_task_5   job_5_task_8   job_1_task_10  job_12_task_10 job_13_task_9  job_4_task_10  job_8_task_9   job_11_task_13 job_6_task_12  job_0_task_13  job_3_task_12
#            [192,288]      [300,366]      [373,445]      [445,484]      [506,597]      [614,672]      [672,737]      [737,781]      [781,845]      [845,930]      [930,943]      [983,1016]     [1016,1078]    [1078,1099]    [1173,1231]
# Machine 8: job_2_task_0   job_14_task_5  job_11_task_5  job_1_task_7   job_6_task_9   job_0_task_6   job_7_task_7   job_13_task_8  job_8_task_7   job_12_task_12 job_5_task_11  job_4_task_11  job_9_task_12  job_10_task_14 job_3_task_13
#            [0,33]         [326,373]      [373,441]      [448,476]      [545,598]      [602,673]      [685,686]      [686,763]      [806,846]      [846,848]      [862,925]      [930,1029]     [1069,1086]    [1086,1184]    [1231,1238]
# Machine 9: job_12_task_0  job_1_task_1   job_4_task_4   job_11_task_3  job_6_task_5   job_5_task_6   job_3_task_5   job_0_task_7   job_8_task_6   job_7_task_11  job_10_task_11 job_9_task_11  job_13_task_13 job_14_task_14 job_2_task_14
#            [0,28]         [68,96]        [256,275]      [275,285]      [411,416]      [457,545]      [545,561]      [673,698]      [743,806]      [901,913]      [913,947]      [975,1069]     [1069,1122]    [1122,1152]    [1157,1239]
# Machine 10: job_3_task_0   job_0_task_0   job_7_task_2   job_12_task_5  job_10_task_5  job_6_task_4   job_1_task_6   job_14_task_7  job_13_task_4  job_8_task_5   job_5_task_10  job_2_task_11  job_11_task_14 job_4_task_13  job_9_task_14
#            [1,14]         [14,100]       [164,256]      [258,317]      [317,344]      [367,411]      [411,448]      [448,449]      [452,514]      [653,743]      [816,862]      [934,1013]     [1016,1107]    [1111,1206]    [1206,1243]
# Machine 11: job_1_task_0   job_14_task_1  job_6_task_1   job_11_task_2  job_5_task_3   job_9_task_3   job_4_task_6   job_8_task_1   job_0_task_4   job_3_task_7   job_12_task_9  job_13_task_10 job_7_task_12  job_10_task_12 job_2_task_13
#            [0,68]         [68,166]       [166,234]      [234,269]      [269,285]      [286,300]      [316,387]      [387,433]      [443,508]      [639,709]      [727,735]      [845,905]      [913,954]      [954,1004]     [1117,1157]
# Machine 12: job_10_task_0  job_4_task_0   job_3_task_1   job_1_task_2   job_12_task_4  job_8_task_0   job_6_task_7   job_14_task_8  job_13_task_6  job_11_task_7  job_2_task_7   job_9_task_8   job_7_task_10  job_5_task_12  job_0_task_14
#            [0,35]         [35,128]       [128,142]      [142,180]      [192,258]      [258,351]      [424,449]      [449,540]      [572,595]      [651,659]      [684,772]      [772,835]      [842,901]      [925,1001]     [1169,1242]
# Machine 13: job_7_task_0   job_11_task_0  job_12_task_7  job_4_task_7   job_10_task_8  job_14_task_9  job_6_task_10  job_3_task_8   job_1_task_13  job_2_task_9   job_0_task_12  job_5_task_13  job_9_task_13  job_8_task_13  job_13_task_14
#            [0,60]         [60,83]        [382,427]      [427,486]      [486,527]      [540,625]      [625,703]      [709,762]      [768,850]      [850,912]      [912,1002]     [1002,1085]    [1086,1148]    [1148,1172]    [1172,1244]
# Machine 14: job_12_task_1  job_10_task_2  job_4_task_2   job_6_task_2   job_1_task_5   job_0_task_3   job_7_task_4   job_8_task_3   job_2_task_5   job_13_task_7  job_11_task_6  job_9_task_7   job_3_task_10  job_14_task_13 job_5_task_14
#            [28,59]        [78,140]       [180,243]      [243,333]      [349,384]      [384,443]      [443,506]      [506,543]      [543,624]      [624,631]      [631,651]      [651,749]      [967,1040]     [1090,1120]    [1160,1222]
# Machine 15: job_10_task_1  job_9_task_1   job_0_task_1   job_1_task_3   job_3_task_2   job_2_task_4   job_6_task_8   job_5_task_7   job_11_task_8  job_4_task_9   job_7_task_9   job_14_task_11 job_12_task_13 job_13_task_11 job_8_task_12
#            [36,78]        [78,113]       [113,173]      [180,216]      [216,289]      [392,475]      [475,545]      [545,614]      [698,756]      [756,816]      [816,835]      [835,877]      [877,900]      [905,1002]     [1071,1120]
#
#
# Statistics
#   - conflicts: 47970
#   - branches : 55587
#   - wall time: 59.983309 s
#   - status   : FEASIBLE
#   - objective: 1244
#   - User Time  : 59
# --- 60.01 seconds ---
# This is the list number: 2
# Solution:
# Optimal Schedule Length: 1218.0
# Machine 1: job_11_task_0  job_9_task_1   job_8_task_2   job_14_task_2  job_2_task_3   job_6_task_2   job_13_task_3  job_3_task_8   job_0_task_7   job_5_task_10  job_12_task_10 job_1_task_13  job_4_task_13  job_10_task_13 job_7_task_14
#            [0,78]         [78,82]        [110,143]      [147,161]      [202,256]      [256,277]      [424,487]      [487,528]      [528,590]      [769,825]      [825,882]      [882,971]      [998,1087]     [1087,1179]    [1183,1210]
# Machine 2: job_2_task_0   job_14_task_0  job_4_task_0   job_1_task_1   job_10_task_2  job_7_task_3   job_6_task_3   job_5_task_5   job_0_task_5   job_9_task_7   job_12_task_7  job_13_task_7  job_3_task_13  job_11_task_12 job_8_task_11
#            [0,62]         [62,135]       [135,171]      [171,222]      [226,307]      [307,310]      [310,337]      [373,467]      [467,470]      [470,516]      [623,640]      [703,793]      [964,967]      [990,1014]     [1041,1063]
# Machine 3: job_2_task_1   job_6_task_1   job_10_task_1  job_3_task_3   job_14_task_4  job_5_task_2   job_13_task_1  job_1_task_6   job_4_task_7   job_7_task_6   job_9_task_12  job_0_task_12  job_12_task_13 job_11_task_14 job_8_task_13
#            [62,109]       [109,187]      [187,204]      [206,236]      [236,239]      [239,245]      [245,331]      [512,564]      [628,693]      [693,743]      [757,853]      [1001,1004]    [1005,1101]    [1101,1143]    [1143,1202]
# Machine 4: job_9_task_2   job_2_task_4   job_0_task_3   job_10_task_4  job_1_task_5   job_12_task_5  job_14_task_8  job_3_task_11  job_4_task_6   job_13_task_6  job_8_task_6   job_11_task_10 job_7_task_9   job_5_task_13  job_6_task_14
#            [82,117]       [256,294]      [301,363]      [385,432]      [432,508]      [508,544]      [544,597]      [599,609]      [609,628]      [628,703]      [703,800]      [800,879]      [935,960]      [1085,1137]    [1150,1214]
# Machine 5: job_7_task_0   job_4_task_2   job_14_task_6  job_3_task_6   job_2_task_7   job_5_task_7   job_10_task_6  job_1_task_7   job_12_task_8  job_13_task_9  job_11_task_11 job_0_task_11  job_6_task_12  job_9_task_14  job_8_task_14
#            [0,12]         [220,230]      [311,395]      [400,411]      [447,543]      [543,619]      [619,670]      [670,688]      [688,787]      [833,910]      [910,919]      [919,1001]     [1001,1100]    [1139,1162]    [1202,1218]
# Machine 6: job_6_task_0   job_5_task_0   job_11_task_5  job_2_task_5   job_9_task_6   job_4_task_5   job_3_task_9   job_8_task_5   job_14_task_9  job_1_task_8   job_10_task_8  job_12_task_9  job_13_task_10 job_7_task_10  job_0_task_14
#            [0,29]         [29,112]       [242,298]      [298,376]      [376,460]      [460,532]      [532,587]      [587,618]      [618,676]      [688,710]      [718,800]      [800,814]      [910,918]      [960,978]      [1123,1211]
# Machine 7: job_3_task_2   job_4_task_4   job_1_task_4   job_11_task_6  job_9_task_8   job_12_task_6  job_5_task_8   job_10_task_7  job_0_task_9   job_6_task_10  job_14_task_11 job_13_task_11 job_8_task_10  job_7_task_11  job_2_task_13
#            [126,206]      [273,342]      [343,432]      [435,511]      [516,612]      [612,623]      [623,669]      [670,693]      [693,759]      [759,831]      [831,918]      [918,945]      [947,1041]     [1041,1096]    [1140,1149]
# Machine 8: job_0_task_0   job_10_task_0  job_7_task_1   job_3_task_5   job_6_task_8   job_11_task_8  job_14_task_10 job_2_task_12  job_4_task_11  job_9_task_13  job_13_task_12 job_1_task_14  job_8_task_12  job_12_task_14 job_5_task_14
#            [0,69]         [69,105]       [105,179]      [369,400]      [549,565]      [596,676]      [676,771]      [771,861]      [861,872]      [872,946]      [946,1042]     [1042,1064]    [1064,1125]    [1125,1142]    [1142,1214]
# Machine 9: job_12_task_0  job_11_task_1  job_4_task_1   job_0_task_2   job_6_task_4   job_2_task_6   job_14_task_7  job_7_task_5   job_3_task_12  job_9_task_10  job_1_task_9   job_8_task_8   job_10_task_10 job_5_task_12  job_13_task_14
#            [0,38]         [78,136]       [171,220]      [220,301]      [337,354]      [376,447]      [447,531]      [531,593]      [609,701]      [716,734]      [734,819]      [881,906]      [906,1002]     [1053,1085]    [1146,1210]
# Machine 10: job_9_task_0   job_2_task_2   job_11_task_4  job_8_task_3   job_7_task_4   job_1_task_3   job_3_task_10  job_6_task_9   job_4_task_8   job_5_task_9   job_0_task_10  job_10_task_9  job_12_task_11 job_14_task_12 job_13_task_13
#            [0,27]         [109,202]      [241,242]      [242,289]      [313,328]      [328,343]      [587,599]      [599,648]      [693,730]      [730,760]      [760,848]      [848,883]      [883,947]      [947,1037]     [1077,1146]
# Machine 11: job_3_task_1   job_9_task_3   job_12_task_2  job_7_task_2   job_14_task_5  job_5_task_4   job_8_task_4   job_6_task_7   job_11_task_7  job_13_task_5  job_2_task_9   job_4_task_9   job_1_task_12  job_10_task_12 job_0_task_13
#            [33,115]       [117,197]      [197,235]      [235,239]      [239,286]      [286,373]      [373,459]      [489,504]      [511,560]      [561,623]      [623,656]      [730,787]      [875,880]      [1012,1066]    [1074,1086]
# Machine 12: job_8_task_1   job_0_task_1   job_14_task_3  job_12_task_3  job_1_task_2   job_13_task_2  job_3_task_7   job_6_task_6   job_5_task_6   job_9_task_11  job_11_task_9  job_7_task_8   job_4_task_12  job_2_task_14  job_10_task_14
#            [69,82]        [82,163]       [163,234]      [235,273]      [274,321]      [331,424]      [424,450]      [475,489]      [507,543]      [734,757]      [757,783]      [876,925]      [925,998]      [1149,1170]    [1179,1217]
# Machine 13: job_1_task_0   job_12_task_1  job_11_task_3  job_5_task_3   job_9_task_4   job_10_task_3  job_0_task_4   job_2_task_10  job_13_task_8  job_8_task_7   job_6_task_11  job_3_task_14  job_14_task_13 job_7_task_13  job_4_task_14
#            [0,83]         [83,169]       [198,241]      [255,268]      [268,317]      [317,384]      [384,464]      [656,700]      [793,833]      [833,881]      [893,912]      [967,1042]     [1042,1110]    [1112,1183]    [1183,1195]
# Machine 14: job_3_task_0   job_13_task_0  job_14_task_1  job_9_task_5   job_0_task_6   job_2_task_11  job_4_task_10  job_1_task_10  job_5_task_11  job_8_task_9   job_12_task_12 job_10_task_11 job_11_task_13 job_7_task_12  job_6_task_13
#            [0,33]         [33,43]        [135,147]      [317,363]      [479,517]      [700,771]      [787,819]      [819,845]      [845,907]      [907,947]      [947,1005]     [1005,1012]    [1048,1072]    [1107,1112]    [1112,1150]
# Machine 15: job_8_task_0   job_11_task_2  job_5_task_1   job_4_task_3   job_3_task_4   job_6_task_5   job_12_task_4  job_10_task_5  job_13_task_4  job_2_task_8   job_0_task_8   job_9_task_9   job_7_task_7   job_1_task_11  job_14_task_14
#            [0,69]         [136,198]      [198,230]      [230,273]      [273,369]      [369,412]      [412,495]      [495,500]      [500,561]      [561,580]      [590,644]      [644,716]      [743,781]      [845,875]      [1134,1209]
#
#
# Statistics
#   - conflicts: 55450
#   - branches : 58421
#   - wall time: 60.055953 s
#   - status   : FEASIBLE
#   - objective: 1218
#   - User Time  : 60
# --- 60.10 seconds ---
# This is the list number: 3
# Solution:
# Optimal Schedule Length: 1175.0
# Machine 1: job_12_task_1  job_11_task_0  job_14_task_2  job_1_task_2   job_8_task_5   job_6_task_3   job_5_task_5   job_2_task_4   job_10_task_6  job_13_task_9  job_3_task_11  job_9_task_10  job_0_task_10  job_7_task_10  job_4_task_12
#            [10,32]        [32,106]       [219,243]      [274,353]      [356,360]      [360,407]      [410,494]      [494,554]      [569,582]      [636,683]      [683,723]      [727,768]      [768,838]      [917,970]      [1072,1102]
# Machine 2: job_1_task_0   job_4_task_0   job_11_task_2  job_5_task_3   job_3_task_6   job_12_task_10 job_8_task_8   job_0_task_9   job_14_task_11 job_2_task_8   job_10_task_9  job_7_task_9   job_13_task_12 job_6_task_11  job_9_task_14
#            [0,19]         [19,64]        [167,210]      [210,303]      [307,401]      [418,481]      [532,556]      [556,641]      [641,736]      [748,756]      [756,850]      [864,917]      [917,1009]     [1058,1065]    [1131,1168]
# Machine 3: job_9_task_0   job_12_task_4  job_5_task_1   job_14_task_1  job_13_task_3  job_3_task_5   job_11_task_4  job_8_task_9   job_10_task_7  job_7_task_6   job_4_task_8   job_1_task_9   job_0_task_13  job_6_task_12  job_2_task_14
#            [0,36]         [49,103]       [103,159]      [195,219]      [222,274]      [288,307]      [323,420]      [556,610]      [610,670]      [670,730]      [730,801]      [806,867]      [1023,1073]    [1073,1084]    [1084,1175]
# Machine 4: job_0_task_0   job_9_task_3   job_2_task_1   job_3_task_4   job_8_task_4   job_10_task_2  job_1_task_6   job_5_task_8   job_14_task_13 job_6_task_8   job_12_task_13 job_11_task_13 job_4_task_11  job_7_task_13  job_13_task_14
#            [0,72]         [139,203]      [218,225]      [269,288]      [288,356]      [356,445]      [507,550]      [554,569]      [783,843]      [888,960]      [960,972]      [982,993]      [1002,1030]    [1058,1141]    [1141,1152]
# Machine 5: job_12_task_2  job_7_task_1   job_8_task_1   job_11_task_1  job_14_task_3  job_13_task_5  job_3_task_7   job_0_task_7   job_10_task_5  job_2_task_5   job_9_task_9   job_5_task_12  job_1_task_12  job_6_task_10  job_4_task_13
#            [32,41]        [41,62]        [62,90]        [106,167]      [243,257]      [395,399]      [401,442]      [488,521]      [529,552]      [554,636]      [641,654]      [723,800]      [953,972]      [1020,1058]    [1102,1119]
# Machine 6: job_13_task_0  job_3_task_2   job_9_task_5   job_14_task_5  job_1_task_3   job_0_task_6   job_7_task_3   job_4_task_3   job_10_task_8  job_5_task_13  job_12_task_12 job_2_task_11  job_8_task_14  job_11_task_14 job_6_task_14
#            [0,67]         [151,235]      [235,276]      [291,348]      [353,400]      [400,488]      [488,530]      [558,587]      [670,716]      [800,855]      [860,902]      [902,946]      [947,1042]     [1042,1112]    [1112,1175]
# Machine 7: job_12_task_0  job_3_task_0   job_0_task_2   job_9_task_4   job_13_task_7  job_14_task_8  job_10_task_4  job_5_task_6   job_4_task_2   job_8_task_10  job_11_task_9  job_7_task_8   job_2_task_10  job_1_task_11  job_6_task_13
#            [0,9]          [9,67]         [128,170]      [204,234]      [400,456]      [476,480]      [482,510]      [510,550]      [550,558]      [610,667]      [761,839]      [839,864]      [879,886]      [897,953]      [1084,1106]
# Machine 8: job_7_task_0   job_8_task_0   job_0_task_1   job_2_task_0   job_6_task_1   job_13_task_4  job_10_task_3  job_5_task_10  job_4_task_5   job_11_task_8  job_14_task_12 job_9_task_12  job_3_task_13  job_1_task_13  job_12_task_14
#            [1,13]         [13,61]        [72,123]       [123,217]      [217,308]      [308,395]      [445,482]      [584,638]      [638,680]      [699,761]      [761,783]      [803,835]      [857,945]      [972,1063]     [1115,1156]
# Machine 9: job_2_task_2   job_0_task_5   job_13_task_6  job_1_task_4   job_8_task_7   job_14_task_10 job_4_task_4   job_3_task_10  job_6_task_5   job_12_task_11 job_11_task_10 job_9_task_13  job_10_task_11 job_5_task_14  job_7_task_14
#            [277,279]      [297,343]      [399,400]      [400,440]      [440,532]      [532,601]      [601,633]      [646,671]      [671,739]      [739,837]      [839,881]      [881,975]      [975,1047]     [1047,1078]    [1141,1173]
# Machine 10: job_12_task_6  job_0_task_4   job_11_task_3  job_10_task_1  job_14_task_6  job_9_task_7   job_3_task_8   job_5_task_7   job_13_task_8  job_2_task_6   job_4_task_7   job_1_task_8   job_6_task_6   job_8_task_13  job_7_task_12
#            [135,227]      [236,297]      [297,323]      [336,345]      [348,378]      [378,452]      [452,550]      [550,554]      [554,636]      [636,712]      [712,716]      [716,800]      [800,862]      [862,947]      [1029,1058]
# Machine 11: job_12_task_3  job_13_task_1  job_9_task_2   job_8_task_3   job_14_task_7  job_0_task_8   job_1_task_7   job_11_task_7  job_5_task_11  job_2_task_9   job_6_task_7   job_10_task_10 job_7_task_11  job_3_task_14  job_4_task_14
#            [41,49]        [67,74]        [74,139]       [219,245]      [412,476]      [521,548]      [550,615]      [624,684]      [684,723]      [781,866]      [866,888]      [888,973]      [973,1029]     [1029,1103]    [1119,1162]
# Machine 12: job_5_task_0   job_3_task_1   job_14_task_0  job_1_task_1   job_10_task_0  job_6_task_2   job_12_task_8  job_2_task_3   job_4_task_1   job_11_task_5  job_7_task_5   job_9_task_11  job_8_task_12  job_13_task_11 job_0_task_12
#            [0,84]         [84,151]       [151,195]      [195,274]      [274,336]      [336,353]      [353,355]      [355,450]      [450,510]      [510,572]      [572,656]      [770,776]      [776,860]      [895,903]      [953,1023]
# Machine 13: job_9_task_1   job_5_task_2   job_12_task_9  job_6_task_4   job_14_task_9  job_3_task_9   job_4_task_6   job_8_task_11  job_7_task_7   job_13_task_10 job_1_task_10  job_0_task_11  job_11_task_11 job_2_task_13  job_10_task_13
#            [36,70]        [159,205]      [355,418]      [418,495]      [506,520]      [550,646]      [680,705]      [705,752]      [752,804]      [804,839]      [867,897]      [897,953]      [953,961]      [992,1064]     [1083,1162]
# Machine 14: job_13_task_2  job_3_task_3   job_12_task_7  job_8_task_6   job_7_task_2   job_1_task_5   job_9_task_8   job_5_task_9   job_11_task_6  job_2_task_7   job_4_task_10  job_6_task_9   job_10_task_12 job_14_task_14 job_0_task_14
#            [95,186]       [235,269]      [269,345]      [360,379]      [379,439]      [440,507]      [515,559]      [569,584]      [584,624]      [712,748]      [880,973]      [973,1020]     [1065,1083]    [1083,1144]    [1144,1169]
# Machine 15: job_6_task_0   job_12_task_5  job_8_task_2   job_0_task_3   job_14_task_4  job_9_task_6   job_5_task_4   job_7_task_4   job_3_task_12  job_4_task_9   job_11_task_12 job_2_task_12  job_13_task_13 job_1_task_14  job_10_task_14
#            [0,65]         [103,135]      [135,205]      [205,236]      [257,291]      [291,344]      [344,410]      [530,552]      [723,797]      [801,880]      [961,982]      [990,992]      [1014,1053]    [1063,1131]    [1162,1173]
#
#
# Statistics
#   - conflicts: 43691
#   - branches : 53715
#   - wall time: 55.045271 s
#   - status   : OPTIMAL
#   - objective: 1175
#   - User Time  : 55
# --- 55.07 seconds ---
# This is the list number: 4
# Solution:
# Optimal Schedule Length: 1229.0
# Machine 1: job_3_task_3   job_5_task_3   job_14_task_2  job_9_task_6   job_7_task_6   job_8_task_8   job_0_task_5   job_4_task_7   job_6_task_4   job_12_task_6  job_13_task_8  job_1_task_11  job_11_task_9  job_2_task_10  job_10_task_14
#            [79,87]        [97,169]       [221,275]      [286,346]      [358,396]      [396,405]      [405,480]      [494,515]      [540,620]      [641,726]      [743,818]      [821,859]      [873,923]      [929,1026]     [1181,1229]
# Machine 2: job_8_task_0   job_0_task_1   job_1_task_1   job_4_task_3   job_13_task_1  job_12_task_4  job_3_task_8   job_6_task_6   job_14_task_10 job_5_task_13  job_10_task_12 job_2_task_11  job_11_task_12 job_7_task_13  job_9_task_14
#            [0,37]         [41,137]       [137,225]      [225,293]      [303,398]      [398,420]      [420,498]      [691,738]      [761,801]      [801,899]      [984,1027]     [1027,1043]    [1043,1120]    [1120,1166]    [1176,1227]
# Machine 3: job_8_task_1   job_10_task_4  job_3_task_6   job_14_task_4  job_11_task_4  job_5_task_9   job_7_task_8   job_6_task_5   job_1_task_9   job_4_task_8   job_2_task_9   job_12_task_11 job_13_task_11 job_0_task_13  job_9_task_13
#            [37,46]        [120,144]      [174,250]      [317,387]      [491,577]      [577,579]      [579,595]      [620,691]      [691,728]      [728,813]      [928,929]      [939,999]      [999,1002]     [1018,1117]    [1126,1175]
# Machine 4: job_7_task_0   job_10_task_1  job_9_task_4   job_2_task_1   job_14_task_5  job_8_task_9   job_5_task_8   job_0_task_8   job_13_task_7  job_3_task_11  job_4_task_9   job_1_task_12  job_11_task_11 job_6_task_11  job_12_task_13
#            [0,29]         [36,85]        [239,249]      [325,371]      [387,416]      [416,457]      [457,540]      [582,647]      [647,743]      [743,813]      [813,892]      [892,960]      [960,1033]     [1049,1059]    [1086,1118]
# Machine 5: job_5_task_0   job_10_task_0  job_0_task_2   job_9_task_5   job_7_task_5   job_13_task_2  job_8_task_12  job_11_task_5  job_2_task_5   job_14_task_11 job_12_task_10 job_1_task_13  job_4_task_12  job_3_task_14  job_6_task_14
#            [0,14]         [14,36]        [137,196]      [249,286]      [320,358]      [398,450]      [576,584]      [584,603]      [607,686]      [801,849]      [871,939]      [960,1054]     [1054,1075]    [1092,1189]    [1189,1222]
# Machine 6: job_1_task_0   job_3_task_2   job_7_task_2   job_14_task_1  job_10_task_6  job_4_task_5   job_11_task_3  job_8_task_11  job_5_task_10  job_0_task_9   job_2_task_6   job_12_task_7  job_13_task_9  job_6_task_10  job_9_task_12
#            [0,2]          [37,79]        [114,203]      [203,221]      [294,367]      [384,421]      [468,491]      [493,576]      [579,665]      [665,681]      [686,748]      [752,844]      [903,915]      [996,1049]     [1049,1124]
# Machine 7: job_4_task_0   job_5_task_2   job_8_task_2   job_9_task_2   job_2_task_0   job_7_task_3   job_11_task_0  job_6_task_2   job_14_task_7  job_13_task_4  job_1_task_6   job_12_task_5  job_10_task_7  job_0_task_10  job_3_task_13
#            [0,68]         [68,97]        [97,146]       [146,193]      [193,280]      [280,290]      [290,371]      [371,470]      [471,521]      [521,554]      [554,592]      [594,617]      [639,707]      [707,778]      [1073,1089]
# Machine 8: job_5_task_1   job_3_task_1   job_9_task_1   job_14_task_0  job_8_task_3   job_12_task_3  job_4_task_4   job_11_task_2  job_2_task_3   job_13_task_6  job_7_task_9   job_1_task_10  job_10_task_10 job_6_task_9   job_0_task_14
#            [16,17]        [19,34]        [34,107]       [107,201]      [201,224]      [248,280]      [293,384]      [447,468]      [468,555]      [567,640]      [640,705]      [728,821]      [821,890]      [918,996]      [1188,1212]
# Machine 9: job_10_task_2  job_12_task_2  job_5_task_4   job_3_task_7   job_7_task_4   job_8_task_7   job_13_task_3  job_0_task_7   job_9_task_9   job_1_task_8   job_14_task_9  job_6_task_7   job_11_task_8  job_2_task_8   job_4_task_10
#            [85,118]       [142,172]      [241,247]      [250,275]      [290,320]      [377,392]      [450,509]      [517,582]      [603,614]      [627,684]      [685,755]      [755,851]      [851,873]      [873,927]      [927,978]
# Machine 10: job_3_task_4   job_0_task_3   job_14_task_6  job_6_task_3   job_1_task_5   job_8_task_13  job_5_task_11  job_7_task_10  job_2_task_7   job_12_task_8  job_9_task_11  job_13_task_12 job_4_task_13  job_11_task_13 job_10_task_13
#            [87,159]       [196,291]      [416,459]      [470,540]      [540,553]      [584,645]      [665,698]      [705,795]      [795,832]      [844,858]      [921,1000]     [1002,1092]    [1092,1122]    [1125,1141]    [1141,1180]
# Machine 11: job_3_task_0   job_7_task_1   job_6_task_0   job_8_task_4   job_14_task_3  job_1_task_3   job_2_task_2   job_13_task_5  job_9_task_8   job_5_task_12  job_10_task_8  job_12_task_9  job_11_task_10 job_0_task_12  job_4_task_14
#            [0,19]         [29,114]       [114,135]      [224,225]      [275,317]      [338,390]      [450,464]      [554,566]      [577,603]      [698,731]      [731,752]      [858,871]      [923,934]      [934,1018]     [1160,1224]
# Machine 12: job_6_task_1   job_4_task_6   job_0_task_6   job_14_task_8  job_3_task_10  job_8_task_14  job_11_task_7  job_9_task_10  job_7_task_11  job_10_task_11 job_5_task_14  job_2_task_12  job_1_task_14  job_12_task_14 job_13_task_14
#            [135,215]      [421,494]      [494,517]      [521,596]      [596,658]      [658,718]      [718,770]      [770,807]      [807,880]      [890,984]      [984,1043]     [1043,1045]    [1055,1126]    [1126,1216]    [1216,1222]
# Machine 13: job_9_task_0   job_0_task_0   job_12_task_0  job_4_task_1   job_13_task_0  job_8_task_5   job_5_task_6   job_11_task_1  job_1_task_7   job_10_task_9  job_6_task_8   job_3_task_12  job_7_task_12  job_14_task_13 job_2_task_14
#            [0,1]          [1,41]         [41,62]        [68,139]       [139,168]      [225,303]      [303,401]      [401,447]      [592,627]      [752,813]      [862,918]      [918,999]      [999,1087]     [1097,1124]    [1124,1220]
# Machine 14: job_12_task_1  job_10_task_5  job_3_task_5   job_5_task_5   job_0_task_4   job_1_task_4   job_8_task_10  job_9_task_7   job_2_task_4   job_11_task_6  job_13_task_10 job_4_task_11  job_6_task_12  job_7_task_14  job_14_task_14
#            [62,142]       [144,147]      [159,174]      [255,286]      [291,367]      [390,458]      [458,493]      [493,577]      [577,607]      [607,671]      [915,998]      [998,1048]     [1059,1151]    [1166,1213]    [1217,1229]
# Machine 15: job_10_task_3  job_4_task_2   job_9_task_3   job_1_task_2   job_8_task_6   job_5_task_7   job_7_task_7   job_3_task_9   job_0_task_11  job_12_task_12 job_14_task_12 job_2_task_13  job_13_task_13 job_6_task_13  job_11_task_14
#            [118,120]      [139,142]      [193,239]      [239,338]      [338,377]      [401,451]      [451,499]      [507,591]      [778,830]      [999,1044]     [1044,1045]    [1045,1096]    [1096,1153]    [1153,1154]    [1154,1229]
#
#
# Statistics
#   - conflicts: 43365
#   - branches : 50528
#   - wall time: 60.050060 s
#   - status   : FEASIBLE
#   - objective: 1229
#   - User Time  : 60
# --- 60.11 seconds ---
# This is the list number: 5
# Solution:
# Optimal Schedule Length: 1239.0
# Machine 1: job_11_task_0  job_1_task_1   job_3_task_1   job_12_task_2  job_8_task_6   job_13_task_7  job_14_task_9  job_0_task_8   job_6_task_6   job_7_task_8   job_4_task_10  job_5_task_8   job_2_task_8   job_10_task_11 job_9_task_14
#            [0,28]         [32,113]       [113,200]      [261,301]      [307,362]      [362,423]      [533,596]      [623,641]      [675,757]      [757,762]      [762,789]      [790,882]      [882,906]      [906,994]      [1161,1231]
# Machine 2: job_10_task_0  job_8_task_1   job_6_task_1   job_2_task_3   job_14_task_6  job_3_task_5   job_1_task_5   job_0_task_9   job_13_task_10 job_12_task_8  job_7_task_10  job_5_task_9   job_11_task_12 job_9_task_13  job_4_task_14
#            [0,4]          [19,74]        [245,278]      [278,357]      [375,423]      [425,441]      [441,486]      [641,698]      [698,722]      [753,768]      [808,891]      [891,918]      [923,1003]     [1148,1155]    [1155,1236]
# Machine 3: job_14_task_1  job_4_task_1   job_13_task_5  job_10_task_3  job_6_task_2   job_1_task_7   job_3_task_9   job_9_task_6   job_0_task_11  job_8_task_11  job_2_task_9   job_12_task_12 job_5_task_11  job_11_task_13 job_7_task_14
#            [80,110]       [111,207]      [207,283]      [311,321]      [321,399]      [550,623]      [644,647]      [679,743]      [743,748]      [770,854]      [906,932]      [980,996]      [996,1003]     [1003,1041]    [1121,1165]
# Machine 4: job_9_task_0   job_14_task_4  job_11_task_5  job_0_task_4   job_7_task_3   job_4_task_7   job_8_task_9   job_1_task_8   job_3_task_10  job_13_task_11 job_12_task_9  job_10_task_12 job_2_task_12  job_5_task_13  job_6_task_13
#            [0,27]         [301,346]      [346,406]      [429,457]      [457,540]      [540,550]      [551,624]      [625,648]      [671,673]      [726,749]      [768,809]      [994,1046]     [1046,1075]    [1098,1164]    [1167,1169]
# Machine 5: job_13_task_1  job_6_task_0   job_8_task_3   job_14_task_3  job_10_task_1  job_7_task_0   job_4_task_6   job_1_task_6   job_9_task_3   job_12_task_6  job_0_task_10  job_2_task_7   job_11_task_11 job_3_task_14  job_5_task_14
#            [9,30]         [30,120]       [120,194]      [194,252]      [252,305]      [305,384]      [384,482]      [486,546]      [546,636]      [640,679]      [698,741]      [741,834]      [889,923]      [1171,1199]    [1199,1212]
# Machine 6: job_8_task_2   job_13_task_4  job_1_task_2   job_0_task_2   job_14_task_7  job_2_task_5   job_11_task_8  job_9_task_4   job_4_task_9   job_10_task_9  job_7_task_9   job_3_task_12  job_12_task_11 job_5_task_12  job_6_task_12
#            [74,94]        [118,197]      [197,292]      [314,385]      [423,451]      [464,530]      [538,604]      [636,642]      [642,707]      [720,764]      [764,808]      [885,889]      [915,979]      [1003,1098]    [1163,1167]
# Machine 7: job_2_task_0   job_13_task_3  job_14_task_2  job_9_task_1   job_5_task_2   job_1_task_4   job_11_task_6  job_3_task_6   job_7_task_4   job_6_task_5   job_10_task_8  job_0_task_12  job_12_task_10 job_4_task_12  job_8_task_14
#            [0,63]         [63,118]       [118,185]      [185,244]      [270,362]      [371,426]      [426,470]      [470,538]      [540,585]      [608,675]      [683,718]      [748,760]      [809,902]      [903,978]      [1232,1238]
# Machine 8: job_8_task_0   job_11_task_1  job_0_task_0   job_2_task_2   job_10_task_2  job_3_task_3   job_14_task_8  job_6_task_4   job_5_task_7   job_4_task_11  job_13_task_13 job_1_task_14  job_7_task_13  job_9_task_11  job_12_task_14
#            [0,19]         [28,39]        [40,136]       [179,242]      [305,311]      [328,351]      [451,515]      [515,608]      [702,790]      [790,847]      [854,945]      [948,1021]     [1027,1105]    [1110,1140]    [1142,1239]
# Machine 9: job_1_task_0   job_13_task_2  job_4_task_0   job_2_task_1   job_5_task_1   job_8_task_5   job_11_task_4  job_12_task_3  job_0_task_3   job_3_task_7   job_14_task_10 job_9_task_7   job_6_task_7   job_7_task_12  job_10_task_13
#            [0,32]         [32,40]        [40,86]        [86,179]       [179,270]      [270,307]      [307,342]      [342,367]      [403,429]      [538,570]      [596,676]      [754,789]      [817,911]      [967,1027]     [1046,1062]
# Machine 10: job_13_task_6  job_4_task_5   job_2_task_4   job_8_task_7   job_11_task_7  job_0_task_7   job_5_task_5   job_7_task_7   job_3_task_11  job_10_task_10 job_1_task_12  job_14_task_12 job_9_task_10  job_12_task_13 job_6_task_11
#            [283,362]      [362,364]      [364,374]      [374,437]      [489,528]      [528,599]      [599,635]      [652,694]      [694,765]      [766,865]      [865,870]      [870,963]      [963,1040]     [1040,1121]    [1121,1163]
# Machine 11: job_12_task_1  job_4_task_4   job_7_task_1   job_10_task_5  job_9_task_5   job_8_task_10  job_1_task_10  job_14_task_11 job_11_task_10 job_3_task_13  job_13_task_14 job_5_task_10  job_6_task_10  job_0_task_14  job_2_task_14
#            [188,220]      [260,353]      [384,408]      [408,497]      [642,679]      [679,734]      [734,826]      [826,849]      [849,889]      [889,956]      [956,978]      [978,991]      [991,1076]     [1076,1139]    [1141,1238]
# Machine 12: job_4_task_3   job_14_task_5  job_5_task_3   job_13_task_8  job_3_task_8   job_7_task_6   job_1_task_9   job_12_task_7  job_0_task_13  job_9_task_9   job_8_task_13  job_2_task_11  job_11_task_14 job_10_task_14 job_6_task_14
#            [218,259]      [346,375]      [375,462]      [462,530]      [570,644]      [645,648]      [648,692]      [692,753]      [760,851]      [851,910]      [910,972]      [972,1041]     [1041,1070]    [1070,1169]    [1169,1239]
# Machine 13: job_3_task_0   job_0_task_1   job_4_task_2   job_12_task_4  job_8_task_8   job_10_task_6  job_13_task_9  job_5_task_6   job_2_task_6   job_11_task_9  job_9_task_8   job_1_task_11  job_7_task_11  job_6_task_8   job_14_task_13
#            [0,80]         [136,159]      [207,218]      [367,407]      [437,477]      [497,535]      [535,634]      [635,702]      [702,729]      [753,802]      [812,837]      [837,857]      [891,950]      [950,962]      [991,1046]
# Machine 14: job_13_task_0  job_5_task_0   job_11_task_3  job_9_task_2   job_1_task_3   job_3_task_4   job_6_task_3   job_0_task_6   job_12_task_5  job_7_task_5   job_10_task_7  job_8_task_12  job_4_task_13  job_2_task_13  job_14_task_14
#            [0,9]          [9,14]         [157,208]      [244,250]      [292,371]      [371,425]      [425,501]      [501,528]      [528,613]      [616,645]      [645,683]      [854,908]      [978,1065]     [1075,1141]    [1146,1194]
# Machine 15: job_14_task_0  job_11_task_2  job_12_task_0  job_8_task_4   job_3_task_2   job_10_task_4  job_7_task_2   job_0_task_5   job_5_task_4   job_4_task_8   job_13_task_12 job_1_task_13  job_2_task_10  job_6_task_9   job_9_task_12
#            [0,80]         [81,157]       [157,188]      [194,260]      [260,328]      [328,379]      [416,457]      [480,496]      [496,562]      [562,605]      [749,841]      [876,948]      [948,956]      [962,967]      [1147,1148]
#
#
# Statistics
#   - conflicts: 56924
#   - branches : 62509
#   - wall time: 60.062115 s
#   - status   : FEASIBLE
#   - objective: 1239
#   - User Time  : 60
# --- 60.11 seconds ---
# This is the list number: 6
# Solution:
# Optimal Schedule Length: 1228.0
# Machine 1: job_2_task_0   job_6_task_1   job_0_task_3   job_10_task_3  job_12_task_4  job_3_task_2   job_1_task_5   job_8_task_7   job_5_task_8   job_4_task_9   job_9_task_10  job_11_task_13 job_7_task_14  job_14_task_14 job_13_task_14
#            [0,62]         [62,155]       [168,188]      [200,288]      [288,310]      [310,403]      [477,565]      [622,685]      [685,694]      [722,803]      [882,965]      [965,1007]     [1007,1068]    [1108,1201]    [1210,1216]
# Machine 2: job_7_task_1   job_12_task_1  job_10_task_2  job_1_task_1   job_2_task_2   job_13_task_4  job_8_task_4   job_5_task_5   job_9_task_4   job_6_task_7   job_0_task_8   job_3_task_7   job_11_task_12 job_14_task_13 job_4_task_14
#            [25,107]       [107,187]      [187,200]      [200,285]      [285,359]      [359,405]      [405,492]      [492,531]      [532,594]      [594,646]      [656,683]      [759,807]      [884,943]      [1063,1108]    [1108,1143]
# Machine 3: job_1_task_0   job_10_task_1  job_11_task_4  job_7_task_6   job_12_task_9  job_14_task_7  job_4_task_7   job_0_task_9   job_2_task_9   job_13_task_10 job_9_task_9   job_6_task_12  job_8_task_12  job_3_task_13  job_5_task_14
#            [0,44]         [44,143]       [237,238]      [325,391]      [509,547]      [547,570]      [620,672]      [727,745]      [745,828]      [828,836]      [857,882]      [882,978]      [978,1069]     [1069,1165]    [1169,1228]
# Machine 4: job_9_task_1   job_2_task_1   job_11_task_1  job_13_task_2  job_12_task_10 job_6_task_8   job_4_task_8   job_5_task_9   job_0_task_10  job_7_task_12  job_14_task_10 job_10_task_10 job_1_task_12  job_3_task_12  job_8_task_14
#            [29,54]        [63,135]       [159,181]      [181,210]      [560,586]      [646,693]      [693,722]      [722,815]      [815,866]      [866,900]      [900,935]      [947,964]      [964,1019]     [1019,1064]    [1169,1228]
# Machine 5: job_10_task_0  job_8_task_3   job_6_task_3   job_12_task_3  job_11_task_7  job_9_task_3   job_2_task_4   job_7_task_8   job_13_task_7  job_14_task_11 job_0_task_12  job_3_task_10  job_5_task_12  job_1_task_13  job_4_task_13
#            [0,20]         [143,159]      [159,210]      [210,266]      [266,350]      [350,415]      [422,517]      [517,573]      [573,648]      [935,952]      [952,962]      [962,983]      [983,1003]     [1019,1053]    [1053,1107]
# Machine 6: job_14_task_0  job_8_task_1   job_6_task_2   job_0_task_4   job_9_task_2   job_11_task_6  job_4_task_2   job_5_task_4   job_2_task_7   job_1_task_6   job_7_task_11  job_12_task_14 job_3_task_11  job_13_task_11 job_10_task_14
#            [1,90]         [90,121]       [155,159]      [191,192]      [192,261]      [261,264]      [294,364]      [405,482]      [574,608]      [608,669]      [829,845]      [845,939]      [983,1000]     [1000,1092]    [1118,1213]
# Machine 7: job_8_task_0   job_7_task_4   job_14_task_3  job_12_task_7  job_13_task_6  job_6_task_6   job_5_task_6   job_10_task_7  job_2_task_8   job_3_task_6   job_4_task_10  job_0_task_13  job_11_task_14 job_9_task_12  job_1_task_14
#            [0,82]         [193,260]      [329,361]      [411,438]      [457,500]      [511,529]      [531,572]      [572,656]      [656,745]      [758,759]      [803,863]      [962,1013]     [1013,1076]    [1076,1131]    [1142,1226]
# Machine 8: job_12_task_0  job_0_task_2   job_13_task_3  job_2_task_3   job_7_task_7   job_14_task_6  job_3_task_3   job_5_task_7   job_8_task_8   job_9_task_6   job_11_task_11 job_1_task_11  job_4_task_12  job_10_task_12 job_6_task_14
# ...
# Machine 16: job_62_task_0  job_92_task_0  job_79_task_1  job_51_task_2  job_26_task_1  job_27_task_6  job_4_task_3   job_17_task_2  job_9_task_5   job_38_task_3  job_25_task_1  job_18_task_2  job_20_task_3  job_30_task_6  job_99_task_4  job_19_task_6  job_23_task_6  job_87_task_9  job_60_task_2  job_31_task_6  job_35_task_3  job_71_task_2  job_42_task_7  job_13_task_9  job_2_task_6   job_85_task_9  job_47_task_14 job_56_task_12 job_95_task_10 job_96_task_9  job_21_task_8  job_50_task_15 job_78_task_9  job_83_task_16 job_5_task_11  job_46_task_6  job_11_task_9  job_74_task_11 job_86_task_4  job_64_task_11 job_63_task_17 job_53_task_8  job_59_task_19 job_49_task_5  job_44_task_13 job_77_task_1  job_36_task_19 job_54_task_7  job_45_task_10 job_39_task_18 job_0_task_15  job_48_task_3  job_16_task_19 job_72_task_11 job_67_task_18 job_97_task_15 job_89_task_17 job_40_task_8  job_68_task_15 job_80_task_15 job_6_task_12  job_8_task_6   job_58_task_14 job_10_task_4  job_24_task_18 job_32_task_11 job_52_task_17 job_94_task_13 job_69_task_11 job_61_task_9  job_29_task_9  job_7_task_10  job_34_task_18 job_90_task_6  job_91_task_5  job_93_task_14 job_33_task_18 job_76_task_15 job_41_task_7  job_73_task_14 job_3_task_15  job_98_task_19 job_88_task_12 job_65_task_13 job_22_task_11 job_12_task_14 job_55_task_7  job_1_task_11  job_81_task_16 job_14_task_19 job_84_task_8  job_66_task_19 job_70_task_13 job_75_task_19 job_43_task_14 job_82_task_18 job_57_task_19 job_37_task_18 job_28_task_19 job_15_task_19
#            [0,34]         [34,117]       [117,144]      [144,204]      [245,247]      [322,335]      [350,390]      [390,417]      [417,516]      [516,519]      [519,601]      [601,603]      [603,700]      [700,736]      [736,745]      [745,774]      [774,797]      [797,878]      [878,935]      [938,1012]     [1015,1029]    [1080,1168]    [1175,1205]    [1230,1259]    [1259,1346]    [1346,1352]    [1352,1384]    [1384,1462]    [1462,1463]    [1463,1559]    [1559,1565]    [1569,1605]    [1605,1660]    [1660,1727]    [1727,1817]    [1817,1818]    [1818,1851]    [1851,1886]    [1886,1934]    [1934,1964]    [1967,1974]    [1974,2044]    [2070,2136]    [2136,2188]    [2188,2216]    [2216,2248]    [2248,2262]    [2262,2337]    [2337,2417]    [2498,2535]    [2603,2659]    [2659,2743]    [2743,2823]    [2834,2890]    [3086,3114]    [3114,3185]    [3270,3343]    [3343,3351]    [3351,3391]    [3391,3474]    [3474,3489]    [3540,3607]    [3607,3622]    [3622,3693]    [3693,3702]    [3733,3740]    [3740,3775]    [3805,3823]    [3823,3902]    [3902,3975]    [3975,4027]    [4027,4037]    [4037,4096]    [4096,4133]    [4133,4203]    [4203,4204]    [4265,4310]    [4310,4367]    [4367,4453]    [4453,4476]    [4476,4503]    [4503,4531]    [4531,4565]    [4584,4640]    [4640,4711]    [4711,4785]    [4789,4837]    [4837,4923]    [4923,4945]    [4945,4989]    [4989,5003]    [5003,5034]    [5107,5194]    [5235,5244]    [5255,5270]    [5303,5374]    [5374,5411]    [5430,5522]    [5522,5526]    [5526,5623]
# Machine 17: job_66_task_0  job_87_task_0  job_74_task_0  job_34_task_0  job_24_task_1  job_4_task_1   job_5_task_0   job_79_task_3  job_85_task_0  job_33_task_4  job_63_task_1  job_18_task_0  job_83_task_7  job_72_task_1  job_19_task_5  job_56_task_3  job_38_task_8  job_17_task_8  job_31_task_4  job_9_task_8   job_3_task_6   job_0_task_4   job_39_task_6  job_42_task_4  job_35_task_4  job_59_task_5  job_99_task_6  job_30_task_11 job_28_task_1  job_44_task_9  job_98_task_3  job_2_task_8   job_36_task_9  job_94_task_5  job_43_task_2  job_13_task_15 job_68_task_1  job_25_task_15 job_88_task_2  job_54_task_5  job_23_task_19 job_86_task_7  job_46_task_12 job_16_task_14 job_50_task_19 job_14_task_5  job_47_task_18 job_51_task_11 job_58_task_7  job_71_task_14 job_80_task_5  job_64_task_18 job_21_task_13 job_81_task_5  job_77_task_6  job_78_task_12 job_11_task_13 job_67_task_13 job_95_task_12 job_6_task_6   job_27_task_16 job_49_task_18 job_60_task_19 job_96_task_18 job_20_task_12 job_48_task_13 job_97_task_17 job_15_task_6  job_32_task_6  job_89_task_19 job_52_task_12 job_75_task_12 job_92_task_15 job_8_task_8   job_93_task_9  job_45_task_18 job_91_task_2  job_1_task_8   job_41_task_5  job_76_task_12 job_69_task_16 job_73_task_11 job_7_task_11  job_65_task_8  job_90_task_12 job_62_task_19 job_82_task_9  job_53_task_18 job_26_task_10 job_10_task_16 job_40_task_13 job_70_task_7  job_22_task_14 job_61_task_19 job_12_task_18 job_55_task_10 job_57_task_16 job_29_task_19 job_37_task_15 job_84_task_18
#            [0,8]          [8,29]         [29,61]        [61,105]       [105,155]      [155,206]      [206,257]      [257,310]      [310,364]      [364,401]      [401,462]      [462,533]      [533,581]      [581,661]      [661,718]      [718,783]      [783,823]      [823,870]      [870,895]      [895,921]      [921,970]      [970,975]      [975,1046]     [1046,1087]    [1087,1152]    [1152,1192]    [1192,1236]    [1236,1305]    [1305,1389]    [1389,1413]    [1413,1491]    [1491,1498]    [1498,1539]    [1539,1624]    [1624,1710]    [1710,1788]    [1788,1878]    [1878,1945]    [1945,2037]    [2037,2051]    [2051,2066]    [2066,2109]    [2109,2112]    [2112,2156]    [2156,2241]    [2241,2335]    [2335,2383]    [2383,2436]    [2436,2495]    [2495,2507]    [2507,2546]    [2546,2552]    [2552,2615]    [2615,2659]    [2659,2696]    [2696,2742]    [2742,2819]    [2819,2877]    [2877,2921]    [2921,3016]    [3016,3069]    [3069,3090]    [3090,3182]    [3182,3209]    [3209,3251]    [3251,3326]    [3326,3338]    [3338,3394]    [3394,3423]    [3423,3480]    [3480,3549]    [3549,3637]    [3637,3726]    [3726,3790]    [3790,3798]    [3798,3893]    [3893,3981]    [3981,4077]    [4077,4174]    [4174,4190]    [4190,4234]    [4234,4294]    [4294,4329]    [4329,4427]    [4427,4431]    [4431,4448]    [4448,4547]    [4547,4643]    [4643,4656]    [4656,4682]    [4682,4768]    [4768,4862]    [4862,4878]    [4879,4912]    [4916,4941]    [4941,5024]    [5058,5090]    [5090,5153]    [5256,5287]    [5546,5548]
# Machine 18: job_64_task_0  job_82_task_0  job_27_task_1  job_66_task_1  job_9_task_1   job_1_task_0   job_2_task_0   job_24_task_2  job_76_task_1  job_33_task_3  job_25_task_0  job_78_task_3  job_87_task_6  job_17_task_4  job_75_task_6  job_30_task_5  job_21_task_1  job_72_task_3  job_39_task_5  job_56_task_4  job_60_task_1  job_36_task_3  job_46_task_2  job_16_task_3  job_71_task_1  job_31_task_7  job_47_task_12 job_83_task_11 job_85_task_8  job_42_task_9  job_23_task_12 job_5_task_8   job_0_task_8   job_69_task_1  job_50_task_12 job_63_task_13 job_99_task_11 job_22_task_2  job_74_task_9  job_49_task_1  job_4_task_10  job_13_task_18 job_68_task_3  job_34_task_12 job_59_task_18 job_53_task_9  job_54_task_6  job_35_task_8  job_19_task_8  job_18_task_14 job_86_task_9  job_80_task_3  job_20_task_6  job_40_task_5  job_8_task_1   job_67_task_9  job_45_task_12 job_51_task_13 job_97_task_10 job_77_task_7  job_95_task_11 job_96_task_15 job_32_task_1  job_15_task_3  job_48_task_10 job_6_task_7   job_89_task_15 job_11_task_17 job_92_task_10 job_14_task_14 job_61_task_2  job_62_task_13 job_29_task_5  job_57_task_4  job_52_task_13 job_93_task_8  job_7_task_4   job_94_task_11 job_3_task_9   job_98_task_13 job_73_task_9  job_58_task_17 job_12_task_11 job_26_task_7  job_28_task_11 job_84_task_1  job_37_task_4  job_55_task_4  job_43_task_6  job_88_task_13 job_44_task_19 job_10_task_19 job_65_task_19 job_70_task_9  job_81_task_17 job_90_task_15 job_91_task_16 job_79_task_18 job_41_task_18 job_38_task_18
#            [0,3]          [3,14]         [14,15]        [15,17]        [17,82]        [82,150]       [150,218]      [218,265]      [265,298]      [298,350]      [350,418]      [418,488]      [488,525]      [525,559]      [559,609]      [609,660]      [660,724]      [724,767]      [767,793]      [793,804]      [804,877]      [890,944]      [944,968]      [978,1006]     [1006,1080]    [1080,1128]    [1164,1209]    [1209,1237]    [1237,1282]    [1282,1291]    [1291,1355]    [1355,1402]    [1402,1467]    [1467,1542]    [1542,1562]    [1562,1620]    [1620,1678]    [1678,1754]    [1754,1783]    [1783,1861]    [1861,1932]    [1932,1982]    [1982,2008]    [2008,2066]    [2066,2070]    [2070,2095]    [2095,2120]    [2120,2170]    [2170,2249]    [2249,2273]    [2273,2304]    [2304,2383]    [2383,2432]    [2432,2482]    [2482,2505]    [2505,2559]    [2559,2614]    [2614,2673]    [2673,2723]    [2723,2758]    [2758,2837]    [2837,2916]    [2916,2997]    [2997,3079]    [3079,3089]    [3089,3106]    [3106,3151]    [3151,3232]    [3232,3251]    [3251,3252]    [3252,3338]    [3338,3398]    [3398,3487]    [3487,3577]    [3577,3578]    [3578,3668]    [3673,3695]    [3695,3785]    [3785,3877]    [3911,3992]    [3992,4084]    [4088,4089]    [4089,4188]    [4188,4287]    [4287,4386]    [4386,4475]    [4475,4574]    [4574,4634]    [4634,4733]    [4733,4751]    [4751,4789]    [4813,4834]    [4859,4874]    [4909,4944]    [4945,4958]    [4958,4960]    [5267,5276]    [5400,5448]    [5448,5534]    [5534,5581]
# Machine 19: job_29_task_0  job_22_task_0  job_24_task_0  job_79_task_0  job_55_task_0  job_89_task_1  job_92_task_1  job_76_task_0  job_52_task_1  job_58_task_1  job_41_task_4  job_83_task_3  job_30_task_4  job_23_task_3  job_17_task_5  job_47_task_7  job_39_task_4  job_74_task_4  job_42_task_2  job_44_task_6  job_72_task_4  job_5_task_6   job_99_task_5  job_21_task_2  job_0_task_7   job_95_task_8  job_93_task_5  job_85_task_10 job_28_task_2  job_57_task_2  job_25_task_10 job_31_task_11 job_50_task_14 job_59_task_13 job_14_task_1  job_64_task_6  job_33_task_8  job_96_task_12 job_16_task_12 job_86_task_3  job_51_task_7  job_36_task_14 job_43_task_4  job_35_task_6  job_87_task_18 job_13_task_19 job_63_task_19 job_2_task_11  job_18_task_13 job_19_task_9  job_71_task_13 job_45_task_11 job_60_task_15 job_81_task_4  job_4_task_14  job_46_task_19 job_88_task_8  job_48_task_6  job_67_task_14 job_49_task_17 job_11_task_16 job_80_task_13 job_27_task_17 job_6_task_9   job_73_task_7  job_54_task_17 job_97_task_19 job_9_task_18  job_15_task_7  job_77_task_18 job_34_task_15 job_61_task_7  job_98_task_10 job_7_task_7   job_68_task_19 job_62_task_16 job_69_task_13 job_94_task_16 job_75_task_16 job_66_task_8  job_32_task_16 job_1_task_9   job_3_task_10  job_53_task_16 job_90_task_10 job_70_task_5  job_8_task_10  job_65_task_10 job_10_task_14 job_38_task_11 job_78_task_18 job_91_task_12 job_26_task_13 job_37_task_9  job_40_task_15 job_20_task_18 job_12_task_19 job_56_task_19 job_82_task_15 job_84_task_14
#            [0,5]          [5,11]         [11,35]        [35,67]        [67,105]       [105,148]      [148,177]      [177,229]      [229,242]      [242,309]      [309,332]      [332,350]      [363,437]      [517,616]      [616,621]      [621,675]      [675,695]      [713,750]      [794,804]      [804,879]      [879,955]      [955,1043]     [1043,1125]    [1125,1205]    [1205,1226]    [1226,1294]    [1294,1368]    [1368,1448]    [1448,1477]    [1477,1507]    [1507,1524]    [1524,1552]    [1567,1569]    [1579,1592]    [1592,1671]    [1671,1681]    [1692,1737]    [1737,1759]    [1759,1783]    [1783,1793]    [1793,1819]    [1819,1851]    [1851,1921]    [1921,2008]    [2008,2013]    [2013,2035]    [2059,2064]    [2064,2135]    [2215,2224]    [2249,2330]    [2348,2366]    [2417,2441]    [2466,2565]    [2565,2586]    [2586,2642]    [2642,2727]    [2727,2752]    [2850,2862]    [2877,2923]    [2926,2999]    [2999,3065]    [3065,3107]    [3107,3166]    [3166,3245]    [3245,3339]    [3339,3403]    [3403,3464]    [3464,3474]    [3474,3552]    [3552,3574]    [3574,3663]    [3698,3707]    [3707,3753]    [3802,3858]    [3858,3954]    [3954,3977]    [3977,4015]    [4015,4019]    [4019,4038]    [4038,4067]    [4067,4099]    [4099,4160]    [4160,4243]    [4284,4341]    [4341,4357]    [4357,4396]    [4396,4494]    [4494,4506]    [4506,4599]    [4618,4629]    [4629,4714]    [4734,4801]    [4801,4818]    [4828,4846]    [4877,4921]    [4936,4999]    [5010,5042]    [5074,5140]    [5140,5149]    [5352,5440]
# Machine 20: job_28_task_0  job_82_task_1  job_65_task_0  job_62_task_3  job_1_task_2   job_97_task_3  job_92_task_2  job_19_task_2  job_93_task_1  job_3_task_1   job_83_task_6  job_63_task_2  job_67_task_6  job_87_task_7  job_39_task_2  job_13_task_1  job_95_task_2  job_75_task_7  job_47_task_8  job_45_task_3  job_40_task_2  job_73_task_2  job_17_task_10 job_2_task_4   job_59_task_7  job_21_task_4  job_99_task_8  job_25_task_9  job_5_task_9   job_16_task_10 job_72_task_7  job_96_task_11 job_36_task_13 job_23_task_17 job_94_task_8  job_74_task_10 job_64_task_9  job_50_task_17 job_54_task_4  job_11_task_10 job_86_task_6  job_4_task_12  job_30_task_19 job_68_task_5  job_33_task_11 job_49_task_6  job_35_task_10 job_51_task_10 job_18_task_15 job_80_task_4  job_14_task_7  job_46_task_18 job_77_task_5  job_8_task_3   job_71_task_16 job_85_task_17 job_27_task_14 job_89_task_12 job_88_task_9  job_60_task_18 job_32_task_2  job_9_task_14  job_98_task_6  job_52_task_10 job_58_task_12 job_6_task_10  job_24_task_14 job_48_task_16 job_29_task_6  job_0_task_18  job_78_task_17 job_76_task_10 job_34_task_17 job_10_task_7  job_57_task_7  job_44_task_15 job_41_task_6  job_69_task_18 job_42_task_17 job_26_task_8  job_61_task_16 job_66_task_16 job_79_task_12 job_53_task_19 job_91_task_11 job_43_task_7  job_37_task_8  job_81_task_15 job_12_task_17 job_90_task_14 job_84_task_7  job_56_task_18 job_7_task_18  job_20_task_19 job_55_task_14 job_38_task_16 job_15_task_17 job_70_task_18 job_31_task_17 job_22_task_19
#            [0,31]         [31,77]        [77,164]       [164,215]      [215,237]      [237,259]      [259,286]      [286,328]      [328,384]      [384,456]      [456,494]      [494,519]      [519,528]      [528,549]      [549,606]      [606,679]      [679,683]      [683,693]      [693,769]      [769,777]      [777,854]      [854,952]      [952,1004]     [1015,1047]    [1210,1242]    [1256,1331]    [1331,1340]    [1340,1424]    [1424,1460]    [1528,1592]    [1620,1664]    [1664,1706]    [1706,1743]    [1743,1746]    [1746,1786]    [1786,1800]    [1800,1833]    [1833,1929]    [1929,1980]    [1980,2037]    [2037,2038]    [2038,2078]    [2078,2103]    [2103,2113]    [2113,2188]    [2188,2235]    [2235,2334]    [2334,2362]    [2362,2401]    [2401,2452]    [2452,2471]    [2510,2601]    [2621,2627]    [2666,2685]    [2696,2768]    [2768,2809]    [2809,2851]    [2851,2936]    [2936,2960]    [2960,3025]    [3025,3089]    [3089,3101]    [3101,3169]    [3189,3208]    [3208,3302]    [3302,3380]    [3380,3411]    [3437,3490]    [3490,3530]    [3530,3626]    [3626,3725]    [3725,3775]    [3775,3838]    [3858,3954]    [3954,3977]    [4093,4113]    [4187,4278]    [4310,4327]    [4327,4375]    [4378,4464]    [4464,4467]    [4467,4541]    [4541,4588]    [4647,4690]    [4690,4734]    [4734,4768]    [4781,4828]    [4828,4906]    [4906,4916]    [4916,4944]    [4944,4974]    [4974,4996]    [5010,5105]    [5105,5150]    [5217,5312]    [5318,5337]    [5337,5427]    [5427,5519]    [5526,5585]    [5585,5624]
#
#
# Statistics
#   - conflicts: 999
#   - branches : 10133
#   - wall time: 59.660559 s
#   - status   : FEASIBLE
#   - objective: 5627
#   - User Time  : 59
# --- 59.96 seconds ---
# --- 592.17 seconds for the file---
# --- 4688.78 seconds for the cell---
