# %% [markdown]
# # JOB SHOP SCHEDULING

# %%
import pandas as pd
import numpy as np
from ortools.linear_solver import pywraplp
from ortools.init import pywrapinit
import pandas as pd 
import time
import collections
from ortools.linear_solver import pywraplp
import time

# %% [markdown]
# ## Main functions

# %%
def extract_data(filename):
    # Initialize variables to store the data.
    nj = []
    nm = []
    times = []
    machines = []

    task_counter = 0
    task_matrix = []


    # Open the file and read each line.
    with open(filename, 'r') as file:
        contents = file.read()
        lines = contents.splitlines()

        for line in range(len(lines)):
            # Check if the line contains the number of jobs and machines.
            if 'Nb of jobs' in lines[line]:
                nj.append(lines[line + 1].split()[0])
                nm.append(lines[line + 1].split()[1])
                break
        
        num_jobs = int(nj[0])
        num_machines = int(nm[0])

        for line in range(len(lines)):

            if 'Nb of jobs' in lines[line]:
                continue

            elif ' ' in lines[line]:
                continue

            elif 'Times' in lines[line]:

                task_matrix.append(task_counter)
                task_matrix[task_counter] = []

                job_counter = 0

                pos = 0
                while pos < num_jobs:
                    pos += 1
                    time_var = lines[line + pos].split()
                    machine_var = lines[line + pos + num_jobs + 1].split()

                    task_matrix[task_counter].append([])
                    
                    #print('new times/machines pairs')
                    for aux in range(len(time_var)):
                        #print(f'{time_var[aux]} , {machine_var[aux]}')
                        task_matrix[task_counter][job_counter].append((int(time_var[aux]), int(machine_var[aux])))
                    
                    job_counter += 1

                task_counter +=1

        #print(task_matrix)

    return (num_jobs, num_machines, task_matrix)

# %%
num_jobs, num_machines, task_matrix = extract_data('tai15_15.txt')

# %%
a =[]
for i in task_matrix:
    for j in i:
        a.append(j)

# %%
def main(jobs_data):
    machines_count = num_machines
    all_machines = range(1,machines_count+1,1)
    # Computes horizon dynamically as the sum of all durations.
    horizon = sum(task[0] for job in jobs_data for task in job)

    # Named tuple to store information about created variables.
    task_type = collections.namedtuple('task_type', 'start end interval')
    # Named tuple to manipulate solution information.
    assigned_task_type = collections.namedtuple('assigned_task_type',
                                                'start job index duration')

    # Create the MIP solver with the CBC backend.
    solver = pywraplp.Solver('schedule_jobs_mip',
                            pywraplp.Solver.SCIP_MIXED_INTEGER_PROGRAMMING)

    # Creates job intervals and add to the corresponding machine lists.
    all_tasks = {}
    machine_to_intervals = collections.defaultdict(list)

    # Create binary variables for task overlap.
    x = {}
    M = 1000000  # Large constant for precedence constraints.
    for job_id, job in enumerate(jobs_data):
        for task_id, task in enumerate(job):
            for other_task_id, other_task in enumerate(job):
                if task_id != other_task_id:
                    x[job_id, task_id, other_task_id] = solver.BoolVar(
                        'x_%i_%i_%i' % (job_id, task_id, other_task_id))

    for job_id, job in enumerate(jobs_data):
        #print(job_id,job)
        for task_id, task in enumerate(job):
            #print(task_id+1, task)
            duration = task[0]
            machine = task[1]
            suffix = '_%i_%i' % (job_id, task_id)

            start_var = solver.IntVar(0, horizon, 'start' + suffix)
            #end_var = solver.IntVar(0, horizon, 'end' + suffix)
            end_var = start_var + duration
            #interval_var = solver.ComputeExactConditionNumber(0,horizon, name = 'interval' + suffix)
            all_tasks[job_id, task_id] = task_type(start=start_var,
                                                end = end_var,
                                                interval = None)
            machine_to_intervals[machine].append(start_var)
            #correto
    # # Create precedence constraints for tasks on the same machine.
    for job_id, job in enumerate(jobs_data):
        for task_id, task in enumerate(job):
            for other_task_id, other_task in enumerate(job):
                if task_id != other_task_id:
                    x[job_id, task_id, other_task_id] = solver.BoolVar(
                        'x_%i_%i_%i' % (job_id, task_id, other_task_id))
    # Add constraints to ensure that the start time, duration, and end time variables
    # represent a valid time interval.
    #solver.Add(end_var == start_var + interval_var)


    # Makespan objective.
    obj_var = solver.IntVar(0, horizon, 'makespan')
    for job_id, job in enumerate(jobs_data):
        solver.Add(obj_var >= all_tasks[job_id, len(job) - 1].end)
    solver.Minimize(obj_var)

    if solver.Solve() == pywraplp.Solver.OPTIMAL or solver.Solve() == pywraplp.Solver.FEASIBLE:
        print('Solution:')
        # Create one list of assigned tasks per machine.
        assigned_jobs = collections.defaultdict(list)
        for job_id, job in enumerate(jobs_data):
            for task_id, task in enumerate(job):
                machine = task[1]
                assigned_jobs[machine].append(
                    assigned_task_type(solver.Objective().Value(
                        ),
                                        job=job_id,
                                        index=task_id,
                                        duration=task[0]))
            # Create per machine output lines.
        output = ''
        for machine in all_machines:
            # Sort by starting time.
            assigned_jobs[machine].sort()
            sol_line_tasks = 'Machine ' + str(machine) + ': '
            sol_line = '           '

            for assigned_task in assigned_jobs[machine]:
                name = 'job_%i_task_%i' % (assigned_task.job,
                                            assigned_task.index)
                # Add spaces to output to align columns.
                sol_line_tasks += '%-15s' % name

                start = assigned_task.start
                duration = assigned_task.duration

                sol_tmp = '[%i,%i]' % (start,duration)
                # Add spaces to output to align columns.
                sol_line += '%-15s' % sol_tmp

            sol_line += '\n'
            sol_line_tasks += '\n'
            output += sol_line_tasks
            output += sol_line

        # Finally print the solution found.
        print(f'Optimal Schedule Length: {solver.Objective().Value()}')
        print(output)
    else:
        print('No solution found.')

# %%
list_files = ['tai15_15.txt','tai20_15.txt','tai20_20.txt','tai30_15.txt','tai30_20.txt','tai50_15.txt','tai50_20.txt','tai100_20.txt']
start_cell_time = time.time()
for i in range(len(list_files)):
    start_list_time = time.time()
    print(f'This is the file: {list_files[i]}')
    num_jobs, num_machines, task_matrix = extract_data(list_files[i])
    for i in range(len(task_matrix)):
        start_time = time.time()
        print (f'This is the list number: {i}')
        main(task_matrix[i])
        print("--- %.2f seconds ---" % (time.time() - start_time))
    print("--- %.2f seconds for the file---" % (time.time() - start_list_time))
print("--- %.2f seconds for the cell---" % (time.time() - start_cell_time))
# Out:
# This is the file: tai15_15.txt
# This is the list number: 0
# Solution:
# Optimal Schedule Length: 97.0
# Machine 1: job_0_task_13  job_1_task_10  job_2_task_8   job_3_task_5   job_4_task_13  job_5_task_11  job_6_task_12  job_7_task_2   job_8_task_4   job_9_task_5   job_10_task_3  job_11_task_2  job_12_task_7  job_13_task_14 job_14_task_9
#            [97,70]        [97,18]        [97,54]        [97,94]        [97,42]        [97,87]        [97,37]        [97,9]         [97,13]        [97,17]        [97,8]         [97,75]        [97,77]        [97,35]        [97,8]
# Machine 2: job_0_task_14  job_1_task_13  job_2_task_0   job_3_task_13  job_4_task_10  job_5_task_9   job_6_task_6   job_7_task_7   job_8_task_5   job_9_task_10  job_10_task_11 job_11_task_11 job_12_task_10 job_13_task_7  job_14_task_5
#            [97,83]        [97,99]        [97,4]         [97,92]        [97,93]        [97,26]        [97,19]        [97,62]        [97,87]        [97,69]        [97,93]        [97,45]        [97,48]        [97,56]        [97,26]
# Machine 3: job_0_task_5   job_1_task_14  job_2_task_9   job_3_task_1   job_4_task_6   job_5_task_8   job_6_task_10  job_7_task_8   job_8_task_6   job_9_task_3   job_10_task_14 job_11_task_0  job_12_task_3  job_13_task_13 job_14_task_12
#            [97,15]        [97,33]        [97,68]        [97,23]        [97,95]        [97,78]        [97,43]        [97,6]         [97,82]        [97,60]        [97,73]        [97,47]        [97,20]        [97,7]         [97,83]
# Machine 4: job_0_task_4   job_1_task_11  job_2_task_13  job_3_task_14  job_4_task_14  job_5_task_1   job_6_task_1   job_7_task_11  job_8_task_14  job_9_task_7   job_10_task_10 job_11_task_12 job_12_task_4  job_13_task_12 job_14_task_11
#            [97,26]        [97,51]        [97,35]        [97,9]         [97,96]        [97,61]        [97,75]        [97,80]        [97,15]        [97,89]        [97,90]        [97,67]        [97,31]        [97,16]        [97,87]
# Machine 5: job_0_task_2   job_1_task_0   job_2_task_12  job_3_task_7   job_4_task_4   job_5_task_5   job_6_task_8   job_7_task_10  job_8_task_9   job_9_task_13  job_10_task_0  job_11_task_14 job_12_task_9  job_13_task_2  job_14_task_4
#            [97,10]        [97,74]        [97,39]        [97,93]        [97,36]        [97,31]        [97,85]        [97,7]         [97,56]        [97,6]         [97,90]        [97,87]        [97,80]        [97,51]        [97,37]
# Machine 6: job_0_task_12  job_1_task_1   job_2_task_7   job_3_task_0   job_4_task_9   job_5_task_0   job_6_task_9   job_7_task_1   job_8_task_7   job_9_task_14  job_10_task_4  job_11_task_7  job_12_task_0  job_13_task_4  job_14_task_14
#            [97,96]        [97,31]        [97,6]         [97,73]        [97,76]        [97,29]        [97,73]        [97,52]        [97,83]        [97,13]        [97,91]        [97,34]        [97,65]        [97,17]        [97,97]
# Machine 7: job_0_task_0   job_1_task_8   job_2_task_4   job_3_task_3   job_4_task_2   job_5_task_13  job_6_task_5   job_7_task_13  job_8_task_2   job_9_task_0   job_10_task_6  job_11_task_4  job_12_task_5  job_13_task_5  job_14_task_3
#            [97,94]        [97,91]        [97,50]        [97,30]        [97,21]        [97,14]        [97,68]        [97,57]        [97,96]        [97,5]         [97,89]        [97,51]        [97,33]        [97,89]        [97,34]
# Machine 8: job_0_task_3   job_1_task_2   job_2_task_10  job_3_task_8   job_4_task_0   job_5_task_7   job_6_task_2   job_7_task_3   job_8_task_11  job_9_task_9   job_10_task_1  job_11_task_6  job_12_task_13 job_13_task_9  job_14_task_10
#            [97,53]        [97,88]        [97,82]        [97,32]        [97,78]        [97,83]        [97,20]        [97,49]        [97,8]         [97,88]        [97,27]        [97,84]        [97,96]        [97,18]        [97,12]
# Machine 9: job_0_task_8   job_1_task_5   job_2_task_1   job_3_task_11  job_4_task_1   job_5_task_14  job_6_task_3   job_7_task_9   job_8_task_10  job_9_task_4   job_10_task_7  job_11_task_8  job_12_task_1  job_13_task_0  job_14_task_1
#            [97,10]        [97,78]        [97,82]        [97,56]        [97,23]        [97,30]        [97,4]         [97,62]        [97,85]        [97,41]        [97,49]        [97,28]        [97,62]        [97,28]        [97,16]
# Machine 10: job_0_task_10  job_1_task_7   job_2_task_2   job_3_task_2   job_4_task_5   job_5_task_12  job_6_task_14  job_7_task_12  job_8_task_12  job_9_task_2   job_10_task_13 job_11_task_9  job_12_task_6  job_13_task_6  job_14_task_13
#            [97,93]        [97,7]         [97,40]        [97,30]        [97,29]        [97,62]        [97,66]        [97,3]         [97,66]        [97,30]        [97,35]        [97,60]        [97,33]        [97,59]        [97,20]
# Machine 11: job_0_task_6   job_1_task_9   job_2_task_11  job_3_task_4   job_4_task_3   job_5_task_10  job_6_task_11  job_7_task_14  job_8_task_0   job_9_task_8   job_10_task_9  job_11_task_5  job_12_task_2  job_13_task_11 job_14_task_0
#            [97,65]        [97,79]        [97,20]        [97,53]        [97,60]        [97,50]        [97,24]        [97,7]         [97,85]        [97,78]        [97,28]        [97,3]         [97,97]        [97,30]        [97,57]
# Machine 12: job_0_task_7   job_1_task_6   job_2_task_5   job_3_task_10  job_4_task_12  job_5_task_4   job_6_task_7   job_7_task_0   job_8_task_1   job_9_task_1   job_10_task_12 job_11_task_13 job_12_task_11 job_13_task_10 job_14_task_8
#            [97,82]        [97,8]         [97,54]        [97,30]        [97,52]        [97,16]        [97,54]        [97,32]        [97,30]        [97,59]        [97,6]         [97,58]        [97,90]        [97,17]        [97,5]
# Machine 13: job_0_task_1   job_1_task_12  job_2_task_3   job_3_task_12  job_4_task_8   job_5_task_2   job_6_task_0   job_7_task_4   job_8_task_8   job_9_task_11  job_10_task_5  job_11_task_3  job_12_task_12 job_13_task_8  job_14_task_2
#            [97,66]        [97,18]        [97,86]        [97,27]        [97,79]        [97,88]        [97,18]        [97,61]        [97,78]        [97,45]        [97,80]        [97,8]         [97,75]        [97,63]        [97,42]
# Machine 14: job_0_task_11  job_1_task_4   job_2_task_6   job_3_task_6   job_4_task_11  job_5_task_3   job_6_task_13  job_7_task_5   job_8_task_13  job_9_task_6   job_10_task_2  job_11_task_10 job_12_task_8  job_13_task_3  job_14_task_6
#            [97,92]        [97,57]        [97,21]        [97,58]        [97,42]        [97,70]        [97,87]        [97,35]        [97,88]        [97,66]        [97,1]         [97,69]        [97,50]        [97,75]        [97,68]
# Machine 15: job_0_task_9   job_1_task_3   job_2_task_14  job_3_task_9   job_4_task_7   job_5_task_6   job_6_task_4   job_7_task_6   job_8_task_3   job_9_task_12  job_10_task_8  job_11_task_1  job_12_task_14 job_13_task_1  job_14_task_7
#            [97,27]        [97,51]        [97,68]        [97,91]        [97,99]        [97,65]        [97,91]        [97,99]        [97,91]        [97,82]        [97,32]        [97,43]        [97,44]        [97,21]        [97,73]
#
# --- 0.15 seconds ---
# This is the list number: 1
# Solution:
# Optimal Schedule Length: 98.0
# Machine 1: job_0_task_8   job_1_task_14  job_2_task_1   job_3_task_3   job_4_task_12  job_5_task_4   job_6_task_3   job_7_task_1   job_8_task_10  job_9_task_6   job_10_task_9  job_11_task_11 job_12_task_3  job_13_task_12 job_14_task_4
#            [98,98]        [98,23]        [98,67]        [98,88]        [98,73]        [98,10]        [98,34]        [98,64]        [98,16]        [98,6]         [98,25]        [98,32]        [98,28]        [98,36]        [98,84]
# Machine 2: job_0_task_10  job_1_task_11  job_2_task_10  job_3_task_4   job_4_task_5   job_5_task_2   job_6_task_6   job_7_task_13  job_8_task_4   job_9_task_5   job_10_task_6  job_11_task_9  job_12_task_8  job_13_task_5  job_14_task_0
#            [98,43]        [98,11]        [98,22]        [98,24]        [98,41]        [98,93]        [98,8]         [98,11]        [98,91]        [98,3]         [98,52]        [98,62]        [98,81]        [98,23]        [98,36]
# Machine 3: job_0_task_11  job_1_task_9   job_2_task_6   job_3_task_14  job_4_task_8   job_5_task_1   job_6_task_11  job_7_task_8   job_8_task_11  job_9_task_0   job_10_task_10 job_11_task_10 job_12_task_11 job_13_task_0  job_14_task_3
#            [98,8]         [98,86]        [98,60]        [98,4]         [98,19]        [98,60]        [98,92]        [98,96]        [98,83]        [98,5]         [98,9]         [98,39]        [98,42]        [98,11]        [98,24]
# Machine 4: job_0_task_5   job_1_task_4   job_2_task_12  job_3_task_11  job_4_task_3   job_5_task_9   job_6_task_14  job_7_task_3   job_8_task_8   job_9_task_2   job_10_task_13 job_11_task_1  job_12_task_14 job_13_task_3  job_14_task_12
#            [98,94]        [98,93]        [98,38]        [98,90]        [98,13]        [98,41]        [98,70]        [98,44]        [98,68]        [98,21]        [98,41]        [98,32]        [98,53]        [98,59]        [98,20]
# Machine 5: job_0_task_2   job_1_task_8   job_2_task_8   job_3_task_9   job_4_task_1   job_5_task_5   job_6_task_13  job_7_task_14  job_8_task_14  job_9_task_9   job_10_task_4  job_11_task_4  job_12_task_6  job_13_task_2  job_14_task_2
#            [98,10]        [98,62]        [98,20]        [98,68]        [98,52]        [98,72]        [98,85]        [98,94]        [98,23]        [98,64]        [98,73]        [98,29]        [98,24]        [98,27]        [98,38]
# Machine 6: job_0_task_9   job_1_task_12  job_2_task_3   job_3_task_6   job_4_task_14  job_5_task_0   job_6_task_0   job_7_task_6   job_8_task_2   job_9_task_10  job_10_task_3  job_11_task_12 job_12_task_2  job_13_task_1  job_14_task_10
#            [98,49]        [98,20]        [98,91]        [98,78]        [98,19]        [98,62]        [98,50]        [98,21]        [98,51]        [98,76]        [98,68]        [98,8]         [98,3]         [98,93]        [98,68]
# Machine 7: job_0_task_13  job_1_task_10  job_2_task_2   job_3_task_12  job_4_task_10  job_5_task_8   job_6_task_12  job_7_task_5   job_8_task_9   job_9_task_4   job_10_task_7  job_11_task_13 job_12_task_10 job_13_task_9  job_14_task_6
#            [98,21]        [98,65]        [98,96]        [98,58]        [98,85]        [98,58]        [98,62]        [98,91]        [98,13]        [98,66]        [98,39]        [98,33]        [98,44]        [98,64]        [98,72]
# Machine 8: job_0_task_6   job_1_task_7   job_2_task_0   job_3_task_13  job_4_task_11  job_5_task_11  job_6_task_9   job_7_task_7   job_8_task_7   job_9_task_12  job_10_task_14 job_11_task_5  job_12_task_12 job_13_task_8  job_14_task_5
#            [98,71]        [98,28]        [98,33]        [98,7]         [98,99]        [98,63]        [98,53]        [98,1]         [98,40]        [98,17]        [98,98]        [98,68]        [98,2]         [98,77]        [98,47]
# Machine 9: job_0_task_7   job_1_task_1   job_2_task_14  job_3_task_5   job_4_task_4   job_5_task_6   job_6_task_5   job_7_task_11  job_8_task_6   job_9_task_11  job_10_task_11 job_11_task_3  job_12_task_0  job_13_task_13 job_14_task_14
#            [98,25]        [98,28]        [98,82]        [98,16]        [98,19]        [98,88]        [98,5]         [98,12]        [98,63]        [98,94]        [98,34]        [98,10]        [98,28]        [98,53]        [98,30]
# Machine 10: job_0_task_0   job_1_task_6   job_2_task_11  job_3_task_0   job_4_task_13  job_5_task_10  job_6_task_4   job_7_task_2   job_8_task_5   job_9_task_14  job_10_task_5  job_11_task_14 job_12_task_5  job_13_task_4  job_14_task_7
#            [98,86]        [98,37]        [98,79]        [98,13]        [98,95]        [98,46]        [98,44]        [98,92]        [98,90]        [98,37]        [98,27]        [98,91]        [98,59]        [98,62]        [98,1]
# Machine 11: job_0_task_4   job_1_task_0   job_2_task_13  job_3_task_7   job_4_task_6   job_5_task_3   job_6_task_1   job_7_task_12  job_8_task_1   job_9_task_3   job_10_task_12 job_11_task_2  job_12_task_9  job_13_task_10 job_14_task_1
#            [98,65]        [98,68]        [98,40]        [98,70]        [98,71]        [98,16]        [98,68]        [98,41]        [98,46]        [98,14]        [98,50]        [98,35]        [98,8]         [98,60]        [98,98]
# Machine 12: job_0_task_14  job_1_task_2   job_2_task_7   job_3_task_1   job_4_task_0   job_5_task_12  job_6_task_7   job_7_task_10  job_8_task_0   job_9_task_8   job_10_task_0  job_11_task_7  job_12_task_4  job_13_task_6  job_14_task_8
#            [98,73]        [98,38]        [98,88]        [98,14]        [98,93]        [98,76]        [98,25]        [98,59]        [98,93]        [98,63]        [98,35]        [98,8]         [98,66]        [98,23]        [98,91]
# Machine 13: job_0_task_12  job_1_task_13  job_2_task_9   job_3_task_8   job_4_task_7   job_5_task_13  job_6_task_10  job_7_task_0   job_8_task_13  job_9_task_13  job_10_task_8  job_11_task_0  job_12_task_7  job_13_task_14 job_14_task_9
#            [98,90]        [98,82]        [98,62]        [98,53]        [98,59]        [98,83]        [98,78]        [98,60]        [98,24]        [98,62]        [98,41]        [98,23]        [98,45]        [98,72]        [98,85]
# Machine 14: job_0_task_3   job_1_task_5   job_2_task_5   job_3_task_10  job_4_task_2   job_5_task_14  job_6_task_2   job_7_task_4   job_8_task_3   job_9_task_7   job_10_task_2  job_11_task_6  job_12_task_1  job_13_task_7  job_14_task_13
#            [98,59]        [98,35]        [98,81]        [98,73]        [98,63]        [98,62]        [98,90]        [98,63]        [98,37]        [98,98]        [98,62]        [98,20]        [98,31]        [98,7]         [98,30]
# Machine 15: job_0_task_1   job_1_task_3   job_2_task_4   job_3_task_2   job_4_task_9   job_5_task_7   job_6_task_8   job_7_task_9   job_8_task_12  job_9_task_1   job_10_task_1  job_11_task_8  job_12_task_13 job_13_task_11 job_14_task_11
#            [98,60]        [98,36]        [98,83]        [98,73]        [98,60]        [98,69]        [98,70]        [98,19]        [98,49]        [98,35]        [98,42]        [98,58]        [98,23]        [98,97]        [98,42]
#
# --- 0.13 seconds ---
# This is the list number: 2
# Solution:
# Optimal Schedule Length: 88.0
# Machine 1: job_0_task_7   job_1_task_13  job_2_task_3   job_3_task_8   job_4_task_13  job_5_task_10  job_6_task_2   job_7_task_14  job_8_task_2   job_9_task_1   job_10_task_13 job_11_task_0  job_12_task_10 job_13_task_3  job_14_task_2
#            [88,62]        [88,89]        [88,54]        [88,41]        [88,89]        [88,56]        [88,21]        [88,27]        [88,33]        [88,4]         [88,92]        [88,78]        [88,57]        [88,63]        [88,14]
# Machine 2: job_0_task_5   job_1_task_1   job_2_task_0   job_3_task_13  job_4_task_0   job_5_task_5   job_6_task_3   job_7_task_3   job_8_task_11  job_9_task_7   job_10_task_2  job_11_task_12 job_12_task_7  job_13_task_7  job_14_task_0
#            [88,3]         [88,51]        [88,62]        [88,3]         [88,36]        [88,94]        [88,27]        [88,3]         [88,22]        [88,46]        [88,81]        [88,24]        [88,17]        [88,90]        [88,73]
# Machine 3: job_0_task_12  job_1_task_6   job_2_task_1   job_3_task_3   job_4_task_7   job_5_task_2   job_6_task_1   job_7_task_6   job_8_task_13  job_9_task_12  job_10_task_1  job_11_task_14 job_12_task_13 job_13_task_1  job_14_task_4
#            [88,3]         [88,52]        [88,47]        [88,30]        [88,65]        [88,6]         [88,78]        [88,50]        [88,59]        [88,96]        [88,17]        [88,42]        [88,96]        [88,86]        [88,3]
# Machine 4: job_0_task_3   job_1_task_5   job_2_task_4   job_3_task_11  job_4_task_6   job_5_task_13  job_6_task_14  job_7_task_9   job_8_task_6   job_9_task_2   job_10_task_4  job_11_task_10 job_12_task_5  job_13_task_6  job_14_task_8
#            [88,62]        [88,76]        [88,38]        [88,10]        [88,19]        [88,52]        [88,64]        [88,25]        [88,97]        [88,35]        [88,47]        [88,79]        [88,36]        [88,75]        [88,53]
# Machine 5: job_0_task_11  job_1_task_7   job_2_task_7   job_3_task_6   job_4_task_2   job_5_task_7   job_6_task_12  job_7_task_0   job_8_task_14  job_9_task_14  job_10_task_6  job_11_task_11 job_12_task_8  job_13_task_9  job_14_task_6
#            [88,82]        [88,18]        [88,96]        [88,11]        [88,10]        [88,76]        [88,99]        [88,12]        [88,16]        [88,23]        [88,51]        [88,9]         [88,99]        [88,77]        [88,84]
# Machine 6: job_0_task_14  job_1_task_8   job_2_task_5   job_3_task_9   job_4_task_5   job_5_task_0   job_6_task_0   job_7_task_10  job_8_task_5   job_9_task_6   job_10_task_8  job_11_task_5  job_12_task_9  job_13_task_10 job_14_task_9
#            [88,88]        [88,22]        [88,78]        [88,55]        [88,72]        [88,83]        [88,29]        [88,18]        [88,31]        [88,84]        [88,82]        [88,56]        [88,14]        [88,8]         [88,58]
# Machine 7: job_0_task_9   job_1_task_4   job_2_task_13  job_3_task_2   job_4_task_4   job_5_task_8   job_6_task_10  job_7_task_11  job_8_task_10  job_9_task_8   job_10_task_7  job_11_task_6  job_12_task_6  job_13_task_11 job_14_task_11
#            [88,66]        [88,89]        [88,9]         [88,80]        [88,69]        [88,46]        [88,72]        [88,55]        [88,94]        [88,96]        [88,23]        [88,76]        [88,11]        [88,27]        [88,87]
# Machine 8: job_0_task_0   job_1_task_14  job_2_task_12  job_3_task_5   job_4_task_11  job_5_task_14  job_6_task_8   job_7_task_1   job_8_task_12  job_9_task_13  job_10_task_0  job_11_task_8  job_12_task_14 job_13_task_12 job_14_task_10
#            [88,69]        [88,22]        [88,90]        [88,31]        [88,11]        [88,72]        [88,16]        [88,74]        [88,61]        [88,74]        [88,36]        [88,80]        [88,17]        [88,96]        [88,95]
# Machine 9: job_0_task_2   job_1_task_9   job_2_task_6   job_3_task_12  job_4_task_1   job_5_task_12  job_6_task_4   job_7_task_5   job_8_task_8   job_9_task_10  job_10_task_10 job_11_task_1  job_12_task_0  job_13_task_14 job_14_task_7
#            [88,81]        [88,85]        [88,71]        [88,92]        [88,49]        [88,32]        [88,17]        [88,62]        [88,25]        [88,18]        [88,96]        [88,58]        [88,38]        [88,64]        [88,84]
# Machine 10: job_0_task_10  job_1_task_3   job_2_task_2   job_3_task_10  job_4_task_8   job_5_task_9   job_6_task_9   job_7_task_4   job_8_task_3   job_9_task_0   job_10_task_9  job_11_task_4  job_12_task_11 job_13_task_13 job_14_task_12
#            [88,88]        [88,15]        [88,93]        [88,12]        [88,37]        [88,30]        [88,49]        [88,15]        [88,47]        [88,27]        [88,35]        [88,1]         [88,64]        [88,69]        [88,90]
# Machine 11: job_0_task_13  job_1_task_12  job_2_task_9   job_3_task_1   job_4_task_9   job_5_task_4   job_6_task_7   job_7_task_2   job_8_task_4   job_9_task_3   job_10_task_12 job_11_task_7  job_12_task_2  job_13_task_5  job_14_task_5
#            [88,12]        [88,5]         [88,33]        [88,82]        [88,57]        [88,87]        [88,15]        [88,4]         [88,86]        [88,80]        [88,54]        [88,49]        [88,38]        [88,62]        [88,47]
# Machine 12: job_0_task_1   job_1_task_2   job_2_task_14  job_3_task_7   job_4_task_12  job_5_task_6   job_6_task_6   job_7_task_8   job_8_task_1   job_9_task_11  job_10_task_14 job_11_task_9  job_12_task_3  job_13_task_2  job_14_task_3
#            [88,81]        [88,47]        [88,21]        [88,26]        [88,73]        [88,36]        [88,14]        [88,49]        [88,13]        [88,23]        [88,38]        [88,26]        [88,38]        [88,93]        [88,71]
# Machine 13: job_0_task_4   job_1_task_0   job_2_task_10  job_3_task_14  job_4_task_14  job_5_task_3   job_6_task_11  job_7_task_13  job_8_task_7   job_9_task_4   job_10_task_3  job_11_task_3  job_12_task_1  job_13_task_8  job_14_task_13
#            [88,80]        [88,83]        [88,44]        [88,75]        [88,12]        [88,13]        [88,19]        [88,71]        [88,48]        [88,49]        [88,67]        [88,43]        [88,86]        [88,40]        [88,68]
# Machine 14: job_0_task_6   job_1_task_10  job_2_task_11  job_3_task_0   job_4_task_10  job_5_task_11  job_6_task_13  job_7_task_12  job_8_task_9   job_9_task_5   job_10_task_11 job_11_task_13 job_12_task_12 job_13_task_0  job_14_task_1
#            [88,38]        [88,26]        [88,71]        [88,33]        [88,32]        [88,62]        [88,38]        [88,5]         [88,40]        [88,46]        [88,7]         [88,24]        [88,58]        [88,10]        [88,12]
# Machine 15: job_0_task_8   job_1_task_11  job_2_task_8   job_3_task_4   job_4_task_3   job_5_task_1   job_6_task_5   job_7_task_7   job_8_task_0   job_9_task_9   job_10_task_5  job_11_task_2  job_12_task_4  job_13_task_4  job_14_task_14
#            [88,54]        [88,30]        [88,19]        [88,96]        [88,43]        [88,32]        [88,43]        [88,38]        [88,69]        [88,72]        [88,5]         [88,62]        [88,83]        [88,61]        [88,75]
#
# --- 0.19 seconds ---
# This is the list number: 3
# Solution:
# Optimal Schedule Length: 95.0
# Machine 1: job_0_task_10  job_1_task_2   job_2_task_4   job_3_task_11  job_4_task_12  job_5_task_5   job_6_task_3   job_7_task_10  job_8_task_5   job_9_task_10  job_10_task_6  job_11_task_0  job_12_task_1  job_13_task_9  job_14_task_2
#            [95,70]        [95,79]        [95,60]        [95,40]        [95,30]        [95,84]        [95,47]        [95,53]        [95,4]         [95,41]        [95,13]        [95,74]        [95,22]        [95,47]        [95,24]
# Machine 2: job_0_task_9   job_1_task_0   job_2_task_8   job_3_task_6   job_4_task_0   job_5_task_3   job_6_task_11  job_7_task_9   job_8_task_8   job_9_task_14  job_10_task_9  job_11_task_2  job_12_task_10 job_13_task_12 job_14_task_11
#            [95,85]        [95,19]        [95,8]         [95,94]        [95,45]        [95,93]        [95,7]         [95,53]        [95,24]        [95,37]        [95,94]        [95,43]        [95,63]        [95,92]        [95,95]
# Machine 3: job_0_task_13  job_1_task_9   job_2_task_14  job_3_task_5   job_4_task_8   job_5_task_1   job_6_task_12  job_7_task_6   job_8_task_9   job_9_task_0   job_10_task_7  job_11_task_4  job_12_task_4  job_13_task_3  job_14_task_1
#            [95,50]        [95,61]        [95,91]        [95,19]        [95,71]        [95,56]        [95,11]        [95,60]        [95,54]        [95,36]        [95,60]        [95,97]        [95,54]        [95,52]        [95,24]
# Machine 4: job_0_task_0   job_1_task_6   job_2_task_1   job_3_task_4   job_4_task_11  job_5_task_8   job_6_task_8   job_7_task_13  job_8_task_4   job_9_task_3   job_10_task_2  job_11_task_13 job_12_task_13 job_13_task_14 job_14_task_13
#            [95,72]        [95,43]        [95,7]         [95,19]        [95,28]        [95,15]        [95,72]        [95,83]        [95,68]        [95,64]        [95,89]        [95,11]        [95,12]        [95,11]        [95,60]
# Machine 5: job_0_task_7   job_1_task_12  job_2_task_5   job_3_task_7   job_4_task_13  job_5_task_12  job_6_task_10  job_7_task_1   job_8_task_1   job_9_task_9   job_10_task_5  job_11_task_1  job_12_task_2  job_13_task_5  job_14_task_3
#            [95,33]        [95,19]        [95,82]        [95,41]        [95,17]        [95,77]        [95,38]        [95,21]        [95,28]        [95,13]        [95,23]        [95,61]        [95,9]         [95,4]         [95,14]
# Machine 6: job_0_task_6   job_1_task_3   job_2_task_11  job_3_task_2   job_4_task_3   job_5_task_13  job_6_task_14  job_7_task_3   job_8_task_14  job_9_task_5   job_10_task_8  job_11_task_14 job_12_task_12 job_13_task_0  job_14_task_5
#            [95,88]        [95,47]        [95,44]        [95,84]        [95,29]        [95,55]        [95,63]        [95,42]        [95,95]        [95,41]        [95,46]        [95,70]        [95,42]        [95,67]        [95,57]
# Machine 7: job_0_task_2   job_1_task_11  job_2_task_10  job_3_task_0   job_4_task_2   job_5_task_6   job_6_task_13  job_7_task_8   job_8_task_10  job_9_task_4   job_10_task_4  job_11_task_9  job_12_task_0  job_13_task_7  job_14_task_8
#            [95,42]        [95,56]        [95,7]         [95,58]        [95,8]         [95,40]        [95,22]        [95,25]        [95,57]        [95,30]        [95,28]        [95,78]        [95,9]         [95,56]        [95,4]
# Machine 8: job_0_task_1   job_1_task_13  job_2_task_0   job_3_task_13  job_4_task_5   job_5_task_10  job_6_task_1   job_7_task_0   job_8_task_0   job_9_task_12  job_10_task_3  job_11_task_8  job_12_task_14 job_13_task_4  job_14_task_12
#            [95,51]        [95,91]        [95,94]        [95,88]        [95,42]        [95,54]        [95,91]        [95,12]        [95,48]        [95,32]        [95,37]        [95,62]        [95,41]        [95,87]        [95,22]
# Machine 9: job_0_task_5   job_1_task_4   job_2_task_2   job_3_task_10  job_4_task_4   job_5_task_14  job_6_task_5   job_7_task_14  job_8_task_7   job_9_task_13  job_10_task_11 job_11_task_10 job_12_task_11 job_13_task_6  job_14_task_10
#            [95,46]        [95,40]        [95,2]         [95,25]        [95,32]        [95,31]        [95,68]        [95,32]        [95,92]        [95,94]        [95,72]        [95,42]        [95,98]        [95,1]         [95,69]
# Machine 10: job_0_task_4   job_1_task_8   job_2_task_6   job_3_task_8   job_4_task_7   job_5_task_7   job_6_task_6   job_7_task_12  job_8_task_13  job_9_task_7   job_10_task_1  job_11_task_3  job_12_task_6  job_13_task_8  job_14_task_6
#            [95,61]        [95,84]        [95,76]        [95,98]        [95,4]         [95,4]         [95,62]        [95,29]        [95,85]        [95,74]        [95,9]         [95,26]        [95,92]        [95,82]        [95,30]
# Machine 11: job_0_task_8   job_1_task_7   job_2_task_9   job_3_task_14  job_4_task_14  job_5_task_11  job_6_task_7   job_7_task_11  job_8_task_3   job_9_task_2   job_10_task_10 job_11_task_7  job_12_task_3  job_13_task_1  job_14_task_7
#            [95,27]        [95,65]        [95,85]        [95,74]        [95,43]        [95,39]        [95,22]        [95,56]        [95,26]        [95,65]        [95,85]        [95,60]        [95,8]         [95,7]         [95,64]
# Machine 12: job_0_task_12  job_1_task_1   job_2_task_3   job_3_task_1   job_4_task_1   job_5_task_0   job_6_task_2   job_7_task_5   job_8_task_12  job_9_task_11  job_10_task_0  job_11_task_5  job_12_task_8  job_13_task_11 job_14_task_0
#            [95,70]        [95,79]        [95,95]        [95,67]        [95,60]        [95,84]        [95,17]        [95,84]        [95,84]        [95,6]         [95,62]        [95,62]        [95,2]         [95,8]         [95,44]
# Machine 13: job_0_task_11  job_1_task_10  job_2_task_13  job_3_task_9   job_4_task_6   job_5_task_2   job_6_task_4   job_7_task_7   job_8_task_11  job_9_task_1   job_10_task_13 job_11_task_11 job_12_task_9  job_13_task_10 job_14_task_9
#            [95,56]        [95,30]        [95,72]        [95,96]        [95,25]        [95,46]        [95,77]        [95,52]        [95,47]        [95,34]        [95,79]        [95,8]         [95,63]        [95,35]        [95,14]
# Machine 14: job_0_task_14  job_1_task_5   job_2_task_7   job_3_task_3   job_4_task_10  job_5_task_9   job_6_task_9   job_7_task_2   job_8_task_6   job_9_task_8   job_10_task_12 job_11_task_6  job_12_task_7  job_13_task_2  job_14_task_14
#            [95,25]        [95,67]        [95,36]        [95,34]        [95,93]        [95,15]        [95,47]        [95,60]        [95,19]        [95,44]        [95,18]        [95,40]        [95,76]        [95,91]        [95,61]
# Machine 15: job_0_task_3   job_1_task_14  job_2_task_12  job_3_task_12  job_4_task_9   job_5_task_4   job_6_task_0   job_7_task_4   job_8_task_2   job_9_task_6   job_10_task_14 job_11_task_12 job_12_task_5  job_13_task_13 job_14_task_4
#            [95,31]        [95,68]        [95,2]         [95,74]        [95,79]        [95,66]        [95,65]        [95,22]        [95,70]        [95,53]        [95,11]        [95,21]        [95,32]        [95,39]        [95,34]
#
# --- 0.16 seconds ---
# This is the list number: 4
# Solution:
# Optimal Schedule Length: 97.0
# Machine 1: job_0_task_5   job_1_task_11  job_2_task_10  job_3_task_3   job_4_task_7   job_5_task_3   job_6_task_4   job_7_task_6   job_8_task_8   job_9_task_6   job_10_task_14 job_11_task_9  job_12_task_6  job_13_task_8  job_14_task_2
#            [97,75]        [97,38]        [97,97]        [97,8]         [97,21]        [97,72]        [97,80]        [97,38]        [97,9]         [97,60]        [97,48]        [97,50]        [97,85]        [97,75]        [97,54]
# Machine 2: job_0_task_1   job_1_task_1   job_2_task_11  job_3_task_8   job_4_task_3   job_5_task_13  job_6_task_6   job_7_task_13  job_8_task_0   job_9_task_14  job_10_task_12 job_11_task_12 job_12_task_4  job_13_task_1  job_14_task_10
#            [97,96]        [97,88]        [97,16]        [97,78]        [97,68]        [97,98]        [97,47]        [97,46]        [97,37]        [97,51]        [97,43]        [97,77]        [97,22]        [97,95]        [97,40]
# Machine 3: job_0_task_13  job_1_task_9   job_2_task_9   job_3_task_6   job_4_task_8   job_5_task_9   job_6_task_5   job_7_task_8   job_8_task_1   job_9_task_13  job_10_task_4  job_11_task_4  job_12_task_11 job_13_task_11 job_14_task_4
#            [97,99]        [97,37]        [97,1]         [97,76]        [97,85]        [97,2]         [97,71]        [97,16]        [97,9]         [97,49]        [97,24]        [97,86]        [97,60]        [97,3]         [97,70]
# Machine 4: job_0_task_8   job_1_task_12  job_2_task_1   job_3_task_11  job_4_task_9   job_5_task_8   job_6_task_11  job_7_task_0   job_8_task_9   job_9_task_4   job_10_task_1  job_11_task_11 job_12_task_13 job_13_task_7  job_14_task_5
#            [97,65]        [97,68]        [97,46]        [97,70]        [97,79]        [97,83]        [97,10]        [97,29]        [97,41]        [97,10]        [97,49]        [97,73]        [97,32]        [97,96]        [97,29]
# Machine 5: job_0_task_2   job_1_task_13  job_2_task_5   job_3_task_14  job_4_task_12  job_5_task_0   job_6_task_14  job_7_task_5   job_8_task_12  job_9_task_5   job_10_task_0  job_11_task_5  job_12_task_10 job_13_task_2  job_14_task_11
#            [97,59]        [97,94]        [97,79]        [97,97]        [97,21]        [97,14]        [97,33]        [97,38]        [97,8]         [97,37]        [97,22]        [97,19]        [97,68]        [97,52]        [97,48]
# Machine 6: job_0_task_9   job_1_task_0   job_2_task_6   job_3_task_2   job_4_task_5   job_5_task_10  job_6_task_10  job_7_task_2   job_8_task_11  job_9_task_12  job_10_task_6  job_11_task_3  job_12_task_7  job_13_task_9  job_14_task_1
#            [97,16]        [97,2]         [97,62]        [97,42]        [97,37]        [97,86]        [97,53]        [97,89]        [97,83]        [97,75]        [97,73]        [97,23]        [97,92]        [97,12]        [97,18]
# Machine 7: job_0_task_10  job_1_task_6   job_2_task_0   job_3_task_13  job_4_task_0   job_5_task_2   job_6_task_2   job_7_task_3   job_8_task_2   job_9_task_2   job_10_task_7  job_11_task_0  job_12_task_5  job_13_task_4  job_14_task_7
#            [97,71]        [97,38]        [97,87]        [97,16]        [97,68]        [97,29]        [97,99]        [97,10]        [97,49]        [97,47]        [97,68]        [97,81]        [97,23]        [97,33]        [97,50]
# Machine 8: job_0_task_14  job_1_task_10  job_2_task_3   job_3_task_1   job_4_task_4   job_5_task_1   job_6_task_9   job_7_task_9   job_8_task_3   job_9_task_1   job_10_task_10 job_11_task_2  job_12_task_3  job_13_task_6  job_14_task_0
#            [97,24]        [97,93]        [97,87]        [97,15]        [97,91]        [97,1]         [97,78]        [97,65]        [97,23]        [97,73]        [97,69]        [97,21]        [97,32]        [97,73]        [97,94]
# Machine 9: job_0_task_7   job_1_task_8   job_2_task_8   job_3_task_7   job_4_task_10  job_5_task_4   job_6_task_7   job_7_task_4   job_8_task_7   job_9_task_9   job_10_task_2  job_11_task_8  job_12_task_2  job_13_task_3  job_14_task_9
#            [97,65]        [97,57]        [97,54]        [97,25]        [97,51]        [97,6]         [97,96]        [97,30]        [97,15]        [97,11]        [97,33]        [97,22]        [97,30]        [97,59]        [97,70]
# Machine 10: job_0_task_3   job_1_task_5   job_2_task_7   job_3_task_4   job_4_task_13  job_5_task_11  job_6_task_3   job_7_task_10  job_8_task_13  job_9_task_11  job_10_task_13 job_11_task_13 job_12_task_8  job_13_task_12 job_14_task_6
#            [97,95]        [97,13]        [97,37]        [97,72]        [97,30]        [97,33]        [97,70]        [97,90]        [97,61]        [97,79]        [97,39]        [97,16]        [97,14]        [97,90]        [97,43]
# Machine 11: job_0_task_12  job_1_task_3   job_2_task_2   job_3_task_0   job_4_task_14  job_5_task_12  job_6_task_0   job_7_task_1   job_8_task_4   job_9_task_8   job_10_task_8  job_11_task_10 job_12_task_9  job_13_task_5  job_14_task_3
#            [97,84]        [97,52]        [97,14]        [97,19]        [97,64]        [97,33]        [97,21]        [97,85]        [97,1]         [97,26]        [97,21]        [97,11]        [97,13]        [97,12]        [97,42]
# Machine 12: job_0_task_6   job_1_task_14  job_2_task_12  job_3_task_10  job_4_task_6   job_5_task_14  job_6_task_1   job_7_task_11  job_8_task_14  job_9_task_10  job_10_task_11 job_11_task_7  job_12_task_14 job_13_task_14 job_14_task_8
#            [97,23]        [97,71]        [97,2]         [97,62]        [97,73]        [97,59]        [97,80]        [97,73]        [97,60]        [97,37]        [97,94]        [97,52]        [97,90]        [97,6]         [97,75]
# Machine 13: job_0_task_0   job_1_task_7   job_2_task_14  job_3_task_12  job_4_task_1   job_5_task_6   job_6_task_8   job_7_task_12  job_8_task_5   job_9_task_0   job_10_task_9  job_11_task_1  job_12_task_0  job_13_task_0  job_14_task_13
#            [97,40]        [97,35]        [97,96]        [97,81]        [97,71]        [97,98]        [97,56]        [97,88]        [97,78]        [97,1]         [97,61]        [97,46]        [97,21]        [97,29]        [97,27]
# Machine 14: job_0_task_4   job_1_task_4   job_2_task_4   job_3_task_5   job_4_task_11  job_5_task_5   job_6_task_12  job_7_task_14  job_8_task_10  job_9_task_7   job_10_task_5  job_11_task_6  job_12_task_1  job_13_task_10 job_14_task_14
#            [97,76]        [97,68]        [97,30]        [97,15]        [97,50]        [97,31]        [97,92]        [97,47]        [97,35]        [97,84]        [97,3]         [97,64]        [97,80]        [97,83]        [97,12]
# Machine 15: job_0_task_11  job_1_task_2   job_2_task_13  job_3_task_9   job_4_task_2   job_5_task_7   job_6_task_13  job_7_task_7   job_8_task_6   job_9_task_3   job_10_task_3  job_11_task_14 job_12_task_12 job_13_task_13 job_14_task_12
#            [97,52]        [97,99]        [97,51]        [97,84]        [97,3]         [97,50]        [97,1]         [97,48]        [97,39]        [97,46]        [97,2]         [97,75]        [97,45]        [97,57]        [97,1]
#
# --- 0.12 seconds ---
# This is the list number: 5
# Solution:
# Optimal Schedule Length: 99.0
# Machine 1: job_0_task_8   job_1_task_1   job_2_task_8   job_3_task_1   job_4_task_10  job_5_task_8   job_6_task_6   job_7_task_8   job_8_task_6   job_9_task_14  job_10_task_11 job_11_task_0  job_12_task_2  job_13_task_7  job_14_task_9
#            [99,18]        [99,81]        [99,24]        [99,87]        [99,27]        [99,92]        [99,82]        [99,5]         [99,55]        [99,70]        [99,88]        [99,28]        [99,40]        [99,61]        [99,63]
# Machine 2: job_0_task_9   job_1_task_5   job_2_task_3   job_3_task_5   job_4_task_14  job_5_task_9   job_6_task_1   job_7_task_10  job_8_task_1   job_9_task_13  job_10_task_0  job_11_task_12 job_12_task_8  job_13_task_10 job_14_task_6
#            [99,57]        [99,45]        [99,79]        [99,16]        [99,81]        [99,27]        [99,33]        [99,83]        [99,55]        [99,7]         [99,4]         [99,80]        [99,15]        [99,24]        [99,48]
# Machine 3: job_0_task_11  job_1_task_7   job_2_task_9   job_3_task_9   job_4_task_1   job_5_task_11  job_6_task_2   job_7_task_14  job_8_task_11  job_9_task_6   job_10_task_3  job_11_task_13 job_12_task_12 job_13_task_5  job_14_task_1
#            [99,5]         [99,73]        [99,26]        [99,3]         [99,96]        [99,7]         [99,78]        [99,44]        [99,84]        [99,64]        [99,10]        [99,38]        [99,16]        [99,76]        [99,30]
# Machine 4: job_0_task_4   job_1_task_8   job_2_task_12  job_3_task_10  job_4_task_7   job_5_task_13  job_6_task_13  job_7_task_3   job_8_task_9   job_9_task_0   job_10_task_12 job_11_task_5  job_12_task_9  job_13_task_11 job_14_task_4
#            [99,28]        [99,23]        [99,29]        [99,2]         [99,10]        [99,66]        [99,2]         [99,83]        [99,73]        [99,27]        [99,52]        [99,60]        [99,41]        [99,23]        [99,45]
# Machine 5: job_0_task_10  job_1_task_6   job_2_task_7   job_3_task_14  job_4_task_6   job_5_task_14  job_6_task_0   job_7_task_0   job_8_task_3   job_9_task_3   job_10_task_1  job_11_task_11 job_12_task_6  job_13_task_1  job_14_task_3
#            [99,43]        [99,60]        [99,93]        [99,28]        [99,98]        [99,13]        [99,90]        [99,79]        [99,74]        [99,90]        [99,53]        [99,34]        [99,39]        [99,21]        [99,58]
# Machine 6: job_0_task_2   job_1_task_2   job_2_task_5   job_3_task_12  job_4_task_9   job_5_task_12  job_6_task_12  job_7_task_9   job_8_task_2   job_9_task_4   job_10_task_9  job_11_task_8  job_12_task_11 job_13_task_4  job_14_task_7
#            [99,71]        [99,95]        [99,66]        [99,4]         [99,65]        [99,95]        [99,4]         [99,44]        [99,20]        [99,6]         [99,44]        [99,66]        [99,64]        [99,79]        [99,28]
# Machine 7: job_0_task_12  job_1_task_4   job_2_task_0   job_3_task_6   job_4_task_12  job_5_task_2   job_6_task_5   job_7_task_4   job_8_task_14  job_9_task_1   job_10_task_8  job_11_task_6  job_12_task_10 job_13_task_3  job_14_task_2
#            [99,12]        [99,55]        [99,63]        [99,68]        [99,75]        [99,92]        [99,67]        [99,45]        [99,6]         [99,59]        [99,35]        [99,44]        [99,93]        [99,55]        [99,67]
# Machine 8: job_0_task_0   job_1_task_14  job_2_task_2   job_3_task_3   job_4_task_11  job_5_task_7   job_6_task_4   job_7_task_13  job_8_task_0   job_9_task_11  job_10_task_2  job_11_task_1  job_12_task_14 job_13_task_13 job_14_task_8
#            [99,96]        [99,73]        [99,63]        [99,23]        [99,57]        [99,88]        [99,93]        [99,78]        [99,19]        [99,30]        [99,6]         [99,11]        [99,97]        [99,91]        [99,64]
# Machine 9: job_0_task_3   job_1_task_0   job_2_task_1   job_3_task_7   job_4_task_0   job_5_task_1   job_6_task_7   job_7_task_12  job_8_task_5   job_9_task_7   job_10_task_13 job_11_task_4  job_12_task_3  job_13_task_2  job_14_task_10
#            [99,26]        [99,32]        [99,93]        [99,32]        [99,46]        [99,91]        [99,94]        [99,60]        [99,37]        [99,35]        [99,16]        [99,35]        [99,25]        [99,8]         [99,80]
# Machine 10: job_0_task_7   job_1_task_12  job_2_task_4   job_3_task_11  job_4_task_5   job_5_task_5   job_6_task_11  job_7_task_7   job_8_task_7   job_9_task_10  job_10_task_10 job_11_task_7  job_12_task_13 job_13_task_6  job_14_task_12
#            [99,71]        [99,5]         [99,10]        [99,71]        [99,2]         [99,36]        [99,42]        [99,42]        [99,63]        [99,77]        [99,99]        [99,39]        [99,81]        [99,79]        [99,93]
# Machine 11: job_0_task_14  job_1_task_10  job_2_task_14  job_3_task_13  job_4_task_4   job_5_task_10  job_6_task_10  job_7_task_1   job_8_task_10  job_9_task_5   job_10_task_5  job_11_task_10 job_12_task_1  job_13_task_14 job_14_task_11
#            [99,63]        [99,92]        [99,97]        [99,67]        [99,93]        [99,13]        [99,85]        [99,24]        [99,55]        [99,37]        [99,89]        [99,40]        [99,32]        [99,22]        [99,23]
# Machine 12: job_0_task_13  job_1_task_9   job_2_task_11  job_3_task_8   job_4_task_3   job_5_task_3   job_6_task_14  job_7_task_6   job_8_task_13  job_9_task_9   job_10_task_14 job_11_task_14 job_12_task_7  job_13_task_8  job_14_task_5
#            [99,91]        [99,44]        [99,69]        [99,74]        [99,41]        [99,87]        [99,70]        [99,3]         [99,62]        [99,59]        [99,99]        [99,29]        [99,61]        [99,68]        [99,29]
# Machine 13: job_0_task_1   job_1_task_11  job_2_task_6   job_3_task_0   job_4_task_2   job_5_task_6   job_6_task_8   job_7_task_11  job_8_task_8   job_9_task_8   job_10_task_6  job_11_task_9  job_12_task_4  job_13_task_9  job_14_task_13
#            [99,23]        [99,20]        [99,27]        [99,80]        [99,11]        [99,67]        [99,12]        [99,59]        [99,40]        [99,25]        [99,38]        [99,49]        [99,40]        [99,99]        [99,55]
# Machine 14: job_0_task_6   job_1_task_3   job_2_task_13  job_3_task_4   job_4_task_13  job_5_task_0   job_6_task_3   job_7_task_5   job_8_task_12  job_9_task_2   job_10_task_7  job_11_task_3  job_12_task_5  job_13_task_0  job_14_task_14
#            [99,27]        [99,79]        [99,66]        [99,54]        [99,87]        [99,5]         [99,76]        [99,29]        [99,54]        [99,6]         [99,38]        [99,51]        [99,85]        [99,9]         [99,48]
# Machine 15: job_0_task_5   job_1_task_13  job_2_task_10  job_3_task_2   job_4_task_8   job_5_task_4   job_6_task_9   job_7_task_2   job_8_task_4   job_9_task_12  job_10_task_4  job_11_task_2  job_12_task_0  job_13_task_12 job_14_task_0
#            [99,16]        [99,72]        [99,8]         [99,68]        [99,43]        [99,66]        [99,5]         [99,41]        [99,66]        [99,1]         [99,51]        [99,76]        [99,31]        [99,92]        [99,80]
#
# --- 0.17 seconds ---
# This is the list number: 6
# Solution:
# Optimal Schedule Length: 95.0
# Machine 1: job_0_task_3   job_1_task_5   job_2_task_0   job_3_task_2   job_4_task_9   job_5_task_8   job_6_task_1   job_7_task_14  job_8_task_7   job_9_task_10  job_10_task_3  job_11_task_13 job_12_task_4  job_13_task_14 job_14_task_14
#            [95,20]        [95,88]        [95,62]        [95,93]        [95,81]        [95,9]         [95,93]        [95,61]        [95,63]        [95,83]        [95,88]        [95,42]        [95,22]        [95,6]         [95,93]
# Machine 2: job_0_task_8   job_1_task_1   job_2_task_2   job_3_task_7   job_4_task_14  job_5_task_5   job_6_task_7   job_7_task_1   job_8_task_4   job_9_task_4   job_10_task_2  job_11_task_12 job_12_task_1  job_13_task_4  job_14_task_13
#            [95,27]        [95,85]        [95,74]        [95,48]        [95,35]        [95,39]        [95,52]        [95,82]        [95,87]        [95,62]        [95,13]        [95,59]        [95,80]        [95,46]        [95,45]
# Machine 3: job_0_task_9   job_1_task_0   job_2_task_9   job_3_task_13  job_4_task_7   job_5_task_14  job_6_task_12  job_7_task_6   job_8_task_12  job_9_task_9   job_10_task_1  job_11_task_4  job_12_task_9  job_13_task_10 job_14_task_7
#            [95,18]        [95,44]        [95,83]        [95,96]        [95,52]        [95,59]        [95,96]        [95,66]        [95,91]        [95,25]        [95,99]        [95,1]         [95,38]        [95,8]         [95,23]
# Machine 4: job_0_task_10  job_1_task_12  job_2_task_1   job_3_task_12  job_4_task_8   job_5_task_9   job_6_task_8   job_7_task_12  job_8_task_14  job_9_task_1   job_10_task_10 job_11_task_1  job_12_task_10 job_13_task_2  job_14_task_10
#            [95,51]        [95,55]        [95,72]        [95,45]        [95,29]        [95,93]        [95,47]        [95,34]        [95,59]        [95,25]        [95,17]        [95,22]        [95,26]        [95,29]        [95,35]
# Machine 5: job_0_task_12  job_1_task_13  job_2_task_4   job_3_task_10  job_4_task_13  job_5_task_12  job_6_task_3   job_7_task_8   job_8_task_3   job_9_task_3   job_10_task_0  job_11_task_7  job_12_task_3  job_13_task_7  job_14_task_11
#            [95,10]        [95,34]        [95,95]        [95,21]        [95,54]        [95,20]        [95,51]        [95,56]        [95,16]        [95,65]        [95,20]        [95,84]        [95,56]        [95,75]        [95,17]
# Machine 6: job_0_task_4   job_1_task_6   job_2_task_7   job_3_task_11  job_4_task_2   job_5_task_4   job_6_task_2   job_7_task_11  job_8_task_1   job_9_task_2   job_10_task_14 job_11_task_6  job_12_task_14 job_13_task_11 job_14_task_0
#            [95,1]         [95,61]        [95,34]        [95,17]        [95,70]        [95,77]        [95,4]         [95,16]        [95,31]        [95,69]        [95,95]        [95,3]         [95,94]        [95,92]        [95,89]
# Machine 7: job_0_task_13  job_1_task_14  job_2_task_8   job_3_task_6   job_4_task_10  job_5_task_6   job_6_task_6   job_7_task_4   job_8_task_0   job_9_task_12  job_10_task_7  job_11_task_14 job_12_task_7  job_13_task_6  job_14_task_3
#            [95,51]        [95,84]        [95,89]        [95,1]         [95,60]        [95,41]        [95,18]        [95,67]        [95,82]        [95,55]        [95,84]        [95,63]        [95,27]        [95,43]        [95,32]
# Machine 8: job_0_task_2   job_1_task_11  job_2_task_3   job_3_task_3   job_4_task_12  job_5_task_7   job_6_task_14  job_7_task_7   job_8_task_8   job_9_task_6   job_10_task_12 job_11_task_11 job_12_task_0  job_13_task_3  job_14_task_6
#            [95,6]         [95,34]        [95,63]        [95,79]        [95,80]        [95,10]        [95,90]        [95,92]        [95,29]        [95,97]        [95,63]        [95,73]        [95,72]        [95,90]        [95,16]
# Machine 9: job_0_task_14  job_1_task_2   job_2_task_5   job_3_task_14  job_4_task_0   job_5_task_10  job_6_task_9   job_7_task_13  job_8_task_9   job_9_task_0   job_10_task_11 job_11_task_0  job_12_task_5  job_13_task_0  job_14_task_9
#            [95,41]        [95,2]         [95,29]        [95,11]        [95,83]        [95,7]         [95,21]        [95,99]        [95,99]        [95,28]        [95,54]        [95,59]        [95,8]         [95,72]        [95,46]
# Machine 10: job_0_task_6   job_1_task_8   job_2_task_12  job_3_task_0   job_4_task_4   job_5_task_3   job_6_task_0   job_7_task_2   job_8_task_6   job_9_task_7   job_10_task_6  job_11_task_8  job_12_task_11 job_13_task_13 job_14_task_4
# ...
# Machine 16: job_0_task_15  job_1_task_11  job_2_task_6   job_3_task_15  job_4_task_3   job_5_task_11  job_6_task_12  job_7_task_10  job_8_task_6   job_9_task_5   job_10_task_4  job_11_task_9  job_12_task_14 job_13_task_9  job_14_task_19 job_15_task_19 job_16_task_19 job_17_task_2  job_18_task_2  job_19_task_6  job_20_task_3  job_21_task_8  job_22_task_11 job_23_task_6  job_24_task_18 job_25_task_1  job_26_task_1  job_27_task_6  job_28_task_19 job_29_task_9  job_30_task_6  job_31_task_6  job_32_task_11 job_33_task_18 job_34_task_18 job_35_task_3  job_36_task_19 job_37_task_18 job_38_task_3  job_39_task_18 job_40_task_8  job_41_task_7  job_42_task_7  job_43_task_14 job_44_task_13 job_45_task_10 job_46_task_6  job_47_task_14 job_48_task_3  job_49_task_5  job_50_task_15 job_51_task_2  job_52_task_17 job_53_task_8  job_54_task_7  job_55_task_7  job_56_task_12 job_57_task_19 job_58_task_14 job_59_task_19 job_60_task_2  job_61_task_9  job_62_task_0  job_63_task_17 job_64_task_11 job_65_task_13 job_66_task_19 job_67_task_18 job_68_task_15 job_69_task_11 job_70_task_13 job_71_task_2  job_72_task_11 job_73_task_14 job_74_task_11 job_75_task_19 job_76_task_15 job_77_task_1  job_78_task_9  job_79_task_1  job_80_task_15 job_81_task_16 job_82_task_18 job_83_task_16 job_84_task_8  job_85_task_9  job_86_task_4  job_87_task_9  job_88_task_12 job_89_task_17 job_90_task_6  job_91_task_5  job_92_task_0  job_93_task_14 job_94_task_13 job_95_task_10 job_96_task_9  job_97_task_15 job_98_task_19 job_99_task_4
#            [97,56]        [97,86]        [97,87]        [97,27]        [97,40]        [97,90]        [97,15]        [97,10]        [97,67]        [97,99]        [97,71]        [97,33]        [97,74]        [97,29]        [97,44]        [97,97]        [97,80]        [97,27]        [97,2]         [97,29]        [97,97]        [97,6]         [97,71]        [97,23]        [97,9]         [97,82]        [97,2]         [97,13]        [97,4]         [97,52]        [97,36]        [97,74]        [97,7]         [97,45]        [97,59]        [97,14]        [97,14]        [97,92]        [97,3]         [97,37]        [97,8]         [97,86]        [97,30]        [97,15]        [97,28]        [97,80]        [97,1]         [97,32]        [97,84]        [97,52]        [97,36]        [97,60]        [97,35]        [97,70]        [97,75]        [97,48]        [97,78]        [97,37]        [97,15]        [97,66]        [97,57]        [97,73]        [97,34]        [97,7]         [97,30]        [97,56]        [97,31]        [97,28]        [97,40]        [97,79]        [97,87]        [97,88]        [97,56]        [97,23]        [97,35]        [97,9]         [97,57]        [97,32]        [97,55]        [97,27]        [97,83]        [97,22]        [97,71]        [97,67]        [97,14]        [97,6]         [97,48]        [97,81]        [97,34]        [97,73]        [97,37]        [97,70]        [97,83]        [97,1]         [97,18]        [97,1]         [97,96]        [97,71]        [97,28]        [97,9]
# Machine 17: job_0_task_4   job_1_task_8   job_2_task_8   job_3_task_6   job_4_task_1   job_5_task_0   job_6_task_6   job_7_task_11  job_8_task_8   job_9_task_8   job_10_task_16 job_11_task_13 job_12_task_18 job_13_task_15 job_14_task_5  job_15_task_6  job_16_task_14 job_17_task_8  job_18_task_0  job_19_task_5  job_20_task_12 job_21_task_13 job_22_task_14 job_23_task_19 job_24_task_1  job_25_task_15 job_26_task_10 job_27_task_16 job_28_task_1  job_29_task_19 job_30_task_11 job_31_task_4  job_32_task_6  job_33_task_4  job_34_task_0  job_35_task_4  job_36_task_9  job_37_task_15 job_38_task_8  job_39_task_6  job_40_task_13 job_41_task_5  job_42_task_4  job_43_task_2  job_44_task_9  job_45_task_18 job_46_task_12 job_47_task_18 job_48_task_13 job_49_task_18 job_50_task_19 job_51_task_11 job_52_task_12 job_53_task_18 job_54_task_5  job_55_task_10 job_56_task_3  job_57_task_16 job_58_task_7  job_59_task_5  job_60_task_19 job_61_task_19 job_62_task_19 job_63_task_1  job_64_task_18 job_65_task_8  job_66_task_0  job_67_task_13 job_68_task_1  job_69_task_16 job_70_task_7  job_71_task_14 job_72_task_1  job_73_task_11 job_74_task_0  job_75_task_12 job_76_task_12 job_77_task_6  job_78_task_12 job_79_task_3  job_80_task_5  job_81_task_5  job_82_task_9  job_83_task_7  job_84_task_18 job_85_task_0  job_86_task_7  job_87_task_0  job_88_task_2  job_89_task_19 job_90_task_12 job_91_task_2  job_92_task_15 job_93_task_9  job_94_task_5  job_95_task_12 job_96_task_18 job_97_task_17 job_98_task_3  job_99_task_6
#            [97,5]         [97,96]        [97,7]         [97,49]        [97,51]        [97,51]        [97,95]        [97,35]        [97,64]        [97,26]        [97,26]        [97,77]        [97,25]        [97,78]        [97,94]        [97,56]        [97,44]        [97,47]        [97,71]        [97,57]        [97,42]        [97,63]        [97,16]        [97,15]        [97,50]        [97,67]        [97,13]        [97,53]        [97,84]        [97,63]        [97,69]        [97,25]        [97,29]        [97,37]        [97,44]        [97,65]        [97,41]        [97,31]        [97,40]        [97,71]        [97,86]        [97,97]        [97,41]        [97,86]        [97,24]        [97,95]        [97,3]         [97,48]        [97,75]        [97,21]        [97,85]        [97,53]        [97,69]        [97,96]        [97,14]        [97,83]        [97,65]        [97,32]        [97,59]        [97,40]        [97,92]        [97,33]        [97,17]        [97,61]        [97,6]         [97,98]        [97,8]         [97,58]        [97,90]        [97,44]        [97,94]        [97,12]        [97,80]        [97,60]        [97,32]        [97,88]        [97,16]        [97,37]        [97,46]        [97,53]        [97,39]        [97,44]        [97,99]        [97,48]        [97,2]         [97,54]        [97,43]        [97,21]        [97,92]        [97,57]        [97,4]         [97,88]        [97,89]        [97,8]         [97,85]        [97,44]        [97,27]        [97,12]        [97,78]        [97,44]
# Machine 18: job_0_task_8   job_1_task_0   job_2_task_0   job_3_task_9   job_4_task_10  job_5_task_8   job_6_task_7   job_7_task_4   job_8_task_1   job_9_task_1   job_10_task_19 job_11_task_17 job_12_task_11 job_13_task_18 job_14_task_14 job_15_task_3  job_16_task_3  job_17_task_4  job_18_task_14 job_19_task_8  job_20_task_6  job_21_task_1  job_22_task_2  job_23_task_12 job_24_task_2  job_25_task_0  job_26_task_7  job_27_task_1  job_28_task_11 job_29_task_5  job_30_task_5  job_31_task_7  job_32_task_1  job_33_task_3  job_34_task_12 job_35_task_8  job_36_task_3  job_37_task_4  job_38_task_18 job_39_task_5  job_40_task_5  job_41_task_18 job_42_task_9  job_43_task_6  job_44_task_19 job_45_task_12 job_46_task_2  job_47_task_12 job_48_task_10 job_49_task_1  job_50_task_12 job_51_task_13 job_52_task_13 job_53_task_9  job_54_task_6  job_55_task_4  job_56_task_4  job_57_task_4  job_58_task_17 job_59_task_18 job_60_task_1  job_61_task_2  job_62_task_13 job_63_task_13 job_64_task_0  job_65_task_19 job_66_task_1  job_67_task_9  job_68_task_3  job_69_task_1  job_70_task_9  job_71_task_1  job_72_task_3  job_73_task_9  job_74_task_9  job_75_task_6  job_76_task_1  job_77_task_7  job_78_task_3  job_79_task_18 job_80_task_3  job_81_task_17 job_82_task_0  job_83_task_11 job_84_task_1  job_85_task_8  job_86_task_9  job_87_task_6  job_88_task_13 job_89_task_15 job_90_task_15 job_91_task_16 job_92_task_10 job_93_task_8  job_94_task_11 job_95_task_11 job_96_task_15 job_97_task_10 job_98_task_13 job_99_task_11
#            [97,65]        [97,68]        [97,68]        [97,92]        [97,71]        [97,47]        [97,17]        [97,22]        [97,23]        [97,65]        [97,21]        [97,81]        [97,99]        [97,50]        [97,1]         [97,82]        [97,28]        [97,34]        [97,24]        [97,79]        [97,49]        [97,64]        [97,76]        [97,64]        [97,47]        [97,68]        [97,99]        [97,1]         [97,99]        [97,89]        [97,51]        [97,48]        [97,81]        [97,52]        [97,58]        [97,50]        [97,54]        [97,99]        [97,47]        [97,26]        [97,50]        [97,86]        [97,9]         [97,99]        [97,38]        [97,55]        [97,24]        [97,45]        [97,10]        [97,78]        [97,20]        [97,59]        [97,1]         [97,25]        [97,25]        [97,60]        [97,11]        [97,90]        [97,1]         [97,4]         [97,73]        [97,86]        [97,60]        [97,58]        [97,3]         [97,15]        [97,2]         [97,54]        [97,26]        [97,75]        [97,35]        [97,74]        [97,43]        [97,92]        [97,29]        [97,50]        [97,33]        [97,35]        [97,70]        [97,48]        [97,79]        [97,13]        [97,11]        [97,28]        [97,89]        [97,45]        [97,31]        [97,37]        [97,18]        [97,45]        [97,2]         [97,9]         [97,19]        [97,90]        [97,90]        [97,79]        [97,79]        [97,50]        [97,81]        [97,58]
# Machine 19: job_0_task_7   job_1_task_9   job_2_task_11  job_3_task_10  job_4_task_14  job_5_task_6   job_6_task_9   job_7_task_7   job_8_task_10  job_9_task_18  job_10_task_14 job_11_task_16 job_12_task_19 job_13_task_19 job_14_task_1  job_15_task_7  job_16_task_12 job_17_task_5  job_18_task_13 job_19_task_9  job_20_task_18 job_21_task_2  job_22_task_0  job_23_task_3  job_24_task_0  job_25_task_10 job_26_task_13 job_27_task_17 job_28_task_2  job_29_task_0  job_30_task_4  job_31_task_11 job_32_task_16 job_33_task_8  job_34_task_15 job_35_task_6  job_36_task_14 job_37_task_9  job_38_task_11 job_39_task_4  job_40_task_15 job_41_task_4  job_42_task_2  job_43_task_4  job_44_task_6  job_45_task_11 job_46_task_19 job_47_task_7  job_48_task_6  job_49_task_17 job_50_task_14 job_51_task_7  job_52_task_1  job_53_task_16 job_54_task_17 job_55_task_0  job_56_task_19 job_57_task_2  job_58_task_1  job_59_task_13 job_60_task_15 job_61_task_7  job_62_task_16 job_63_task_19 job_64_task_6  job_65_task_10 job_66_task_8  job_67_task_14 job_68_task_19 job_69_task_13 job_70_task_5  job_71_task_13 job_72_task_4  job_73_task_7  job_74_task_4  job_75_task_16 job_76_task_0  job_77_task_18 job_78_task_18 job_79_task_0  job_80_task_13 job_81_task_4  job_82_task_15 job_83_task_3  job_84_task_14 job_85_task_10 job_86_task_3  job_87_task_18 job_88_task_8  job_89_task_1  job_90_task_10 job_91_task_12 job_92_task_1  job_93_task_5  job_94_task_16 job_95_task_8  job_96_task_12 job_97_task_19 job_98_task_10 job_99_task_5
#            [97,21]        [97,61]        [97,71]        [97,83]        [97,56]        [97,88]        [97,79]        [97,56]        [97,98]        [97,10]        [97,93]        [97,66]        [97,32]        [97,22]        [97,79]        [97,78]        [97,24]        [97,5]         [97,9]         [97,81]        [97,63]        [97,80]        [97,6]         [97,99]        [97,24]        [97,17]        [97,17]        [97,59]        [97,29]        [97,5]         [97,74]        [97,28]        [97,32]        [97,45]        [97,89]        [97,87]        [97,32]        [97,18]        [97,11]        [97,20]        [97,44]        [97,23]        [97,10]        [97,70]        [97,75]        [97,24]        [97,85]        [97,54]        [97,12]        [97,73]        [97,2]         [97,26]        [97,13]        [97,57]        [97,64]        [97,38]        [97,66]        [97,30]        [97,67]        [97,13]        [97,99]        [97,9]         [97,23]        [97,5]         [97,10]        [97,12]        [97,29]        [97,46]        [97,96]        [97,38]        [97,39]        [97,18]        [97,76]        [97,94]        [97,37]        [97,19]        [97,52]        [97,22]        [97,85]        [97,32]        [97,42]        [97,21]        [97,9]         [97,18]        [97,88]        [97,80]        [97,10]        [97,5]         [97,25]        [97,43]        [97,16]        [97,67]        [97,29]        [97,74]        [97,4]         [97,68]        [97,22]        [97,61]        [97,46]        [97,82]
# Machine 20: job_0_task_18  job_1_task_2   job_2_task_4   job_3_task_1   job_4_task_12  job_5_task_9   job_6_task_10  job_7_task_18  job_8_task_3   job_9_task_14  job_10_task_7  job_11_task_10 job_12_task_17 job_13_task_1  job_14_task_7  job_15_task_17 job_16_task_10 job_17_task_10 job_18_task_15 job_19_task_2  job_20_task_19 job_21_task_4  job_22_task_19 job_23_task_17 job_24_task_14 job_25_task_9  job_26_task_8  job_27_task_14 job_28_task_0  job_29_task_6  job_30_task_19 job_31_task_17 job_32_task_2  job_33_task_11 job_34_task_17 job_35_task_10 job_36_task_13 job_37_task_8  job_38_task_16 job_39_task_2  job_40_task_2  job_41_task_6  job_42_task_17 job_43_task_7  job_44_task_15 job_45_task_3  job_46_task_18 job_47_task_8  job_48_task_16 job_49_task_6  job_50_task_17 job_51_task_10 job_52_task_10 job_53_task_19 job_54_task_4  job_55_task_14 job_56_task_18 job_57_task_7  job_58_task_12 job_59_task_7  job_60_task_18 job_61_task_16 job_62_task_3  job_63_task_2  job_64_task_9  job_65_task_0  job_66_task_16 job_67_task_6  job_68_task_5  job_69_task_18 job_70_task_18 job_71_task_16 job_72_task_7  job_73_task_2  job_74_task_10 job_75_task_7  job_76_task_10 job_77_task_5  job_78_task_17 job_79_task_12 job_80_task_4  job_81_task_15 job_82_task_1  job_83_task_6  job_84_task_7  job_85_task_17 job_86_task_6  job_87_task_7  job_88_task_9  job_89_task_12 job_90_task_14 job_91_task_11 job_92_task_2  job_93_task_1  job_94_task_8  job_95_task_2  job_96_task_11 job_97_task_3  job_98_task_6  job_99_task_8
#            [97,96]        [97,22]        [97,32]        [97,72]        [97,40]        [97,36]        [97,78]        [97,95]        [97,19]        [97,12]        [97,96]        [97,57]        [97,10]        [97,73]        [97,19]        [97,90]        [97,64]        [97,52]        [97,39]        [97,42]        [97,45]        [97,75]        [97,39]        [97,3]         [97,31]        [97,84]        [97,86]        [97,42]        [97,31]        [97,40]        [97,25]        [97,59]        [97,64]        [97,75]        [97,63]        [97,99]        [97,37]        [97,47]        [97,19]        [97,57]        [97,77]        [97,91]        [97,48]        [97,34]        [97,20]        [97,8]         [97,91]        [97,76]        [97,53]        [97,47]        [97,96]        [97,28]        [97,19]        [97,43]        [97,51]        [97,95]        [97,22]        [97,23]        [97,94]        [97,32]        [97,65]        [97,3]         [97,51]        [97,25]        [97,33]        [97,87]        [97,74]        [97,9]         [97,10]        [97,17]        [97,92]        [97,72]        [97,44]        [97,98]        [97,14]        [97,10]        [97,50]        [97,6]         [97,99]        [97,47]        [97,51]        [97,78]        [97,46]        [97,38]        [97,30]        [97,41]        [97,1]         [97,21]        [97,24]        [97,85]        [97,28]        [97,44]        [97,27]        [97,56]        [97,40]        [97,4]         [97,42]        [97,22]        [97,68]        [97,9]
#
# --- 1.31 seconds ---
# --- 16.23 seconds for the file---
# --- 41.05 seconds for the cell---
